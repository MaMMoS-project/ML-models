# %% [markdown]
# # Compound to simulated Spontaneous Magnetization

# %%
import sys
sys.path.append("..")

sys.argv = [
    "preprocess_ms_data.py",
    "--data-dir", "../data",
    "--out-dir", "../preprocessed_data",
]

# %%
# 1. Pre-process the raw data
import warnings

warnings.filterwarnings("ignore", category=FutureWarning)

import src.preprocess_ms_data as preprocess
preprocess.main()
# Out:
# Simulated Ms  — 54747 compositions (Ms>50000 A/m dropped 102790; dropped 2 unparsable)
#   RE / RE-free   : 19419 / 35328
#   Ms [A/m] range : 5.002e+04 .. 2.143e+06 (median 2.580e+05)
#   Dropped 18 KNOWN ferrimagnets (magnetite / spinel ferrites / garnets / hexaferrites).
#   !! CAREFUL: the dataset MAY STILL CONTAIN UNKNOWN ferrimagnets — composition cannot identify ferrimagnetism in general.
#   wrote 4 files to ../preprocessed_data/

# %%
# 2. Create embeddings for the pre-processed data
import src.create_embeddings as embeddings
embeddings.create_embeddings()
# Out:
# ======================================================================
# Creating compound embeddings for simulated Ms datasets
# ======================================================================
#
# Element embeddings: /home/christina-winkler/Projects/ML-models-git/compound-to-ms/compound-to-simulated-ms/demonstrator_notebook/../data/embeddings/element/matscholar200.json
# Vocabulary: 103 elements  |  dimension: 200
#
# ------------------------------------------------------------
# Dataset : RE-Free  (Simulated_Ms_RE-Free.csv)
#   Rows with valid Ms : 35328
#   Dropped (un-embeddable): 0
#   Embeddable rows        : 35328
#
# ------------------------------------------------------------
# Dataset : RE  (Simulated_Ms_RE.csv)
#   Rows with valid Ms : 19419
#   Dropped (un-embeddable): 0
#   Embeddable rows        : 19419
#
# ------------------------------------------------------------
# Dataset : All  (Simulated_Ms_all.csv)
#   Rows with valid Ms : 54747
#   Dropped (un-embeddable): 0
#   Embeddable rows        : 54747
#
# Done. Next step: python src/compress_embeddings_pca.py

# %%
# 3. Compress embeddings using PCA
import src.compress_embeddings_pca as compress_embeddings_pca
compress_embeddings_pca.compress_embeddings_pca()
# Out:
# ======================================================================
# PCA compression of compound embeddings
# ======================================================================
# Component sizes: [8, 16, 32, 64]
#
# ------------------------------------------------------------
# Dataset : RE-Free
#   Loaded 35328 rows
#   Raw embeddings shape: (35328, 200)
#   PCA( 8 components): explained variance = 0.705  → 'comp_emb_pca_8'
#   PCA(16 components): explained variance = 0.840  → 'comp_emb_pca_16'
#   PCA(32 components): explained variance = 0.951  → 'comp_emb_pca_32'
#   PCA(64 components): explained variance = 1.000  → 'comp_emb_pca_64'
#
# ------------------------------------------------------------
# Dataset : RE
#   Loaded 19419 rows
#   Raw embeddings shape: (19419, 200)
#   PCA( 8 components): explained variance = 0.652  → 'comp_emb_pca_8'
#   PCA(16 components): explained variance = 0.792  → 'comp_emb_pca_16'
#   PCA(32 components): explained variance = 0.926  → 'comp_emb_pca_32'
#   PCA(64 components): explained variance = 0.994  → 'comp_emb_pca_64'
#
# ------------------------------------------------------------
# Dataset : All
#   Loaded 54747 rows
#   Raw embeddings shape: (54747, 200)
#   PCA( 8 components): explained variance = 0.674  → 'comp_emb_pca_8'
#   PCA(16 components): explained variance = 0.807  → 'comp_emb_pca_16'
#   PCA(32 components): explained variance = 0.927  → 'comp_emb_pca_32'
#   PCA(64 components): explained variance = 0.993  → 'comp_emb_pca_64'
#
# Done. Next step: python src/train_ms.py

# %%
# 4. Train models
from src.train_ms import train_ms
train_ms()  # all three datasets (RE-Free, RE, All)
