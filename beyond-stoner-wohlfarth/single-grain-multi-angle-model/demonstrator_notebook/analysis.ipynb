# %% [markdown]
# ## Beyond Stoner-Wohlfarth Single-grain multi angle model
# ML model for micromagnetic simulations, h and K orientation can change independently on sphere.

# %%
import sys
from pathlib import Path
import os

# Get project root (parent of notebooks/)
PROJECT_ROOT = Path.cwd().parent.resolve()

# Add project root to Python path so src/ is importable
sys.path.insert(0, str(PROJECT_ROOT))

# Change working directory to project root
os.chdir(PROJECT_ROOT)

# %% [markdown]
# ### Data Pre-Processing

# %%
from scripts.analyze_magnetic_data import analyze_magnetic_data

# %%
analyze_magnetic_data()
# Out:
# Applying symmetry operations
#
#
# Removing very small BHmax values
#
#
#  Removing  76  datapoints out of  9914 points
#
#
#  Writting applied symmetries data for training into ./data/processed/
#
# Shape of the DataFrame: (9838, 7)
# No missing values in the DataFrame.
# Basic statistics:
#            Ms (A/m)       A (J/m)     K (J/m^3)      Hc (A/m)      Mr (A/m)  \
# count  9.838000e+03  9.838000e+03  9.838000e+03  9.838000e+03  9.838000e+03
# mean   4.290971e+06  5.025679e-10  4.849508e+06  8.669455e+05  1.610952e+06
# std    2.103766e+06  2.828490e-10  2.902159e+06  1.096235e+06  1.417877e+06
# min    4.074314e+04  3.770118e-13  3.087719e+02  8.005315e-01  6.365871e-04
# 25%    2.517801e+06  2.567231e-10  2.315572e+06  1.533786e+05  5.054696e+05
# 50%    4.286668e+06  4.995010e-10  4.814105e+06  4.666123e+05  1.178233e+06
# 75%    6.076723e+06  7.453580e-10  7.366409e+06  1.142565e+06  2.353315e+06
# max    7.955488e+06  9.998231e-10  9.998651e+06  9.130162e+06  7.472977e+06
# range  7.914744e+06  9.994461e-10  9.998342e+06  9.130161e+06  7.472977e+06
#
#        BHmax (J/m^3)  relative_angle
# count   9.838000e+03     9838.000000
# mean    2.740456e+05        0.997651
# std     4.722338e+05        0.372902
# min     2.644133e-01        0.009464
# 25%     1.342963e+04        0.729693
# 50%     7.383180e+04        1.046842
# 75%     3.188115e+05        1.309303
# max     4.520666e+06        1.570740
# range   4.520666e+06        1.561276
# 1496273.9997397268 6369095.238317108 0.2349272453547239 0.2349272453547239 2.351988602530484e-08 5.208764700102087e-09 4.515444136849543
#
# Analysis complete. Please check the plots directory for visualizations.

# %% [markdown]
# ### Model training

# %%
from scripts.train_model import MLPipeline

# %%
configpath = 'config/ml_config_test.yaml'

# %%
pipeline = MLPipeline(configpath)
# Out:
# Loaded configurations:
# {
#   "LogTransformation": {
#     "remove_negative": true,
#     "convert_to_tesla": false,
#     "apply_log_transform": true,
#     "log_exclude_cols": [
#       "relative_angle"
#     ]
#   }
# }

# %%
pipeline.run()
# Out:
#        Ms (A/m)       A (J/m)     K (J/m^3)      Hc (A/m)      Mr (A/m)  \
# 0  6.369095e+06  6.915201e-10  1.250070e+06  2.427709e+05  1.496274e+06
# 1  7.508412e+06  6.639665e-10  7.348260e+05  1.591135e+05  9.050180e+05
# 2  1.508968e+06  3.365501e-10  9.418408e+06  3.221281e+06  5.214874e+05
# 3  6.475838e+06  9.188104e-10  5.459821e+05  1.451171e+05  2.631304e+06
# 4  7.259253e+06  3.189277e-10  5.170089e+06  8.746818e+04  3.253484e+05
#
#    BHmax (J/m^3)  relative_angle        calculator  \
# 0   55795.721896        1.557563  mumax3_MinDriver
# 1   19129.603358        0.978500  mumax3_MinDriver
# 2   34838.510487        1.217929  mumax3_MinDriver
# 3  128853.092501        0.880977  mumax3_MinDriver
# 4    4171.165412        1.421916  mumax3_MinDriver
#
#                                      file_path
# 0   mumax_mindrive_data/data/output_157907_186
# 1  mumax_mindrive_data/data/output_165319_1688
# 2   mumax_mindrive_data/data/output_157882_867
# 3  mumax_mindrive_data/data/output_157907_1086
# 4  mumax_mindrive_data/data/output_157882_1661
# Dataset loaded successfully
# Dataset shape: (9838, 9)
#
# Using clustering method: none
# No clustering will be used, dataset will be 'all'
#
# Processed dataset: LogTransformation_all
# Total samples: 9838
# datasets:  {'all': {'LogTransformation_all': (       Ms (A/m)       A (J/m)  K (J/m^3)  relative_angle
# 0     15.666968  6.915201e-10  14.038711        1.557563
# 1     15.831535  6.639665e-10  13.507390        0.978500
# 2     14.226937  3.365501e-10  16.058177        1.217929
# 3     15.683589  9.188104e-10  13.210343        0.880977
# 4     15.797788  3.189277e-10  15.458401        1.421916
# ...         ...           ...        ...             ...
# 9833  15.685919  4.271719e-10  15.534305        1.262968
# 9834  15.453741  3.866344e-10  15.099293        0.171640
# 9835  14.254147  4.466923e-10  12.105414        0.438901
# 9836  15.279704  5.871795e-10  15.822898        1.024911
# 9837  15.686195  4.281240e-10  14.594616        0.973488
#
# [9838 rows x 4 columns],        Hc (A/m)   Mr (A/m)  BHmax (J/m^3)
# 0     12.399878  14.218489      10.929470
# 1     11.977379  13.715711       9.859045
# 2     14.985290  13.164442      10.458507
# 3     11.885303  14.782990      11.766436
# 4     11.379042  12.692655       8.336190
# ...         ...        ...            ...
# 9833  12.145502  13.538734       9.983037
# 9834  12.949697  15.415730      14.178017
# 9835  11.597840  14.155952      11.186863
# 9836  14.008936  14.617416      12.830431
# 9837  12.112527  13.594159      10.087749
#
# [9838 rows x 3 columns])}}
#
# Training and evaluating random_forest...
#
# Processing all dataset...
#
# Training random_forest on LogTransformation_all...
# Using scaler: standard
# Fitting 2 folds for each of 2 candidates, totalling 4 fits
# Best parameters: {'max_depth': 20}
# Best score: 0.5067706657962189
# Feature importance plot saved to results/plots/LogTransformation_all/random_forest/feature_importance_LogTransformation_all_standard.png
# Best parameters: {'max_depth': 20}
# Computing jackknife variance for Random Forest model...
# Jackknife variance computed successfully. Shape: (1968, 3)
#
# ==== random_forest Metrics for LogTransformation_all ====
#
#
# === OVERALL METRICS (Averaged Across All Outputs) ===
#
# Train Metrics:
# MSE   : 0.0630
# MAE   : 0.1082
# R²    : 0.9781
# Adj R²: 0.9781
# MAPE  : 36.51 %
# Gini  : -0.3691
#
# Test Metrics:
# MSE   : 0.4330
# MAE   : 0.2957
# R²    : 0.8541
# Adj R²: 0.8538
# MAPE  : 3.23 %
# Gini  : -0.3682
#
# === PER-VARIABLE METRICS ===
#
# --- Hc (A/m) ---
#
# Train Metrics:
# MSE   : 0.0332
# MAE   : 0.0905
# R²    : 0.9833
# Adj R²: 0.9833
# MAPE  : 0.89 %
# Gini  : -0.3631
#
# Test Metrics:
# MSE   : 0.2261
# MAE   : 0.2497
# R²    : 0.8864
# Adj R²: 0.8862
# MAPE  : 2.19 %
# Gini  : -0.3626
#
# --- Mr (A/m) ---
#
# Train Metrics:
# MSE   : 0.0373
# MAE   : 0.0786
# R²    : 0.9728
# Adj R²: 0.9728
# MAPE  : 106.24 %
# Gini  : -0.3549
#
# Test Metrics:
# MSE   : 0.2468
# MAE   : 0.2159
# R²    : 0.8238
# Adj R²: 0.8234
# MAPE  : 1.70 %
# Gini  : -0.3541
#
# --- BHmax (J/m^3) ---
#
# Train Metrics:
# MSE   : 0.1185
# MAE   : 0.1553
# R²    : 0.9781
# Adj R²: 0.9781
# MAPE  : 2.40 %
# Gini  : -0.3893
#
# Test Metrics:
# MSE   : 0.8262
# MAE   : 0.4215
# R²    : 0.8520
# Adj R²: 0.8517
# MAPE  : 5.79 %
# Gini  : -0.3879
#
# Training and evaluating neural_network...
#
# Processing all dataset...
#
# Training neural_network on LogTransformation_all...
# Using scaler: standard
# Input dimension: 4, Output dimension: 3
# Epoch [10/50], Loss: 0.619904
# Epoch [20/50], Loss: 0.514504
# Epoch [30/50], Loss: 0.464898
# Epoch [40/50], Loss: 0.434605
# Epoch [50/50], Loss: 0.430004
# Best parameters: {'hidden_dim': 64, 'num_epochs': 50, 'learning_rate': 0.001, 'batch_size': 32}
# PyTorch model saved to results/models/LogTransformation_all/neural_network.pt
#
# ==== neural_network Metrics for LogTransformation_all ====
#
#
# === OVERALL METRICS (Averaged Across All Outputs) ===
#
# Train Metrics:
# MSE   : 0.4133
# MAE   : 0.3633
# R²    : 0.8488
# Adj R²: 0.8487
# MAPE  : 87.09 %
# Gini  : -0.3681
#
# Test Metrics:
# MSE   : 0.4279
# MAE   : 0.3742
# R²    : 0.8512
# Adj R²: 0.8509
# MAPE  : 3.96 %
# Gini  : -0.3685
#
# === PER-VARIABLE METRICS ===
#
# --- Hc (A/m) ---
#
# Train Metrics:
# MSE   : 0.2510
# MAE   : 0.3064
# R²    : 0.8738
# Adj R²: 0.8738
# MAPE  : 2.86 %
# Gini  : -0.3626
#
# Test Metrics:
# MSE   : 0.2437
# MAE   : 0.3138
# R²    : 0.8776
# Adj R²: 0.8774
# MAPE  : 2.70 %
# Gini  : -0.3628
#
# --- Mr (A/m) ---
#
# Train Metrics:
# MSE   : 0.2662
# MAE   : 0.3160
# R²    : 0.8058
# Adj R²: 0.8057
# MAPE  : 251.25 %
# Gini  : -0.3539
#
# Test Metrics:
# MSE   : 0.2574
# MAE   : 0.3213
# R²    : 0.8162
# Adj R²: 0.8158
# MAPE  : 2.47 %
# Gini  : -0.3542
#
# --- BHmax (J/m^3) ---
#
# Train Metrics:
# MSE   : 0.7226
# MAE   : 0.4674
# R²    : 0.8667
# Adj R²: 0.8667
# MAPE  : 7.17 %
# Gini  : -0.3879
#
# Test Metrics:
# MSE   : 0.7825
# MAE   : 0.4874
# R²    : 0.8598
# Adj R²: 0.8595
# MAPE  : 6.71 %
# Gini  : -0.3884
#
# Training and evaluating linear_regression...
#
# Processing all dataset...
#
# Training linear_regression on LogTransformation_all...
# Using scaler: standard
# Fitting 2 folds for each of 2 candidates, totalling 4 fits
# Fitting 2 folds for each of 2 candidates, totalling 4 fits
# Fitting 2 folds for each of 2 candidates, totalling 4 fits
# Best parameters for multi-output linear regression:
# Output 0: {'fit_intercept': True}
# Output 1: {'fit_intercept': True}
# Output 2: {'fit_intercept': True}
# Best parameters: {'fit_intercept': True}
#
# ==== linear_regression Metrics for LogTransformation_all ====
#
#
# === OVERALL METRICS (Averaged Across All Outputs) ===
#
# Train Metrics:
# MSE   : 1.6547
# MAE   : 0.8504
# R²    : 0.4564
# Adj R²: 0.4561
# MAPE  : 103.20 %
# Gini  : -0.3594
#
# Test Metrics:
# MSE   : 1.6496
# MAE   : 0.8504
# R²    : 0.4747
# Adj R²: 0.4737
# MAPE  : 8.95 %
# Gini  : -0.3600
#
# === PER-VARIABLE METRICS ===
#
# --- Hc (A/m) ---
#
# Train Metrics:
# MSE   : 0.7991
# MAE   : 0.6152
# R²    : 0.5984
# Adj R²: 0.5982
# MAPE  : 5.44 %
# Gini  : -0.3594
#
# Test Metrics:
# MSE   : 0.7691
# MAE   : 0.6091
# R²    : 0.6138
# Adj R²: 0.6130
# MAPE  : 5.16 %
# Gini  : -0.3596
#
# --- Mr (A/m) ---
#
# Train Metrics:
# MSE   : 0.8456
# MAE   : 0.6382
# R²    : 0.3832
# Adj R²: 0.3829
# MAPE  : 286.07 %
# Gini  : -0.3474
#
# Test Metrics:
# MSE   : 0.8240
# MAE   : 0.6437
# R²    : 0.4116
# Adj R²: 0.4104
# MAPE  : 4.95 %
# Gini  : -0.3481
#
# --- BHmax (J/m^3) ---
#
# Train Metrics:
# MSE   : 3.3196
# MAE   : 1.2980
# R²    : 0.3877
# Adj R²: 0.3874
# MAPE  : 18.09 %
# Gini  : -0.3713
#
# Test Metrics:
# MSE   : 3.3556
# MAE   : 1.2985
# R²    : 0.3988
# Adj R²: 0.3975
# MAPE  : 16.74 %
# Gini  : -0.3724
#
# Training and evaluating lasso...
#
# Processing all dataset...
#
# Training lasso on LogTransformation_all...
# Using scaler: standard
# Best parameters: {'alpha': 0.01, 'tol': 0.0001}
#
# ==== lasso Metrics for LogTransformation_all ====
#
#
# === OVERALL METRICS (Averaged Across All Outputs) ===
#
# Train Metrics:
# MSE   : 1.6551
# MAE   : 0.8529
# R²    : 0.4562
# Adj R²: 0.4560
# MAPE  : 103.60 %
# Gini  : -0.3594
#
# Test Metrics:
# MSE   : 1.6507
# MAE   : 0.8533
# R²    : 0.4743
# Adj R²: 0.4732
# MAPE  : 8.97 %
# Gini  : -0.3600
#
# === PER-VARIABLE METRICS ===
#
# --- Hc (A/m) ---
#
# Train Metrics:
# MSE   : 0.7995
# MAE   : 0.6182
# R²    : 0.5981
# Adj R²: 0.5979
# MAPE  : 5.47 %
# Gini  : -0.3594
#
# Test Metrics:
# MSE   : 0.7696
# MAE   : 0.6123
# R²    : 0.6135
# Adj R²: 0.6127
# MAPE  : 5.18 %
# Gini  : -0.3596
#
# --- Mr (A/m) ---
#
# Train Metrics:
# MSE   : 0.8459
# MAE   : 0.6401
# R²    : 0.3829
# Adj R²: 0.3826
# MAPE  : 287.22 %
# Gini  : -0.3474
#
# Test Metrics:
# MSE   : 0.8249
# MAE   : 0.6462
# R²    : 0.4110
# Adj R²: 0.4098
# MAPE  : 4.97 %
# Gini  : -0.3481
#
# --- BHmax (J/m^3) ---
#
# Train Metrics:
# MSE   : 3.3200
# MAE   : 1.3004
# R²    : 0.3876
# Adj R²: 0.3873
# MAPE  : 18.12 %
# Gini  : -0.3713
#
# Test Metrics:
# MSE   : 3.3575
# MAE   : 1.3014
# R²    : 0.3984
# Adj R²: 0.3972
# MAPE  : 16.77 %
# Gini  : -0.3724
#
# Results saved to results/overall_results.json
# Pipeline execution completed.

# %% [markdown]
# ### Plot Metrics

# %%
from scripts.plot_metrics import *

# %%
results_dir = 'results/'

# %%
output = 'results/metric_tables'

# %%
# Set matplotlib style
plt.style.use('ggplot')

# %%
# Set default output directory as a subdirectory of the input directory
results_path = Path(results_dir)
if output is None:
    output_path = results_path / "metric_tables"
else:
    output_path = Path(output)

# %%
# Create output directory
output_path.mkdir(parents=True, exist_ok=True)

# %%
# Load results
results = load_results(results_dir)

# %%
# Create tables
create_metric_tables(results, output_path)
        
print(f"Tables and plots generated successfully in {output_path}")
# Out:
# Processing all data...
#   Creating tables for dataset: LogTransformation_all_standard
#     Saved overall metrics to results/metric_tables/LogTransformation_all_standard_overall_metrics.html
# Saved metrics plot to results/metric_tables/LogTransformation_all_standard_Overall_metrics.png
#     Creating table for variable: Mr (A/m)
#     Saved Mr (A/m) metrics to results/metric_tables/LogTransformation_all_standard_Mr__A_m__metrics.html
# Saved metrics plot to results/metric_tables/LogTransformation_all_standard_Mr__A_m__metrics.png
#     Creating table for variable: BHmax (J/m^3)
#     Saved BHmax (J/m^3) metrics to results/metric_tables/LogTransformation_all_standard_BHmax__J_m_3__metrics.html
# Saved metrics plot to results/metric_tables/LogTransformation_all_standard_BHmax__J_m_3__metrics.png
#     Creating table for variable: Hc (A/m)
#     Saved Hc (A/m) metrics to results/metric_tables/LogTransformation_all_standard_Hc__A_m__metrics.html
# Saved metrics plot to results/metric_tables/LogTransformation_all_standard_Hc__A_m__metrics.png
# Tables and plots generated successfully in results/metric_tables
