# %% [markdown]
# ## Beyond Stoner-Wohlfarth Single-grain multi angle model

# %%
import sys
from pathlib import Path
import os

# Get project root (parent of notebooks/)
PROJECT_ROOT = Path.cwd().parent.resolve()

# Add project root to Python path so src/ is importable
sys.path.insert(0, str(PROJECT_ROOT))

# Change working directory to project root
os.chdir(PROJECT_ROOT)

# %% [markdown]
# ### Data Pre-Processing

# %%
# !pip install mammos-units
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Ignored the following versions that require a different python version: 0.2.1 Requires-Python >=3.11; 0.2.2 Requires-Python >=3.11; 0.2.3 Requires-Python >=3.11; 0.3.0 Requires-Python >=3.11; 0.3.1 Requires-Python >=3.11; 0.3.1.post0 Requires-Python >=3.11; 0.3.2 Requires-Python >=3.11
# ERROR: Could not find a version that satisfies the requirement mammos-units (from versions: none)
# ERROR: No matching distribution found for mammos-units

# %%
from scripts.analyze_magnetic_data import analyze_magnetic_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from scripts.analyze_magnetic_data import analyze_magnetic_data
#
# File /raven/ptmp/cwinkler/ML-models/beyond-stoner-wohlfarth/single-grain-multi-angle-model/scripts/analyze_magnetic_data.py:6
#       3 import sys
#       4 import os
# ----> 6 import mammos_entity as me
#       7 import mammos_units as u
#       8 import numpy as np
#
# ModuleNotFoundError: No module named 'mammos_entity'

# %%
analyze_magnetic_data()

# %% [markdown]
# ### Model training

# %%
from scripts.train_model import MLPipeline

# %%
configpath = 'config/ml_config_test.yaml'

# %%
pipeline = MLPipeline(configpath)

# %%
pipeline.run()

# %% [markdown]
# ### Plot Metrics

# %%
from scripts.plot_metrics import *

# %%
results_dir = 'results/'

# %%
output = 'results/metric_tables'

# %%
# Set matplotlib style
plt.style.use('ggplot')

# %%
# Set default output directory as a subdirectory of the input directory
results_path = Path(results_dir)
if output is None:
    output_path = results_path / "metric_tables"
else:
    output_path = Path(output)

# %%
# Create output directory
output_path.mkdir(parents=True, exist_ok=True)

# %%
# Load results
results = load_results(results_dir)

# %%
# Create tables
create_metric_tables(results, output_path)
        
print(f"Tables and plots generated successfully in {output_path}")
