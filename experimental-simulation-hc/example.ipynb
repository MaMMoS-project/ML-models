# %% [markdown]
# ## Error Correction - experimental-simulated coercive field Hc
# ML models for predicting differences between experimentally measured and simulated coercivity field Hc

# %%
from src.ms_aux import *
from src.neel_data_analysis import analyze_neel_data

# %%
DATA_FOLDER = 'data'
PLOTS_FOLDER = 'plots'
fmdh_filename = '/'.join([DATA_FOLDER, 'full_micromagnetic_with_height.csv'])

# %% [markdown]
# ## Analyze Coercivity Data

# %%
analyze_neel_data(DATA_FOLDER, PLOTS_FOLDER, fmdh_filename)
# Out:
# ...
# Summary Regression model for $\Delta H_{c}$
# Intercept = -1447509.6029884499
# X0 coefficient= -0.4791866679648813
# X1 coefficient = 1886.7551723148574
# rank = 2
# singular value X0 = 2285810.9906070177
# singular value X1 = 1301.2146066979844
# r2_score_train = 0.941705992844217
# r2_score_test = 0.9578085587268598
# rmse_train = 46582.36776246172
# rmse_test = 43309.85883404562
# ...
#
# ...
# Summary Regression model for $H_{c}^{exp}$
# Intercept = -203113.714270949
# X0 coefficient= 1889.3244377763554
# X1 coefficient = -435650.9080241416
# rank = 2
# singular value X0 = 1415.6853530303547
# singular value X1 = 2.5118449326355163
# r2_score_train = 0.9673604506004532
# r2_score_test = 0.965583227641289
# rmse_train = 46573.12808245954
# rmse_test = 43359.3158027121
# ...
