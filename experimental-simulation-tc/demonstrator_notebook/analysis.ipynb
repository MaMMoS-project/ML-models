# %% [markdown]
# # Error Correction Curie temperature

# %% [markdown]
# [TODO] add description

# %%
import sys
from pathlib import Path
import os

# Get project root (parent of notebooks/)
PROJECT_ROOT = Path.cwd().parent.resolve()

# Add project root to Python path so src/ is importable
sys.path.insert(0, str(PROJECT_ROOT))

# Change working directory to project root
os.chdir(PROJECT_ROOT)

# %%
from src.augment_data import augment_data

# %% [markdown]
# ### 1. Data augmentation

# %%
augment_data()
# Out:
# Input: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/data/EC_curie_temp.csv
# Output directory: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs
#
# ============================================================
# CURIE TEMPERATURE DATA AUGMENTATION
# ============================================================
# Random seed: 42
# Loading data from /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/data/EC_curie_temp.csv
# Loaded 27754 entries using mammos_entity
#
# ============================================================
# FILTERING PAIRED DATA
# ============================================================
# All paired data: 839 samples
# RE paired data: 547 samples
# RE-free paired data: 292 samples
#
# ============================================================
# STATISTICAL DISTRIBUTION TESTS: RE VS RE-FREE
# ============================================================
#
# Performing Kolmogorov-Smirnov test on RE vs RE-free Tc_delta distributions
# Null hypothesis: The two distributions are the same
# Alternative hypothesis: The two distributions are different
#
# Kolmogorov-Smirnov test results:
#   KS statistic: 0.1933
#   p-value: 0.00000105
#   Result: Reject the null hypothesis (p < 0.05)
#   The distributions of Tc_delta in RE and RE-free datasets are significantly different.
#   This suggests that developing separate ML models for each dataset is justified.
#
# Distribution statistics:
#   RE materials:      mean = 2.20 K, std = 47.29 K, n = 547
#   RE-free materials: mean = -18.69 K, std = 126.22 K, n = 292
#
# ============================================================
# AUGMENTING DATASETS
# ============================================================
#
# Materials with Tc_sim but no Tc_exp: 1516
#
# Labeling materials for augmentation
#
# Generating mock experimental values:
#
# 1. ALL MATERIALS
#
#   Generating 1518 mock values for All materials...
#   Completed after 3 iteration(s)
#   Mean: 346.90 K, Std: 308.91 K
#   Min: 0.00 K, Max: 2315.00 K
#
# 2. RE MATERIALS
#
#   Generating 663 mock values for RE materials...
#   Completed after 4 iteration(s)
#   Mean: 231.33 K, Std: 215.84 K
#   Min: 0.17 K, Max: 1361.00 K
#
# 3. RE-FREE MATERIALS
#
#   Generating 855 mock values for RE-free materials...
#   Completed after 4 iteration(s)
#   Mean: 432.35 K, Std: 350.46 K
#   Min: 0.00 K, Max: 2455.00 K
#
# ============================================================
# COMBINING REAL AND MOCK DATA
# ============================================================
#
# Updating Tc_exp with augmented values where missing:
#   Updated RE-free compounds
#   Updated RE compounds
# ✓ All original Tc_exp values preserved correctly
# Total samples with valid Tc_exp: 18996
#
# ============================================================
# CALCULATING TEMPERATURE DELTAS
# ============================================================
# Main delta calculated using augmented Tc_exp values
#
# ============================================================
# GENERATING DELTA DISTRIBUTION PLOTS
# ============================================================
# Using 1383 bins for histograms
#   Saved: deltas_combined.png
#   Saved: deltas_re_free_and_re.png
#
# ============================================================
# SAVING AUGMENTED DATASETS
# ============================================================
#   Saved filtered original All dataset: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_all.csv
#     Samples: 839
#   Saved filtered original RE dataset: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_RE.csv
#     Samples: 547
#   Saved filtered original RE-free dataset: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_RE_Free.csv
#     Samples: 292
#   Saved All dataset: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_all.csv
#     Samples: 2474
#   Saved RE dataset: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_RE.csv
#     Samples: 1261
#   Saved RE-free dataset: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_RE_Free.csv
#     Samples: 1213
#
# Creating embedding-ready datasets based on use_for_emb == True
#   Original filtered embedding-compatible samples (All): 764
#   Saved original filtered All embedding dataset: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_all_emb.csv
#     Samples: 764
#   Saved original filtered RE embedding dataset: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_RE_emb.csv
#     Samples: 507
#   Saved original filtered RE-free embedding dataset: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_RE_Free_emb.csv
#     Samples: 257
#   Augmented embedding-compatible samples (All): 2013
#   Saved augmented All embedding dataset: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_all_emb.csv
#     Samples: 2013
#   Saved augmented RE embedding dataset: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_RE_emb.csv
#     Samples: 1083
#   Saved augmented RE-free embedding dataset: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_RE_Free_emb.csv
#     Samples: 930
#
# ============================================================
# AUGMENTATION SUMMARY (FROM OUTPUT FILES)
# ============================================================
#
# Reading original dataset files...
#   All: 839 samples
#   RE: 547 samples
#   RE-free: 292 samples
#   All (emb): 764 samples
#   RE (emb): 507 samples
#   RE-free (emb): 257 samples
#
# Reading augmented dataset files...
#   All: 2474 samples
#   RE: 1261 samples
#   RE-free: 1213 samples
#   All (emb): 2013 samples
#   RE (emb): 1083 samples
#   RE-free (emb): 930 samples
#
# ============================================================
# STATISTICAL DISTRIBUTION TESTS: ORIGINAL VS AUGMENTED
# ============================================================
# Performing Kolmogorov-Smirnov tests to verify augmentation quality
# Null hypothesis: The original and augmented distributions are the same
# Alternative hypothesis: The distributions are different
#
# 1. RE DATASET COMPARISON
#   Original RE samples: 547
#   Augmented RE samples: 1261
#   KS statistic: 0.0158
#   p-value: 0.99995880
#   Result: Fail to reject null hypothesis (p >= 0.05)
#   The augmented RE delta distribution is not significantly different from the original.
#   This suggests the augmentation maintained the statistical properties of the RE dataset.
#   Original RE: mean = 2.20 K, std = 47.29 K
#   Augmented RE: mean = 2.86 K, std = 48.71 K
#
# 2. RE-FREE DATASET COMPARISON
#   Original RE-free samples: 292
#   Augmented RE-free samples: 1213
#   KS statistic: 0.0332
#   p-value: 0.94858011
#   Result: Fail to reject null hypothesis (p >= 0.05)
#   The augmented RE-free delta distribution is not significantly different from the original.
#   This suggests the augmentation maintained the statistical properties of the RE-free dataset.
#   Original RE-free: mean = -18.69 K, std = 126.22 K
#   Augmented RE-free: mean = -9.08 K, std = 112.92 K
#
# ============================================================
# DATASET SIZE SUMMARY
# ============================================================
#
# Dataset              Original        Augmented
# --------------------------------------------------
# All                  839             2474
# RE                   547             1261
# RE-free              292             1213
#
# Embedding Dataset    Original        Augmented
# --------------------------------------------------
# All (emb)            764             2013
# RE (emb)             507             1083
# RE-free (emb)        257             930
#
# ============================================================
# AUGMENTATION COMPLETE!
# ============================================================

# %% [markdown]
# ### 2. Creation of embeddings

# %%
from src.create_embeddings import create_embeddings

# %%
create_embeddings()
# Out:
# script_dir /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/src
# project_root /home/christina-winkler/Projects/ML-models/experimental-simulation-tc
# ============================================================
# COMPOUND EMBEDDING CREATION
# ============================================================
# Random seed: 42
# Element embeddings: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/data/embeddings/element/matscholar200.json
# Data directory: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs
# Output directory: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs
#
# Loading element embeddings from /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/data/embeddings/element/matscholar200.json
# ✓ Loaded 103 element embeddings (200D)
#
# ============================================================
# LOADING EMBEDDING-READY DATASETS
# ============================================================
# Loading All_orig dataset from Pairs_all_emb.csv...
# ✓ Loaded All_orig: 764 samples
# Loading RE_orig dataset from Pairs_RE_emb.csv...
# ✓ Loaded RE_orig: 507 samples
# Loading RE-free_orig dataset from Pairs_RE_Free_emb.csv...
# ✓ Loaded RE-free_orig: 257 samples
# Loading All_aug dataset from Augm_all_emb.csv...
# ✓ Loaded All_aug: 2013 samples
# Loading RE_aug dataset from Augm_RE_emb.csv...
# ✓ Loaded RE_aug: 1083 samples
# Loading RE-free_aug dataset from Augm_RE_Free_emb.csv...
# ✓ Loaded RE-free_aug: 930 samples
#
# ============================================================
# Processing All_orig
# ============================================================
# Total samples: 764
# ✓ CompositionData initialized
# Creating embeddings using element-abundance weighted sum...
#   Progress: 700/764
# ✓ Successfully created embeddings: 764/764
#
# ============================================================
# Creating t-SNE visualization for All_orig
# ============================================================
# Samples with valid embeddings: 764
# Embeddings shape: (764, 200)
# Unique majority elements: 43
# Running t-SNE (perplexity=30, random_state=42)...
# ✓ t-SNE complete
# ✓ Saved visualization: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots/tsne_all_orig_majority_element.png
# ✓ Saved Tc_delta visualization: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots/tsne_all_orig_tc_delta.png
# ✓ Saved pickle: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_all_emb_w_embeddings.pkl
#
# ============================================================
# Processing RE_orig
# ============================================================
# Total samples: 507
# ✓ CompositionData initialized
# Creating embeddings using element-abundance weighted sum...
#   Progress: 500/507
# ✓ Successfully created embeddings: 507/507
#
# ============================================================
# Creating t-SNE visualization for RE_orig
# ============================================================
# Samples with valid embeddings: 507
# Embeddings shape: (507, 200)
# Unique majority elements: 30
# Running t-SNE (perplexity=30, random_state=42)...
# ✓ t-SNE complete
# ✓ Saved visualization: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots/tsne_re_orig_majority_element.png
# ✓ Saved Tc_delta visualization: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots/tsne_re_orig_tc_delta.png
# ✓ Saved pickle: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_RE_emb_w_embeddings.pkl
#
# ============================================================
# Processing RE-free_orig
# ============================================================
# Total samples: 257
# ✓ CompositionData initialized
# Creating embeddings using element-abundance weighted sum...
#   Progress: 200/257
# ✓ Successfully created embeddings: 257/257
#
# ============================================================
# Creating t-SNE visualization for RE-free_orig
# ============================================================
# Samples with valid embeddings: 257
# Embeddings shape: (257, 200)
# Unique majority elements: 28
# Running t-SNE (perplexity=30, random_state=42)...
# ✓ t-SNE complete
# ✓ Saved visualization: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots/tsne_re-free_orig_majority_element.png
# ✓ Saved Tc_delta visualization: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots/tsne_re-free_orig_tc_delta.png
# ✓ Saved pickle: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_RE_Free_emb_w_embeddings.pkl
#
# ============================================================
# Processing All_aug
# ============================================================
# Total samples: 2013
# ✓ CompositionData initialized
# Creating embeddings using element-abundance weighted sum...
#   Progress: 2000/2013
# ✓ Successfully created embeddings: 2013/2013
#
# ============================================================
# Creating t-SNE visualization for All_aug
# ============================================================
# Samples with valid embeddings: 2013
# Embeddings shape: (2013, 200)
# Unique majority elements: 61
# Running t-SNE (perplexity=30, random_state=42)...
# ✓ t-SNE complete
# ✓ Saved visualization: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots/tsne_all_aug_majority_element.png
# ✓ Saved Tc_delta visualization: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots/tsne_all_aug_tc_delta.png
# ✓ Saved pickle: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_all_emb_w_embeddings.pkl
#
# ============================================================
# Processing RE_aug
# ============================================================
# Total samples: 1083
# ✓ CompositionData initialized
# Creating embeddings using element-abundance weighted sum...
#   Progress: 1000/1083
# ✓ Successfully created embeddings: 1083/1083
#
# ============================================================
# Creating t-SNE visualization for RE_aug
# ============================================================
# Samples with valid embeddings: 1083
# Embeddings shape: (1083, 200)
# Unique majority elements: 40
# Running t-SNE (perplexity=30, random_state=42)...
# ✓ t-SNE complete
# ✓ Saved visualization: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots/tsne_re_aug_majority_element.png
# ✓ Saved Tc_delta visualization: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots/tsne_re_aug_tc_delta.png
# ✓ Saved pickle: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_RE_emb_w_embeddings.pkl
#
# ============================================================
# Processing RE-free_aug
# ============================================================
# Total samples: 930
# ✓ CompositionData initialized
# Creating embeddings using element-abundance weighted sum...
#   Progress: 900/930
# ✓ Successfully created embeddings: 930/930
#
# ============================================================
# Creating t-SNE visualization for RE-free_aug
# ============================================================
# Samples with valid embeddings: 930
# Embeddings shape: (930, 200)
# Unique majority elements: 46
# Running t-SNE (perplexity=30, random_state=42)...
# ✓ t-SNE complete
# ✓ Saved visualization: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots/tsne_re-free_aug_majority_element.png
# ✓ Saved Tc_delta visualization: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots/tsne_re-free_aug_tc_delta.png
# ✓ Saved pickle: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_RE_Free_emb_w_embeddings.pkl
#
# ============================================================
# EMBEDDING CREATION SUMMARY
# ============================================================
#
# Dataset                             Total   With Emb    % Valid
# ------------------------------------------------------------
# All_orig                              764        764     100.0%
# RE_orig                               507        507     100.0%
# RE-free_orig                          257        257     100.0%
# All_aug                              2013       2013     100.0%
# RE_aug                               1083       1083     100.0%
# RE-free_aug                           930        930     100.0%
#
# ============================================================
# OUTPUTS
# ============================================================
# Embeddings (PKL):   /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs
# Visualizations:     /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots
# ============================================================
#
# ✓ Embedding creation complete!

# %% [markdown]
# ### 3. Compress embeddings with PCA

# %%
from src.compress_embedding_PCA import compress_embeddings_PCA

# %%
compress_embeddings_PCA()
# Out:
# ============================================================
# PCA EMBEDDING COMPRESSION PIPELINE
# ============================================================
# Random seed: 42
# Input directory: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs
# Output directory: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs
#
#
# ============================================================
# PROCESSING DATASET: All_orig
# ============================================================
# Input file: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_all_emb_w_embeddings.pkl
#   Loaded 764 samples
#   Adding PCA components: [8, 16, 32]
#
# ============================================================
# COMPRESSING EMBEDDINGS WITH PCA
# ============================================================
# Original embeddings shape: (764, 200)
#
# Creating PCA compressions:
#
#   Fitting PCA with 8 components...
#   ✓ Explained variance: 0.7833 (78.33%)
#   ✓ Added column: comp_emb_pca_8_components
#
#   Fitting PCA with 16 components...
#   ✓ Explained variance: 0.8996 (89.96%)
#   ✓ Added column: comp_emb_pca_16_components
#
#   Fitting PCA with 32 components...
#   ✓ Explained variance: 0.9776 (97.76%)
#   ✓ Added column: comp_emb_pca_32_components
#
# ✓ Saved: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_all_emb_w_embeddings_PCA.pkl
#   Samples: 764
#   Columns: 12
#
#   Embedding columns:
#     - use_for_emb: ()
#     - compound_embedding: (200,)
#     - comp_emb_pca_8_components: (8,)
#     - comp_emb_pca_16_components: (16,)
#     - comp_emb_pca_32_components: (32,)
#
# ============================================================
# SUMMARY
# ============================================================
#
# Dataset Statistics:
#   Total samples: 764
#   Paired samples (Tc_sim & Tc_exp): 764
#   With embeddings: 764
#   Rare-earth containing: 507
#   Rare-earth free: 257
#
# Embedding Columns:
#   comp_emb_pca_16_components: 764 non-null
#   comp_emb_pca_32_components: 764 non-null
#   comp_emb_pca_8_components: 764 non-null
#   compound_embedding: 764 non-null
#   use_for_emb: 764 non-null
#
# ============================================================
#
# ============================================================
# PROCESSING DATASET: RE_orig
# ============================================================
# Input file: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_RE_emb_w_embeddings.pkl
#   Loaded 507 samples
#   Adding PCA components: [8, 16, 32]
#
# ============================================================
# COMPRESSING EMBEDDINGS WITH PCA
# ============================================================
# Original embeddings shape: (507, 200)
#
# Creating PCA compressions:
#
#   Fitting PCA with 8 components...
#   ✓ Explained variance: 0.8274 (82.74%)
#   ✓ Added column: comp_emb_pca_8_components
#
#   Fitting PCA with 16 components...
#   ✓ Explained variance: 0.9298 (92.98%)
#   ✓ Added column: comp_emb_pca_16_components
#
#   Fitting PCA with 32 components...
#   ✓ Explained variance: 0.9915 (99.15%)
#   ✓ Added column: comp_emb_pca_32_components
#
# ✓ Saved: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_RE_emb_w_embeddings_PCA.pkl
#   Samples: 507
#   Columns: 12
#
#   Embedding columns:
#     - use_for_emb: ()
#     - compound_embedding: (200,)
#     - comp_emb_pca_8_components: (8,)
#     - comp_emb_pca_16_components: (16,)
#     - comp_emb_pca_32_components: (32,)
#
# ============================================================
# SUMMARY
# ============================================================
#
# Dataset Statistics:
#   Total samples: 507
#   Paired samples (Tc_sim & Tc_exp): 507
#   With embeddings: 507
#   Rare-earth containing: 507
#   Rare-earth free: 0
#
# Embedding Columns:
#   comp_emb_pca_16_components: 507 non-null
#   comp_emb_pca_32_components: 507 non-null
#   comp_emb_pca_8_components: 507 non-null
#   compound_embedding: 507 non-null
#   use_for_emb: 507 non-null
#
# ============================================================
#
# ============================================================
# PROCESSING DATASET: RE-free_orig
# ============================================================
# Input file: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_RE_Free_emb_w_embeddings.pkl
#   Loaded 257 samples
#   Adding PCA components: [8, 16, 32]
#
# ============================================================
# COMPRESSING EMBEDDINGS WITH PCA
# ============================================================
# Original embeddings shape: (257, 200)
#
# Creating PCA compressions:
#
#   Fitting PCA with 8 components...
#   ✓ Explained variance: 0.7790 (77.90%)
#   ✓ Added column: comp_emb_pca_8_components
#
#   Fitting PCA with 16 components...
#   ✓ Explained variance: 0.9137 (91.37%)
#   ✓ Added column: comp_emb_pca_16_components
#
#   Fitting PCA with 32 components...
#   ✓ Explained variance: 0.9929 (99.29%)
#   ✓ Added column: comp_emb_pca_32_components
#
# ✓ Saved: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_RE_Free_emb_w_embeddings_PCA.pkl
#   Samples: 257
#   Columns: 12
#
#   Embedding columns:
#     - use_for_emb: ()
#     - compound_embedding: (200,)
#     - comp_emb_pca_8_components: (8,)
#     - comp_emb_pca_16_components: (16,)
#     - comp_emb_pca_32_components: (32,)
#
# ============================================================
# SUMMARY
# ============================================================
#
# Dataset Statistics:
#   Total samples: 257
#   Paired samples (Tc_sim & Tc_exp): 257
#   With embeddings: 257
#   Rare-earth containing: 0
#   Rare-earth free: 257
#
# Embedding Columns:
#   comp_emb_pca_16_components: 257 non-null
#   comp_emb_pca_32_components: 257 non-null
#   comp_emb_pca_8_components: 257 non-null
#   compound_embedding: 257 non-null
#   use_for_emb: 257 non-null
#
# ============================================================
#
# ============================================================
# PROCESSING DATASET: All_aug
# ============================================================
# Input file: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_all_emb_w_embeddings.pkl
#   Loaded 2013 samples
#   Adding PCA components: [8, 16, 32]
#
# ============================================================
# COMPRESSING EMBEDDINGS WITH PCA
# ============================================================
# Original embeddings shape: (2013, 200)
#
# Creating PCA compressions:
#
#   Fitting PCA with 8 components...
#   ✓ Explained variance: 0.7567 (75.67%)
#   ✓ Added column: comp_emb_pca_8_components
#
#   Fitting PCA with 16 components...
#   ✓ Explained variance: 0.8767 (87.67%)
#   ✓ Added column: comp_emb_pca_16_components
#
#   Fitting PCA with 32 components...
#   ✓ Explained variance: 0.9659 (96.59%)
#   ✓ Added column: comp_emb_pca_32_components
#
# ✓ Saved: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_all_emb_w_embeddings_PCA.pkl
#   Samples: 2013
#   Columns: 12
#
#   Embedding columns:
#     - use_for_emb: ()
#     - compound_embedding: (200,)
#     - comp_emb_pca_8_components: (8,)
#     - comp_emb_pca_16_components: (16,)
#     - comp_emb_pca_32_components: (32,)
#
# ============================================================
# SUMMARY
# ============================================================
#
# Dataset Statistics:
#   Total samples: 2013
#   Paired samples (Tc_sim & Tc_exp): 764
#   With embeddings: 2013
#   Rare-earth containing: 1083
#   Rare-earth free: 930
#
# Embedding Columns:
#   comp_emb_pca_16_components: 2013 non-null
#   comp_emb_pca_32_components: 2013 non-null
#   comp_emb_pca_8_components: 2013 non-null
#   compound_embedding: 2013 non-null
#   use_for_emb: 2013 non-null
#
# ============================================================
#
# ============================================================
# PROCESSING DATASET: RE_aug
# ============================================================
# Input file: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_RE_emb_w_embeddings.pkl
#   Loaded 1083 samples
#   Adding PCA components: [8, 16, 32]
#
# ============================================================
# COMPRESSING EMBEDDINGS WITH PCA
# ============================================================
# Original embeddings shape: (1083, 200)
#
# Creating PCA compressions:
#
#   Fitting PCA with 8 components...
#   ✓ Explained variance: 0.8209 (82.09%)
#   ✓ Added column: comp_emb_pca_8_components
#
#   Fitting PCA with 16 components...
#   ✓ Explained variance: 0.9214 (92.14%)
#   ✓ Added column: comp_emb_pca_16_components
#
#   Fitting PCA with 32 components...
#   ✓ Explained variance: 0.9862 (98.62%)
#   ✓ Added column: comp_emb_pca_32_components
#
# ✓ Saved: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_RE_emb_w_embeddings_PCA.pkl
#   Samples: 1083
#   Columns: 12
#
#   Embedding columns:
#     - use_for_emb: ()
#     - compound_embedding: (200,)
#     - comp_emb_pca_8_components: (8,)
#     - comp_emb_pca_16_components: (16,)
#     - comp_emb_pca_32_components: (32,)
#
# ============================================================
# SUMMARY
# ============================================================
#
# Dataset Statistics:
#   Total samples: 1083
#   Paired samples (Tc_sim & Tc_exp): 507
#   With embeddings: 1083
#   Rare-earth containing: 1083
#   Rare-earth free: 0
#
# Embedding Columns:
#   comp_emb_pca_16_components: 1083 non-null
#   comp_emb_pca_32_components: 1083 non-null
#   comp_emb_pca_8_components: 1083 non-null
#   compound_embedding: 1083 non-null
#   use_for_emb: 1083 non-null
#
# ============================================================
#
# ============================================================
# PROCESSING DATASET: RE-free_aug
# ============================================================
# Input file: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_RE_Free_emb_w_embeddings.pkl
#   Loaded 930 samples
#   Adding PCA components: [8, 16, 32]
#
# ============================================================
# COMPRESSING EMBEDDINGS WITH PCA
# ============================================================
# Original embeddings shape: (930, 200)
#
# Creating PCA compressions:
#
#   Fitting PCA with 8 components...
#   ✓ Explained variance: 0.7294 (72.94%)
#   ✓ Added column: comp_emb_pca_8_components
#
#   Fitting PCA with 16 components...
#   ✓ Explained variance: 0.8748 (87.48%)
#   ✓ Added column: comp_emb_pca_16_components
#
#   Fitting PCA with 32 components...
#   ✓ Explained variance: 0.9788 (97.88%)
#   ✓ Added column: comp_emb_pca_32_components
#
# ✓ Saved: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_RE_Free_emb_w_embeddings_PCA.pkl
#   Samples: 930
#   Columns: 12
#
#   Embedding columns:
#     - use_for_emb: ()
#     - compound_embedding: (200,)
#     - comp_emb_pca_8_components: (8,)
#     - comp_emb_pca_16_components: (16,)
#     - comp_emb_pca_32_components: (32,)
#
# ============================================================
# SUMMARY
# ============================================================
#
# Dataset Statistics:
#   Total samples: 930
#   Paired samples (Tc_sim & Tc_exp): 257
#   With embeddings: 930
#   Rare-earth containing: 0
#   Rare-earth free: 930
#
# Embedding Columns:
#   comp_emb_pca_16_components: 930 non-null
#   comp_emb_pca_32_components: 930 non-null
#   comp_emb_pca_8_components: 930 non-null
#   compound_embedding: 930 non-null
#   use_for_emb: 930 non-null
#
# ============================================================
#
# ✓ PCA compression complete for all available datasets!
#
# You can now run the training pipeline with:
#   python src/training_original_emb.py
#   python src/training_augmented_emb.py
#
# NOTE: The compressed embeddings are saved in new files with _PCA.pkl suffix.

# %% [markdown]
# ### 4. Model Training

# %% [markdown]
# #### 4.1 Original Dataset
# Train ML models on existing materials where both experimental and simulated values have been recorded.

# %%
from src.training_original import training_original

# %%
training_original()
# Out:
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/juliacall/__init__.py:61: UserWarning: torch was imported before juliacall. This may cause a segfault. To avoid this, import juliacall before importing torch. For updates, see https://github.com/pytorch/pytorch/issues/78829.
#   warnings.warn(
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# ================================================================================
# ORIGINAL DATA TRAINING (NO EMBEDDINGS)
# ================================================================================
#
# ------------------------------------------------------------
# Training on All-Pairs dataset type: all
# ------------------------------------------------------------
#
# ============================================================
# Training Symbolic Regression: All-Pairs
# ============================================================
# Loading original (pairs) data for all dataset from: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_all.csv
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 839
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 671
# Test samples: 168
#
# Fitting PySR model...
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.439e+03  0.000e+00  y = x₀
# 3           6.139e+03  2.364e-02  y = x₀ * 0.95099
# 5           5.986e+03  1.232e-02  y = (x₀ * 0.91039) + 18.95
# 7           5.986e+03  -0.000e+00  y = ((x₀ + x₀) * 0.45521) + 18.939
# 9           5.977e+03  4.924e-04  y = (((x₀ * -3.7029e-05) + 0.94146) * x₀) + 15.243
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#
# Best equation: x0 * 0.95098996
#
# Test Metrics:
#   R² = 0.8408
#   RMSE = 96.76 K
#   MAE = 39.73 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Pairs_SR.png
#   Symbolic Regression - R²: 0.8408
#
# ============================================================
# Training Linear Models: All-Pairs
# Using only Tc_sim (no embedding)
# ============================================================
# Loading original (pairs) data for all dataset from: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_all.csv
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 839
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 671
# Test samples: 168
# Feature dimensions: 1
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.8464
# Test RMSE = 95.06 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Pairs_lasso_no_emb.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.8462
# Test RMSE = 95.10 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Pairs_ridge_no_emb.png
#
# --- Training LINEAR ---
# Best params: {}
# Test R² = 0.8462
# Test RMSE = 95.13 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Pairs_linear_no_emb.png
#   Linear - Best model: LASSO, R²: 0.8464
#
# ============================================================
# Training Random Forest: All-Pairs
# Using only Tc_sim (no embedding)
# ============================================================
# Loading original (pairs) data for all dataset from: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_all.csv
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 839
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 671
# Test samples: 168
# Feature dimensions: 1
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 100, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': None, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.8278
#   RMSE = 100.63 K
#   MAE = 44.02 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Pairs_RF_no_emb.png
#   Random Forest - R²: 0.8278
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: All-Pairs
# Using only Tc_sim (no embedding)
# ============================================================
# Loading original (pairs) data for all dataset from: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_all.csv
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 839
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 671
# Test samples: 168
# Feature dimensions: 1
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 8729.7802, Val Loss: 7949.3790
# Epoch [40/200], Train Loss: 8426.2090, Val Loss: 7967.7627
# Early stopping at epoch 57
#
# Final Test Metrics:
#   R² = 0.8481
#   RMSE = 94.51 K
#   MAE = 41.00 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Pairs_MLP_no_emb.png
#   FCNN/MLP - R²: 0.8481
#
# ------------------------------------------------------------
# Training on RE-Pairs dataset type: re
# ------------------------------------------------------------
#
# ============================================================
# Training Symbolic Regression: RE-Pairs
# ============================================================
# Loading original (pairs) data for re dataset from: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_RE.csv
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 547
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 437
# Test samples: 110
#
# Fitting PySR model...
#   - outputs/20260206_142450_XnHIcv/hall_of_fame.csv
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.150e+03  0.000e+00  y = x₀
# 3           2.105e+03  1.053e-02  y = x₀ * 0.97406
# 5           2.031e+03  1.773e-02  y = (x₀ + 13.541) * 0.938
# 9           2.028e+03  4.279e-04  y = (((x₀ * 2.8679e-05) + 0.91783) * x₀) + 14.632
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#
# Best equation: (x0 + 13.540794) * 0.937996
#
# Test Metrics:
#   R² = 0.9130
#   RMSE = 52.23 K
#   MAE = 21.27 K
# [ Info: Results saved to:
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_SR.png
#   Symbolic Regression - R²: 0.9130
#
# ============================================================
# Training Linear Models: RE-Pairs
# Using only Tc_sim (no embedding)
# ============================================================
# Loading original (pairs) data for re dataset from: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_RE.csv
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 547
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 437
# Test samples: 110
# Feature dimensions: 1
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.9122
# Test RMSE = 52.46 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_lasso_no_emb.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.9127
# Test RMSE = 52.32 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_ridge_no_emb.png
#
# --- Training LINEAR ---
# Best params: {}
# Test R² = 0.9129
# Test RMSE = 52.23 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_linear_no_emb.png
#   Linear - Best model: LINEAR, R²: 0.9129
#
# ============================================================
# Training Random Forest: RE-Pairs
# Using only Tc_sim (no embedding)
# ============================================================
# Loading original (pairs) data for re dataset from: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_RE.csv
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 547
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 437
# Test samples: 110
# Feature dimensions: 1
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.9000
#   RMSE = 55.97 K
#   MAE = 24.41 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_RF_no_emb.png
#   Random Forest - R²: 0.9000
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: RE-Pairs
# Using only Tc_sim (no embedding)
# ============================================================
# Loading original (pairs) data for re dataset from: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_RE.csv
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 547
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 437
# Test samples: 110
# Feature dimensions: 1
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 4310.2418, Val Loss: 2579.1162
# Epoch [40/200], Train Loss: 3815.9307, Val Loss: 2816.3361
# Early stopping at epoch 41
#
# Final Test Metrics:
#   R² = 0.9095
#   RMSE = 53.26 K
#   MAE = 25.21 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_MLP_no_emb.png
#   FCNN/MLP - R²: 0.9095
#
# ------------------------------------------------------------
# Training on RE-Free-Pairs dataset type: re-free
# ------------------------------------------------------------
#
# ============================================================
# Training Symbolic Regression: RE-Free-Pairs
# ============================================================
# Loading original (pairs) data for re-free dataset from: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_RE_Free.csv
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 292
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 233
# Test samples: 59
#
# Fitting PySR model...
#   - outputs/20260206_142508_HhCYWj/hall_of_fame.csv
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.554e+04  0.000e+00  y = x₀
# 3           1.458e+04  3.146e-02  y = x₀ * 0.93608
# 5           1.408e+04  1.708e-02  y = (x₀ + 49.19) * 0.86205
# 9           1.407e+04  -0.000e+00  y = (((x₀ * 2.4103e-05) + 0.83775) * x₀) + 46.732
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#
# Best equation: x0 * 0.9360753
#
# Test Metrics:
#   R² = 0.7891
#   RMSE = 130.64 K
#   MAE = 71.14 K
# [ Info: Results saved to:
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_SR.png
#   Symbolic Regression - R²: 0.7891
#
# ============================================================
# Training Linear Models: RE-Free-Pairs
# Using only Tc_sim (no embedding)
# ============================================================
# Loading original (pairs) data for re-free dataset from: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_RE_Free.csv
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 292
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 233
# Test samples: 59
# Feature dimensions: 1
#
# --- Training LASSO ---
# Best params: {'alpha': 0.0001, 'max_iter': 20000}
# Test R² = 0.7887
# Test RMSE = 130.74 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_lasso_no_emb.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 0.1}
# Test R² = 0.7887
# Test RMSE = 130.74 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_ridge_no_emb.png
#
# --- Training LINEAR ---
# Best params: {}
# Test R² = 0.7887
# Test RMSE = 130.74 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_linear_no_emb.png
#   Linear - Best model: LINEAR, R²: 0.7887
#
# ============================================================
# Training Random Forest: RE-Free-Pairs
# Using only Tc_sim (no embedding)
# ============================================================
# Loading original (pairs) data for re-free dataset from: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_RE_Free.csv
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 292
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 233
# Test samples: 59
# Feature dimensions: 1
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 50, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': None, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.7699
#   RMSE = 136.46 K
#   MAE = 81.82 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_RF_no_emb.png
#   Random Forest - R²: 0.7699
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: RE-Free-Pairs
# Using only Tc_sim (no embedding)
# ============================================================
# Loading original (pairs) data for re-free dataset from: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_RE_Free.csv
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 292
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 233
# Test samples: 59
# Feature dimensions: 1
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 30338.8948, Val Loss: 27744.4438
# Epoch [40/200], Train Loss: 18738.4277, Val Loss: 19281.4587
# Epoch [60/200], Train Loss: 19014.8917, Val Loss: 18257.2878
# Epoch [80/200], Train Loss: 20543.7596, Val Loss: 18238.8652
# Early stopping at epoch 92
#
# Final Test Metrics:
#   R² = 0.7907
#   RMSE = 130.14 K
#   MAE = 76.26 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_MLP_no_emb.png
#   FCNN/MLP - R²: 0.7907
#
# ================================================================================
# ORIGINAL DATA (NO EMBEDDINGS) - MODEL COMPARISON
# ================================================================================
#       Model_Family  Model       Dataset       R2       RMSE       MAE
#                MLP   FCNN     All-Pairs 0.848124  94.514395 40.996450
#             Linear  LASSO     All-Pairs 0.846373  95.057771 41.092637
# SymbolicRegression   PySR     All-Pairs 0.840829  96.757542 39.731461
#       RandomForest     RF     All-Pairs 0.827818 100.634554 44.019236
#                MLP   FCNN RE-Free-Pairs 0.790683 130.136816 76.259074
# SymbolicRegression   PySR RE-Free-Pairs 0.789052 130.642979 71.144720
#             Linear LINEAR RE-Free-Pairs 0.788735 130.741098 72.643931
#       RandomForest     RF RE-Free-Pairs 0.769854 136.458333 81.817193
# SymbolicRegression   PySR      RE-Pairs 0.912953  52.233133 21.269113
#             Linear LINEAR      RE-Pairs 0.912950  52.234197 21.272112
#                MLP   FCNN      RE-Pairs 0.909493  53.261183 25.207358
#       RandomForest     RF      RE-Pairs 0.900039  55.973840 24.412276
# ================================================================================
# Results saved to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/original_comparison/original_models_comparison.csv
#
# ================================================================================
# BEST MODEL BY DATASET (SORTED BY R2)
# ================================================================================
#       Model_Family Model       Dataset       R2       RMSE       MAE
# SymbolicRegression  PySR      RE-Pairs 0.912953  52.233133 21.269113
#                MLP  FCNN     All-Pairs 0.848124  94.514395 40.996450
#                MLP  FCNN RE-Free-Pairs 0.790683 130.136816 76.259074
# ================================================================================
# Best models by dataset saved to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/original_comparison/original_best_by_dataset.csv
#
# R² BY DATASET AND MODEL FAMILY:
#       Dataset   Linear      MLP  RandomForest  SymbolicRegression
#     All-Pairs 0.846373 0.848124      0.827818            0.840829
# RE-Free-Pairs 0.788735 0.790683      0.769854            0.789052
#      RE-Pairs 0.912950 0.909493      0.900039            0.912953
# Pivot table saved to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/original_comparison/original_comparison_pivot.csv
#   - outputs/20260206_142515_M22D09/hall_of_fame.csv

# %% [markdown]
# #### 4.2 Orginal Dataset with embedding

# %%
from src.training_original_emb import train_original_embedding

# %%
train_original_embedding()
# Out:
# ================================================================================
# ORIGINAL DATA TRAINING WITH EMBEDDINGS
# ================================================================================
# Found PCA-enriched embedding file for all: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_all_emb_w_embeddings_PCA.pkl
# Found PCA-enriched embedding file for re: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_RE_emb_w_embeddings_PCA.pkl
# Found PCA-enriched embedding file for re-free: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_RE_Free_emb_w_embeddings_PCA.pkl
# Loading embeddings file for 'all': /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_all_emb_w_embeddings_PCA.pkl
# Successfully loaded 764 samples for 'all'
# Filtered to pairs only: 764 -> 764 samples
# Available embedding columns for all: ['use_for_emb', 'compound_embedding', 'comp_emb_pca_8_components', 'comp_emb_pca_16_components', 'comp_emb_pca_32_components']
# Available embedding columns: ['use_for_emb', 'compound_embedding', 'comp_emb_pca_8_components', 'comp_emb_pca_16_components', 'comp_emb_pca_32_components']
#
# ============================================================
# DATASET: All-Pairs (type: all)
# ============================================================
#
# --------------------------------------------------
# Training with embedding: raw_200D
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: All-Pairs
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 764
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 611
# Test samples: 153
# Feature dimensions: 201
#
# --- Training LASSO ---
# Best params: {'alpha': 10, 'max_iter': 20000}
# Test R² = 0.7870
# Test RMSE = 111.77 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Pairs_lasso_None.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 10}
# Test R² = 0.7955
# Test RMSE = 109.52 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Pairs_ridge_None.png
#   Linear - Best model: RIDGE, R²: 0.7955
#
# ============================================================
# Training Random Forest: All-Pairs
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 764
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 611
# Test samples: 153
# Feature dimensions: 201
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.7880
#   RMSE = 111.51 K
#   MAE = 45.17 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Pairs_RF_None.png
#   Random Forest - R²: 0.7880
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: All-Pairs
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 764
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 611
# Test samples: 153
# Feature dimensions: 201
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 17024.0056, Val Loss: 17934.3877
# Epoch [40/200], Train Loss: 7849.5983, Val Loss: 12322.9989
# Early stopping at epoch 56
#
# Final Test Metrics:
#   R² = 0.8033
#   RMSE = 107.41 K
#   MAE = 64.91 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Pairs_MLP_None.png
#   FCNN/MLP - R²: 0.8033
#
# --------------------------------------------------
# Training with embedding: pca_16
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: All-Pairs
# Using embedding: pca_16
# ============================================================
# Training samples: 611
# Test samples: 153
# Feature dimensions: 17
#
# --- Training LASSO ---
# Best params: {'alpha': 10, 'max_iter': 20000}
# Test R² = 0.7861
# Test RMSE = 112.01 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Pairs_lasso_pca_16.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 10}
# Test R² = 0.7879
# Test RMSE = 111.53 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Pairs_ridge_pca_16.png
#   Linear - Best model: RIDGE, R²: 0.7879
#
# ============================================================
# Training Random Forest: All-Pairs
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 611
# Test samples: 153
# Feature dimensions: 17
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.7854
#   RMSE = 112.19 K
#   MAE = 43.52 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Pairs_RF_pca_16.png
#   Random Forest - R²: 0.7854
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: All-Pairs
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 611
# Test samples: 153
# Feature dimensions: 17
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 7016.4909, Val Loss: 13130.5995
# Epoch [40/200], Train Loss: 6999.8733, Val Loss: 12958.3227
# Early stopping at epoch 53
#
# Final Test Metrics:
#   R² = 0.7796
#   RMSE = 113.69 K
#   MAE = 62.41 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Pairs_MLP_pca_16.png
#   FCNN/MLP - R²: 0.7796
#
# --------------------------------------------------
# Training with embedding: pca_32
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: All-Pairs
# Using embedding: pca_32
# ============================================================
# Training samples: 611
# Test samples: 153
# Feature dimensions: 33
#
# --- Training LASSO ---
# Best params: {'alpha': 10, 'max_iter': 20000}
# Test R² = 0.7861
# Test RMSE = 112.01 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Pairs_lasso_pca_32.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 10}
# Test R² = 0.7908
# Test RMSE = 110.76 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Pairs_ridge_pca_32.png
#   Linear - Best model: RIDGE, R²: 0.7908
#
# ============================================================
# Training Random Forest: All-Pairs
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 611
# Test samples: 153
# Feature dimensions: 33
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': None, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.7833
#   RMSE = 112.74 K
#   MAE = 43.86 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Pairs_RF_pca_32.png
#   Random Forest - R²: 0.7833
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: All-Pairs
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 611
# Test samples: 153
# Feature dimensions: 33
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 8870.6590, Val Loss: 13221.5244
# Epoch [40/200], Train Loss: 6043.6632, Val Loss: 13192.3663
# Epoch [60/200], Train Loss: 6092.5208, Val Loss: 13253.8402
# Early stopping at epoch 63
#
# Final Test Metrics:
#   R² = 0.7747
#   RMSE = 114.96 K
#   MAE = 63.26 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Pairs_MLP_pca_32.png
#   FCNN/MLP - R²: 0.7747
#
# --------------------------------------------------
# Training with embedding: pca_8
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: All-Pairs
# Using embedding: pca_8
# ============================================================
# Training samples: 611
# Test samples: 153
# Feature dimensions: 9
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.7858
# Test RMSE = 112.10 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Pairs_lasso_pca_8.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 10}
# Test R² = 0.7901
# Test RMSE = 110.96 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Pairs_ridge_pca_8.png
#   Linear - Best model: RIDGE, R²: 0.7901
#
# ============================================================
# Training Random Forest: All-Pairs
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 611
# Test samples: 153
# Feature dimensions: 9
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.7652
#   RMSE = 117.35 K
#   MAE = 46.42 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Pairs_RF_pca_8.png
#   Random Forest - R²: 0.7652
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: All-Pairs
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 611
# Test samples: 153
# Feature dimensions: 9
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 7945.7665, Val Loss: 12666.3801
# Early stopping at epoch 33
#
# Final Test Metrics:
#   R² = 0.7824
#   RMSE = 112.99 K
#   MAE = 67.94 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Pairs_MLP_pca_8.png
#   FCNN/MLP - R²: 0.7824
#
# --------------------------------------------------
# Training with embedding: pca_64
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: All-Pairs
# Using embedding: pca_64
# ============================================================
# Error running Linear models: Embedding column for type pca_64 not found
#
# ============================================================
# Training Random Forest: All-Pairs
# Using embedding: pca_64
# ============================================================
# Error running Random Forest: Embedding column for type pca_64 not found
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: All-Pairs
# Using embedding: pca_64
# ============================================================
# Error running FCNN/MLP: Embedding column for type pca_64 not found
#
# ============================================================
# DATASET: RE-Pairs (type: re)
# ============================================================
# Loading embeddings file for 're': /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_RE_emb_w_embeddings_PCA.pkl
# Successfully loaded 507 samples for 're'
# Filtered to pairs only: 507 -> 507 samples
# Available embedding columns for re: ['use_for_emb', 'compound_embedding', 'comp_emb_pca_8_components', 'comp_emb_pca_16_components', 'comp_emb_pca_32_components']
#
# --------------------------------------------------
# Training with embedding: raw_200D
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Pairs
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 507
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 405
# Test samples: 102
# Feature dimensions: 201
#
# --- Training LASSO ---
# Best params: {'alpha': 10, 'max_iter': 20000}
# Test R² = 0.9140
# Test RMSE = 47.23 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_lasso_None.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 10}
# Test R² = 0.9071
# Test RMSE = 49.10 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_ridge_None.png
#   Linear - Best model: LASSO, R²: 0.9140
#
# ============================================================
# Training Random Forest: RE-Pairs
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 507
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 405
# Test samples: 102
# Feature dimensions: 201
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.9289
#   RMSE = 42.94 K
#   MAE = 21.76 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_RF_None.png
#   Random Forest - R²: 0.9289
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: RE-Pairs
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 507
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 405
# Test samples: 102
# Feature dimensions: 201
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 14282.5455, Val Loss: 7553.0543
# Epoch [40/200], Train Loss: 6721.8267, Val Loss: 4083.2140
# Epoch [60/200], Train Loss: 4243.6575, Val Loss: 2576.7100
# Epoch [80/200], Train Loss: 4150.0403, Val Loss: 2067.1560
# Epoch [100/200], Train Loss: 2993.3852, Val Loss: 2110.4698
# Early stopping at epoch 111
#
# Final Test Metrics:
#   R² = 0.9307
#   RMSE = 42.41 K
#   MAE = 30.66 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_MLP_None.png
#   FCNN/MLP - R²: 0.9307
#
# --------------------------------------------------
# Training with embedding: pca_16
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Pairs
# Using embedding: pca_16
# ============================================================
# Training samples: 405
# Test samples: 102
# Feature dimensions: 17
#
# --- Training LASSO ---
# Best params: {'alpha': 10, 'max_iter': 20000}
# Test R² = 0.9137
# Test RMSE = 47.31 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_lasso_pca_16.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.9252
# Test RMSE = 44.05 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_ridge_pca_16.png
#   Linear - Best model: RIDGE, R²: 0.9252
#
# ============================================================
# Training Random Forest: RE-Pairs
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 405
# Test samples: 102
# Feature dimensions: 17
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.9074
#   RMSE = 49.01 K
#   MAE = 24.73 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_RF_pca_16.png
#   Random Forest - R²: 0.9074
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: RE-Pairs
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 405
# Test samples: 102
# Feature dimensions: 17
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 4765.7435, Val Loss: 3766.8430
# Epoch [40/200], Train Loss: 4425.0039, Val Loss: 2651.3724
# Epoch [60/200], Train Loss: 3734.6882, Val Loss: 2480.1380
# Epoch [80/200], Train Loss: 3716.3662, Val Loss: 2177.1581
# Epoch [100/200], Train Loss: 2713.0521, Val Loss: 1990.7783
# Epoch [120/200], Train Loss: 2588.3979, Val Loss: 1866.1930
# Epoch [140/200], Train Loss: 3297.5993, Val Loss: 1832.2994
# Epoch [160/200], Train Loss: 3142.9618, Val Loss: 1766.5765
# Epoch [180/200], Train Loss: 2677.2891, Val Loss: 1756.2937
# Early stopping at epoch 183
#
# Final Test Metrics:
#   R² = 0.9337
#   RMSE = 41.48 K
#   MAE = 29.70 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_MLP_pca_16.png
#   FCNN/MLP - R²: 0.9337
#
# --------------------------------------------------
# Training with embedding: pca_32
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Pairs
# Using embedding: pca_32
# ============================================================
# Training samples: 405
# Test samples: 102
# Feature dimensions: 33
#
# --- Training LASSO ---
# Best params: {'alpha': 10, 'max_iter': 20000}
# Test R² = 0.9137
# Test RMSE = 47.31 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_lasso_pca_32.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.9202
# Test RMSE = 45.51 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_ridge_pca_32.png
#   Linear - Best model: RIDGE, R²: 0.9202
#
# ============================================================
# Training Random Forest: RE-Pairs
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 405
# Test samples: 102
# Feature dimensions: 33
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.9118
#   RMSE = 47.84 K
#   MAE = 24.51 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_RF_pca_32.png
#   Random Forest - R²: 0.9118
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: RE-Pairs
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 405
# Test samples: 102
# Feature dimensions: 33
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 5866.4874, Val Loss: 6676.5184
# Epoch [40/200], Train Loss: 3876.2233, Val Loss: 4321.9246
# Epoch [60/200], Train Loss: 3664.1902, Val Loss: 4209.7162
# Early stopping at epoch 73
#
# Final Test Metrics:
#   R² = 0.8175
#   RMSE = 68.82 K
#   MAE = 38.86 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_MLP_pca_32.png
#   FCNN/MLP - R²: 0.8175
#
# --------------------------------------------------
# Training with embedding: pca_8
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Pairs
# Using embedding: pca_8
# ============================================================
# Training samples: 405
# Test samples: 102
# Feature dimensions: 9
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.9220
# Test RMSE = 44.97 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_lasso_pca_8.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.9220
# Test RMSE = 44.98 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_ridge_pca_8.png
#   Linear - Best model: LASSO, R²: 0.9220
#
# ============================================================
# Training Random Forest: RE-Pairs
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 405
# Test samples: 102
# Feature dimensions: 9
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.9029
#   RMSE = 50.20 K
#   MAE = 24.94 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_RF_pca_8.png
#   Random Forest - R²: 0.9029
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: RE-Pairs
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 405
# Test samples: 102
# Feature dimensions: 9
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 4840.3973, Val Loss: 2893.6190
# Epoch [40/200], Train Loss: 4024.5397, Val Loss: 2346.1962
# Epoch [60/200], Train Loss: 3963.9308, Val Loss: 2053.6452
# Epoch [80/200], Train Loss: 4220.8328, Val Loss: 1902.2657
# Epoch [100/200], Train Loss: 3767.9210, Val Loss: 1769.8727
# Epoch [120/200], Train Loss: 3217.2100, Val Loss: 1830.5201
# Early stopping at epoch 134
#
# Final Test Metrics:
#   R² = 0.9387
#   RMSE = 39.88 K
#   MAE = 24.31 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_MLP_pca_8.png
#   FCNN/MLP - R²: 0.9387
#
# --------------------------------------------------
# Training with embedding: pca_64
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Pairs
# Using embedding: pca_64
# ============================================================
# Error running Linear models: Embedding column for type pca_64 not found
#
# ============================================================
# Training Random Forest: RE-Pairs
# Using embedding: pca_64
# ============================================================
# Error running Random Forest: Embedding column for type pca_64 not found
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: RE-Pairs
# Using embedding: pca_64
# ============================================================
# Error running FCNN/MLP: Embedding column for type pca_64 not found
#
# ============================================================
# DATASET: RE-Free-Pairs (type: re-free)
# ============================================================
# Loading embeddings file for 're-free': /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Pairs_RE_Free_emb_w_embeddings_PCA.pkl
# Successfully loaded 257 samples for 're-free'
# Filtered to pairs only: 257 -> 257 samples
# Available embedding columns for re-free: ['use_for_emb', 'compound_embedding', 'comp_emb_pca_8_components', 'comp_emb_pca_16_components', 'comp_emb_pca_32_components']
#
# --------------------------------------------------
# Training with embedding: raw_200D
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Free-Pairs
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 257
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 205
# Test samples: 52
# Feature dimensions: 201
#
# --- Training LASSO ---
# Best params: {'alpha': 10, 'max_iter': 20000}
# Test R² = 0.7809
# Test RMSE = 128.21 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_lasso_None.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 10}
# Test R² = 0.7520
# Test RMSE = 136.39 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_ridge_None.png
#   Linear - Best model: LASSO, R²: 0.7809
#
# ============================================================
# Training Random Forest: RE-Free-Pairs
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 257
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 205
# Test samples: 52
# Feature dimensions: 201
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 50, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': None, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.7787
#   RMSE = 128.85 K
#   MAE = 83.37 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_RF_None.png
#   Random Forest - R²: 0.7787
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: RE-Free-Pairs
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 257
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 205
# Test samples: 52
# Feature dimensions: 201
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 35784.9012, Val Loss: 41102.2012
# Epoch [40/200], Train Loss: 26944.0698, Val Loss: 29610.4365
# Epoch [60/200], Train Loss: 18674.9453, Val Loss: 21026.7324
# Epoch [80/200], Train Loss: 14317.0532, Val Loss: 18125.6357
# Epoch [100/200], Train Loss: 12323.5742, Val Loss: 15600.9736
# Epoch [120/200], Train Loss: 12467.0246, Val Loss: 15136.0947
# Epoch [140/200], Train Loss: 11046.1651, Val Loss: 14125.5420
# Early stopping at epoch 150
#
# Final Test Metrics:
#   R² = 0.8064
#   RMSE = 120.50 K
#   MAE = 88.88 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_MLP_None.png
#   FCNN/MLP - R²: 0.8064
#
# --------------------------------------------------
# Training with embedding: pca_16
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Free-Pairs
# Using embedding: pca_16
# ============================================================
# Training samples: 205
# Test samples: 52
# Feature dimensions: 17
#
# --- Training LASSO ---
# Best params: {'alpha': 10, 'max_iter': 20000}
# Test R² = 0.7668
# Test RMSE = 132.27 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_lasso_pca_16.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 10}
# Test R² = 0.7698
# Test RMSE = 131.40 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_ridge_pca_16.png
#   Linear - Best model: RIDGE, R²: 0.7698
#
# ============================================================
# Training Random Forest: RE-Free-Pairs
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 205
# Test samples: 52
# Feature dimensions: 17
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 10, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.7959
#   RMSE = 123.73 K
#   MAE = 76.24 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_RF_pca_16.png
#   Random Forest - R²: 0.7959
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: RE-Free-Pairs
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 205
# Test samples: 52
# Feature dimensions: 17
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 22724.1102, Val Loss: 30588.5547
# Epoch [40/200], Train Loss: 17470.9697, Val Loss: 16769.9648
# Epoch [60/200], Train Loss: 16381.1287, Val Loss: 15625.9502
# Epoch [80/200], Train Loss: 15410.2273, Val Loss: 16314.8997
# Early stopping at epoch 94
#
# Final Test Metrics:
#   R² = 0.7753
#   RMSE = 129.84 K
#   MAE = 93.50 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_MLP_pca_16.png
#   FCNN/MLP - R²: 0.7753
#
# --------------------------------------------------
# Training with embedding: pca_32
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Free-Pairs
# Using embedding: pca_32
# ============================================================
# Training samples: 205
# Test samples: 52
# Feature dimensions: 33
#
# --- Training LASSO ---
# Best params: {'alpha': 10, 'max_iter': 20000}
# Test R² = 0.7604
# Test RMSE = 134.08 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_lasso_pca_32.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 10}
# Test R² = 0.7275
# Test RMSE = 142.96 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_ridge_pca_32.png
#   Linear - Best model: LASSO, R²: 0.7604
#
# ============================================================
# Training Random Forest: RE-Free-Pairs
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 205
# Test samples: 52
# Feature dimensions: 33
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 50, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': None, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.7764
#   RMSE = 129.52 K
#   MAE = 80.68 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_RF_pca_32.png
#   Random Forest - R²: 0.7764
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: RE-Free-Pairs
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 205
# Test samples: 52
# Feature dimensions: 33
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 24507.5049, Val Loss: 42308.8672
# Epoch [40/200], Train Loss: 15396.8039, Val Loss: 29489.6675
# Epoch [60/200], Train Loss: 12779.1926, Val Loss: 26520.5215
# Epoch [80/200], Train Loss: 14701.4500, Val Loss: 25999.0518
# Epoch [100/200], Train Loss: 11470.1429, Val Loss: 26654.2178
# Epoch [120/200], Train Loss: 11393.1038, Val Loss: 24302.2363
# Epoch [140/200], Train Loss: 7924.1164, Val Loss: 24642.1597
# Early stopping at epoch 141
#
# Final Test Metrics:
#   R² = 0.7045
#   RMSE = 148.89 K
#   MAE = 103.22 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_MLP_pca_32.png
#   FCNN/MLP - R²: 0.7045
#
# --------------------------------------------------
# Training with embedding: pca_8
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Free-Pairs
# Using embedding: pca_8
# ============================================================
# Training samples: 205
# Test samples: 52
# Feature dimensions: 9
#
# --- Training LASSO ---
# Best params: {'alpha': 10, 'max_iter': 20000}
# Test R² = 0.7586
# Test RMSE = 134.57 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_lasso_pca_8.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 10}
# Test R² = 0.7640
# Test RMSE = 133.05 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_ridge_pca_8.png
#   Linear - Best model: RIDGE, R²: 0.7640
#
# ============================================================
# Training Random Forest: RE-Free-Pairs
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 205
# Test samples: 52
# Feature dimensions: 9
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20, 'bootstrap': False}
#
# Test Metrics:
#   R² = 0.7547
#   RMSE = 135.67 K
#   MAE = 82.40 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_RF_pca_8.png
#   Random Forest - R²: 0.7547
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: RE-Free-Pairs
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 205
# Test samples: 52
# Feature dimensions: 9
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 22445.1173, Val Loss: 22546.8789
# Epoch [40/200], Train Loss: 17833.9570, Val Loss: 14110.7114
# Epoch [60/200], Train Loss: 16169.3316, Val Loss: 14237.0591
# Early stopping at epoch 73
#
# Final Test Metrics:
#   R² = 0.7919
#   RMSE = 124.95 K
#   MAE = 89.36 K
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.956e+05, tolerance: 2.424e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.009e+05, tolerance: 2.331e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.437e+05, tolerance: 2.218e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.783e+05, tolerance: 2.456e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.299e+05, tolerance: 2.456e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.493e+05, tolerance: 2.436e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.585e+04, tolerance: 2.436e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.979e+05, tolerance: 2.424e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.534e+05, tolerance: 2.218e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.889e+05, tolerance: 2.424e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.522e+05, tolerance: 2.331e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.011e+05, tolerance: 2.456e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.935e+05, tolerance: 2.218e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.447e+05, tolerance: 2.424e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.178e+05, tolerance: 2.436e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.718e+05, tolerance: 2.424e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.663e+05, tolerance: 2.331e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.499e+03, tolerance: 2.456e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.499e+03, tolerance: 2.218e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.943e+04, tolerance: 2.331e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.517e+05, tolerance: 2.331e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.279e+05, tolerance: 2.456e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.050e+04, tolerance: 2.424e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.781e+03, tolerance: 2.456e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.956e+05, tolerance: 2.218e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.358e+05, tolerance: 2.436e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.303e+04, tolerance: 2.331e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.654e+05, tolerance: 8.815e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.092e+05, tolerance: 1.042e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.499e+05, tolerance: 1.054e+03
# ...
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.812e+05, tolerance: 9.835e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.075e+05, tolerance: 9.853e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.782e+05, tolerance: 9.853e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.585e+05, tolerance: 1.039e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.298e+04, tolerance: 1.039e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.358e+05, tolerance: 9.774e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.852e+05, tolerance: 9.774e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.810e+05, tolerance: 1.013e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.821e+04, tolerance: 9.774e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.692e+05, tolerance: 9.853e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.444e+04, tolerance: 9.853e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.219e+05, tolerance: 1.039e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.229e+03, tolerance: 1.039e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.345e+05, tolerance: 9.835e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.902e+04, tolerance: 9.835e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.323e+04, tolerance: 1.013e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.636e+05, tolerance: 9.853e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.314e+05, tolerance: 1.013e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.656e+05, tolerance: 9.835e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.258e+04, tolerance: 9.774e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.197e+04, tolerance: 9.853e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.824e+03, tolerance: 1.039e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.778e+04, tolerance: 1.013e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.291e+04, tolerance: 9.835e+02
#   model = cd_fast.enet_coordinate_descent(
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_MLP_pca_8.png
#   FCNN/MLP - R²: 0.7919
#
# --------------------------------------------------
# Training with embedding: pca_64
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Free-Pairs
# Using embedding: pca_64
# ============================================================
# Error running Linear models: Embedding column for type pca_64 not found
#
# ============================================================
# Training Random Forest: RE-Free-Pairs
# Using embedding: pca_64
# ============================================================
# Error running Random Forest: Embedding column for type pca_64 not found
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: RE-Free-Pairs
# Using embedding: pca_64
# ============================================================
# Error running FCNN/MLP: Embedding column for type pca_64 not found
#
# ================================================================================
# ORIGINAL DATA WITH EMBEDDINGS - MODEL COMPARISON
# ================================================================================
# Model_Family Model       Dataset Embedding       R2       RMSE        MAE
#       Linear RIDGE     All-Pairs    pca_16 0.787940 111.530067  50.475076
# RandomForest    RF     All-Pairs    pca_16 0.785411 112.193275  43.518987
#          MLP  FCNN     All-Pairs    pca_16 0.779637 113.692491  62.408180
#       Linear RIDGE     All-Pairs    pca_32 0.790850 110.762360  51.344423
# RandomForest    RF     All-Pairs    pca_32 0.783300 112.743650  43.857680
#          MLP  FCNN     All-Pairs    pca_32 0.774678 114.964754  63.261466
#       Linear RIDGE     All-Pairs     pca_8 0.790113 110.957334  50.086730
#          MLP  FCNN     All-Pairs     pca_8 0.782364 112.986805  67.940470
# RandomForest    RF     All-Pairs     pca_8 0.765237 117.348502  46.415393
#          MLP  FCNN     All-Pairs  raw_200D 0.803314 107.411285  64.909200
#       Linear RIDGE     All-Pairs  raw_200D 0.795517 109.519372  51.950872
# RandomForest    RF     All-Pairs  raw_200D 0.788016 111.510172  45.169594
# RandomForest    RF RE-Free-Pairs    pca_16 0.795912 123.734126  76.241858
#          MLP  FCNN RE-Free-Pairs    pca_16 0.775264 129.842480  93.502611
#       Linear RIDGE RE-Free-Pairs    pca_16 0.769846 131.398307  87.553420
# RandomForest    RF RE-Free-Pairs    pca_32 0.776384 129.518562  80.682285
#       Linear LASSO RE-Free-Pairs    pca_32 0.760370 134.076113  84.832272
#          MLP  FCNN RE-Free-Pairs    pca_32 0.704494 148.889369 103.222692
#          MLP  FCNN RE-Free-Pairs     pca_8 0.791869 124.953569  89.363043
#       Linear RIDGE RE-Free-Pairs     pca_8 0.764026 133.049159  85.860912
# RandomForest    RF RE-Free-Pairs     pca_8 0.754652 135.666303  82.403198
#          MLP  FCNN RE-Free-Pairs  raw_200D 0.806428 120.504047  88.877575
#       Linear LASSO RE-Free-Pairs  raw_200D 0.780883 128.209122  81.180760
# RandomForest    RF RE-Free-Pairs  raw_200D 0.778683 128.851043  83.365433
#          MLP  FCNN      RE-Pairs    pca_16 0.933687  41.477796  29.703410
#       Linear RIDGE      RE-Pairs    pca_16 0.925216  44.047658  21.464746
# RandomForest    RF      RE-Pairs    pca_16 0.907419  49.009302  24.728321
#       Linear RIDGE      RE-Pairs    pca_32 0.920177  45.507266  22.634541
# RandomForest    RF      RE-Pairs    pca_32 0.911767  47.844657  24.509453
#          MLP  FCNN      RE-Pairs    pca_32 0.817453  68.818448  38.860964
#          MLP  FCNN      RE-Pairs     pca_8 0.938712  39.875339  24.310963
#       Linear LASSO      RE-Pairs     pca_8 0.922037  44.973956  21.577724
# RandomForest    RF      RE-Pairs     pca_8 0.902862  50.200935  24.939557
#          MLP  FCNN      RE-Pairs  raw_200D 0.930657  42.414812  30.664704
# RandomForest    RF      RE-Pairs  raw_200D 0.928917  42.943651  21.758419
#       Linear LASSO      RE-Pairs  raw_200D 0.914033  47.226240  24.875347
# ================================================================================
# Results saved to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/original_emb_comparison/original_emb_models_comparison.csv
#
# ================================================================================
# BEST MODEL BY DATASET (SORTED BY R2)
# ================================================================================
# Model_Family Model       Dataset Embedding       R2       RMSE       MAE
#          MLP  FCNN      RE-Pairs     pca_8 0.938712  39.875339 24.310963
#          MLP  FCNN RE-Free-Pairs  raw_200D 0.806428 120.504047 88.877575
#          MLP  FCNN     All-Pairs  raw_200D 0.803314 107.411285 64.909200
# ================================================================================
# Best models by dataset saved to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/original_emb_comparison/original_emb_best_by_dataset.csv
#
# R² BY EMBEDDING AND MODEL FAMILY:
#       Dataset Embedding   Linear      MLP  RandomForest
#     All-Pairs    pca_16 0.787940 0.779637      0.785411
#     All-Pairs    pca_32 0.790850 0.774678      0.783300
#     All-Pairs     pca_8 0.790113 0.782364      0.765237
#     All-Pairs  raw_200D 0.795517 0.803314      0.788016
# RE-Free-Pairs    pca_16 0.769846 0.775264      0.795912
# RE-Free-Pairs    pca_32 0.760370 0.704494      0.776384
# RE-Free-Pairs     pca_8 0.764026 0.791869      0.754652
# RE-Free-Pairs  raw_200D 0.780883 0.806428      0.778683
#      RE-Pairs    pca_16 0.925216 0.933687      0.907419
#      RE-Pairs    pca_32 0.920177 0.817453      0.911767
#      RE-Pairs     pca_8 0.922037 0.938712      0.902862
#      RE-Pairs  raw_200D 0.914033 0.930657      0.928917
# Pivot table saved to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/original_emb_comparison/original_emb_comparison_pivot.csv

# %% [markdown]
# #### 4.3 Augmented dataset

# %%
from src.training_augmented import training_augmented

# %%
training_augmented()
# Out:
# ================================================================================
# AUGMENTED DATA TRAINING (NO EMBEDDINGS)
# ================================================================================
#
# ------------------------------------------------------------
# Training on All-Augm dataset type: all
# ------------------------------------------------------------
#
# ============================================================
# Training Symbolic Regression: All-Augm
# ============================================================
# Loading augmented data for all dataset from: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_all.csv
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 2474
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 1979
# Test samples: 495
#
# Fitting PySR model...
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           7.687e+03  0.000e+00  y = x₀
# 3           7.588e+03  6.240e-03  y = x₀ * 0.97721
# 5           7.537e+03  3.084e-03  y = (x₀ * 0.95906) + 10.647
# 9           7.457e+03  2.557e-03  y = ((x₀ * 5.9747e-05) + 0.89119) * (x₀ + 23.439)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#
# Best equation: x0 * 0.9772063
#
# Test Metrics:
#   R² = 0.9271
#   RMSE = 81.53 K
#   MAE = 33.78 K
# [ Info: Results saved to:
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Augm_SR.png
#   Symbolic Regression - R²: 0.9271
#
# ============================================================
# Training Linear Models: All-Augm
# Using only Tc_sim (no embedding)
# ============================================================
# Loading augmented data for all dataset from: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_all.csv
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 2474
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 1979
# Test samples: 495
# Feature dimensions: 1
#
# --- Training LASSO ---
# Best params: {'alpha': 0.0001, 'max_iter': 20000}
# Test R² = 0.9275
# Test RMSE = 81.25 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Augm_lasso_no_emb.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 0.0001}
# Test R² = 0.9275
# Test RMSE = 81.25 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Augm_ridge_no_emb.png
#
# --- Training LINEAR ---
# Best params: {}
# Test R² = 0.9275
# Test RMSE = 81.25 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Augm_linear_no_emb.png
#   Linear - Best model: LASSO, R²: 0.9275
#
# ============================================================
# Training Random Forest: All-Augm
# Using only Tc_sim (no embedding)
# ============================================================
# Loading augmented data for all dataset from: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_all.csv
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 2474
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 1979
# Test samples: 495
# Feature dimensions: 1
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 10, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.9174
#   RMSE = 86.78 K
#   MAE = 42.91 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Augm_RF_no_emb.png
#   Random Forest - R²: 0.9174
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: All-Augm
# Using only Tc_sim (no embedding)
# ============================================================
# Loading augmented data for all dataset from: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_all.csv
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 2474
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 1979
# Test samples: 495
# Feature dimensions: 1
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 11781.6758, Val Loss: 6435.4858
# Epoch [40/200], Train Loss: 12040.8406, Val Loss: 6445.0448
# Early stopping at epoch 51
#
# Final Test Metrics:
#   R² = 0.9274
#   RMSE = 81.34 K
#   MAE = 37.56 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Augm_MLP_no_emb.png
#   FCNN/MLP - R²: 0.9274
#
# ------------------------------------------------------------
# Training on RE-Augm dataset type: re
# ------------------------------------------------------------
#
# ============================================================
# Training Symbolic Regression: RE-Augm
# ============================================================
# Loading augmented data for re dataset from: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_RE.csv
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 1261
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 1008
# Test samples: 253
#
# Fitting PySR model...
#   - outputs/20260206_142818_UtUKRF/hall_of_fame.csv
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.687e+03  0.000e+00  y = x₀
# 3           2.674e+03  2.422e-03  y = x₀ + 3.6874
# 5           2.631e+03  7.832e-03  y = (x₀ * 0.96776) + 10.661
# 9           2.630e+03  6.125e-05  y = (((x₀ * -1.4881e-05) + 0.97964) * x₀) + 9.3849
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#
# Best equation: (x0 * 0.96775734) + 10.661284
#
# Test Metrics:
#   R² = 0.9671
#   RMSE = 33.54 K
#   MAE = 15.90 K
# [ Info: Results saved to:
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Augm_SR.png
#   Symbolic Regression - R²: 0.9671
#
# ============================================================
# Training Linear Models: RE-Augm
# Using only Tc_sim (no embedding)
# ============================================================
# Loading augmented data for re dataset from: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_RE.csv
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 1261
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 1008
# Test samples: 253
# Feature dimensions: 1
#
# --- Training LASSO ---
# Best params: {'alpha': 0.1, 'max_iter': 20000}
# Test R² = 0.9671
# Test RMSE = 33.53 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Augm_lasso_no_emb.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 0.1}
# Test R² = 0.9671
# Test RMSE = 33.54 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Augm_ridge_no_emb.png
#
# --- Training LINEAR ---
# Best params: {}
# Test R² = 0.9671
# Test RMSE = 33.54 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Augm_linear_no_emb.png
#   Linear - Best model: LASSO, R²: 0.9671
#
# ============================================================
# Training Random Forest: RE-Augm
# Using only Tc_sim (no embedding)
# ============================================================
# Loading augmented data for re dataset from: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_RE.csv
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 1261
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 1008
# Test samples: 253
# Feature dimensions: 1
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.9627
#   RMSE = 35.71 K
#   MAE = 18.64 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Augm_RF_no_emb.png
#   Random Forest - R²: 0.9627
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: RE-Augm
# Using only Tc_sim (no embedding)
# ============================================================
# Loading augmented data for re dataset from: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_RE.csv
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 1261
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 1008
# Test samples: 253
# Feature dimensions: 1
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 5458.4668, Val Loss: 1158.6223
# Epoch [40/200], Train Loss: 4924.1605, Val Loss: 1218.3958
# Early stopping at epoch 49
#
# Final Test Metrics:
#   R² = 0.9664
#   RMSE = 33.87 K
#   MAE = 15.90 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Augm_MLP_no_emb.png
#   FCNN/MLP - R²: 0.9664
#
# ------------------------------------------------------------
# Training on RE-Free-Augm dataset type: re-free
# ------------------------------------------------------------
#
# ============================================================
# Training Symbolic Regression: RE-Free-Augm
# ============================================================
# Loading augmented data for re-free dataset from: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_RE_Free.csv
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 1213
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 970
# Test samples: 243
#
# Fitting PySR model...
#   - outputs/20260206_142831_ENDL62/hall_of_fame.csv
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.282e+04  0.000e+00  y = x₀
# 3           1.251e+04  1.148e-02  y = x₀ * 0.96813
# 5           1.247e+04  1.355e-03  y = (x₀ + 12.053) * 0.9512
# 9           1.237e+04  1.807e-03  y = (x₀ * ((x₀ * 5.5555e-05) + 0.8803)) + 26.111
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#
# Best equation: x0 * 0.968135
#
# Test Metrics:
#   R² = 0.9008
#   RMSE = 113.77 K
#   MAE = 55.92 K
# [ Info: Results saved to:
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_SR.png
#   Symbolic Regression - R²: 0.9008
#
# ============================================================
# Training Linear Models: RE-Free-Augm
# Using only Tc_sim (no embedding)
# ============================================================
# Loading augmented data for re-free dataset from: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_RE_Free.csv
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 1213
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 970
# Test samples: 243
# Feature dimensions: 1
#
# --- Training LASSO ---
# Best params: {'alpha': 0.1, 'max_iter': 20000}
# Test R² = 0.9005
# Test RMSE = 113.95 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_lasso_no_emb.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.9004
# Test RMSE = 113.98 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_ridge_no_emb.png
#
# --- Training LINEAR ---
# Best params: {}
# Test R² = 0.9005
# Test RMSE = 113.94 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_linear_no_emb.png
#   Linear - Best model: LINEAR, R²: 0.9005
#
# ============================================================
# Training Random Forest: RE-Free-Augm
# Using only Tc_sim (no embedding)
# ============================================================
# Loading augmented data for re-free dataset from: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_RE_Free.csv
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 1213
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 970
# Test samples: 243
# Feature dimensions: 1
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.8871
#   RMSE = 121.38 K
#   MAE = 69.04 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_RF_no_emb.png
#   Random Forest - R²: 0.8871
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: RE-Free-Augm
# Using only Tc_sim (no embedding)
# ============================================================
# Loading augmented data for re-free dataset from: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_RE_Free.csv
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 1213
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 970
# Test samples: 243
# Feature dimensions: 1
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 20046.8548, Val Loss: 12821.4766
# Epoch [40/200], Train Loss: 19017.8344, Val Loss: 12755.0838
# Early stopping at epoch 54
#
# Final Test Metrics:
#   R² = 0.9043
#   RMSE = 111.74 K
#   MAE = 58.31 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_MLP_no_emb.png
#   FCNN/MLP - R²: 0.9043
#
# ================================================================================
# AUGMENTED DATA (NO EMBEDDINGS) - MODEL COMPARISON
# ================================================================================
#       Model_Family  Model      Dataset       R2       RMSE       MAE
#             Linear  LASSO     All-Augm 0.927548  81.253476 34.522182
#                MLP   FCNN     All-Augm 0.927392  81.340542 37.556780
# SymbolicRegression   PySR     All-Augm 0.927060  81.526469 33.783785
#       RandomForest     RF     All-Augm 0.917357  86.779831 42.907296
#             Linear  LASSO      RE-Augm 0.967105  33.534100 15.922176
# SymbolicRegression   PySR      RE-Augm 0.967097  33.538190 15.895152
#                MLP   FCNN      RE-Augm 0.966443  33.869714 15.902224
#       RandomForest     RF      RE-Augm 0.962687  35.714930 18.643267
#                MLP   FCNN RE-Free-Augm 0.904288 111.742531 58.308077
# SymbolicRegression   PySR RE-Free-Augm 0.900791 113.765753 55.922178
#             Linear LINEAR RE-Free-Augm 0.900482 113.942461 55.721495
#       RandomForest     RF RE-Free-Augm 0.887075 121.375361 69.036193
# ================================================================================
# Results saved to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/augmented_comparison/augmented_models_comparison.csv
#
# ================================================================================
# BEST MODEL BY DATASET (SORTED BY R2)
# ================================================================================
# Model_Family Model      Dataset       R2       RMSE       MAE
#       Linear LASSO      RE-Augm 0.967105  33.534100 15.922176
#       Linear LASSO     All-Augm 0.927548  81.253476 34.522182
#          MLP  FCNN RE-Free-Augm 0.904288 111.742531 58.308077
# ================================================================================
# Best models by dataset saved to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/augmented_comparison/augmented_best_by_dataset.csv
#
# R² BY DATASET AND MODEL FAMILY:
#      Dataset   Linear      MLP  RandomForest  SymbolicRegression
#     All-Augm 0.927548 0.927392      0.917357            0.927060
#      RE-Augm 0.967105 0.966443      0.962687            0.967097
# RE-Free-Augm 0.900482 0.904288      0.887075            0.900791
# Pivot table saved to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/augmented_comparison/augmented_comparison_pivot.csv
#   - outputs/20260206_142840_lQdrTs/hall_of_fame.csv

# %% [markdown]
# #### 4.4 Augmented dataset with embedding

# %%
from src.training_augmented_emb import train_augmented_embedding

# %%
train_augmented_embedding()
# Out:
# ================================================================================
# AUGMENTED DATA TRAINING WITH EMBEDDINGS
# ================================================================================
# Found PCA-enriched embedding file for all: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_all_emb_w_embeddings_PCA.pkl
# Found PCA-enriched embedding file for re: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_RE_emb_w_embeddings_PCA.pkl
# Found PCA-enriched embedding file for re-free: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_RE_Free_emb_w_embeddings_PCA.pkl
# Loading embeddings file for 'all': /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_all_emb_w_embeddings_PCA.pkl
# Successfully loaded 2013 samples for 'all'
# Available embedding columns for all: ['use_for_emb', 'compound_embedding', 'comp_emb_pca_8_components', 'comp_emb_pca_16_components', 'comp_emb_pca_32_components']
# Available embedding columns: ['use_for_emb', 'compound_embedding', 'comp_emb_pca_8_components', 'comp_emb_pca_16_components', 'comp_emb_pca_32_components']
#
# ============================================================
# DATASET: All-Augm (type: all)
# ============================================================
#
# --------------------------------------------------
# Training with embedding: raw_200D
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: All-Augm
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 2013
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 1610
# Test samples: 403
# Feature dimensions: 201
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.9234
# Test RMSE = 76.64 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Augm_lasso_None.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 10}
# Test R² = 0.9236
# Test RMSE = 76.53 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Augm_ridge_None.png
#   Linear - Best model: RIDGE, R²: 0.9236
#
# ============================================================
# Training Random Forest: All-Augm
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 2013
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 1610
# Test samples: 403
# Feature dimensions: 201
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.9259
#   RMSE = 75.38 K
#   MAE = 38.82 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Augm_RF_None.png
#   Random Forest - R²: 0.9259
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: All-Augm
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 2013
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 1610
# Test samples: 403
# Feature dimensions: 201
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 10837.9070, Val Loss: 7134.7117
# Epoch [40/200], Train Loss: 11112.9993, Val Loss: 6433.7863
# Epoch [60/200], Train Loss: 10155.9306, Val Loss: 6252.6641
# Epoch [80/200], Train Loss: 9672.5414, Val Loss: 6184.6341
# Early stopping at epoch 92
#
# Final Test Metrics:
#   R² = 0.9212
#   RMSE = 77.72 K
#   MAE = 46.80 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Augm_MLP_None.png
#   FCNN/MLP - R²: 0.9212
#
# --------------------------------------------------
# Training with embedding: pca_16
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: All-Augm
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 1610
# Test samples: 403
# Feature dimensions: 17
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.9230
# Test RMSE = 76.83 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Augm_lasso_pca_16.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.9222
# Test RMSE = 77.24 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Augm_ridge_pca_16.png
#   Linear - Best model: LASSO, R²: 0.9230
#
# ============================================================
# Training Random Forest: All-Augm
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 1610
# Test samples: 403
# Feature dimensions: 17
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': None, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.9257
#   RMSE = 75.49 K
#   MAE = 38.59 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Augm_RF_pca_16.png
#   Random Forest - R²: 0.9257
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: All-Augm
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 1610
# Test samples: 403
# Feature dimensions: 17
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 10761.2091, Val Loss: 6342.4177
# Epoch [40/200], Train Loss: 10520.4899, Val Loss: 5770.8557
# Epoch [60/200], Train Loss: 9405.7964, Val Loss: 5522.4632
# Epoch [80/200], Train Loss: 9728.4488, Val Loss: 5558.3122
# Early stopping at epoch 82
#
# Final Test Metrics:
#   R² = 0.9278
#   RMSE = 74.38 K
#   MAE = 43.36 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Augm_MLP_pca_16.png
#   FCNN/MLP - R²: 0.9278
#
# --------------------------------------------------
# Training with embedding: pca_32
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: All-Augm
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 1610
# Test samples: 403
# Feature dimensions: 33
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.9237
# Test RMSE = 76.49 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Augm_lasso_pca_32.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.9232
# Test RMSE = 76.73 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Augm_ridge_pca_32.png
#   Linear - Best model: LASSO, R²: 0.9237
#
# ============================================================
# Training Random Forest: All-Augm
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 1610
# Test samples: 403
# Feature dimensions: 33
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.9261
#   RMSE = 75.26 K
#   MAE = 38.15 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Augm_RF_pca_32.png
#   Random Forest - R²: 0.9261
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: All-Augm
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 1610
# Test samples: 403
# Feature dimensions: 33
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 15213.0195, Val Loss: 7234.6417
# Epoch [40/200], Train Loss: 12766.4910, Val Loss: 6357.5420
# Epoch [60/200], Train Loss: 11508.1631, Val Loss: 5767.2092
# Epoch [80/200], Train Loss: 13107.1449, Val Loss: 5724.6571
# Early stopping at epoch 94
#
# Final Test Metrics:
#   R² = 0.9268
#   RMSE = 74.91 K
#   MAE = 43.25 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Augm_MLP_pca_32.png
#   FCNN/MLP - R²: 0.9268
#
# --------------------------------------------------
# Training with embedding: pca_8
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: All-Augm
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 1610
# Test samples: 403
# Feature dimensions: 9
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.9229
# Test RMSE = 76.90 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Augm_lasso_pca_8.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 0.1}
# Test R² = 0.9221
# Test RMSE = 77.27 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Augm_ridge_pca_8.png
#   Linear - Best model: LASSO, R²: 0.9229
#
# ============================================================
# Training Random Forest: All-Augm
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 1610
# Test samples: 403
# Feature dimensions: 9
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.9233
#   RMSE = 76.69 K
#   MAE = 39.10 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Augm_RF_pca_8.png
#   Random Forest - R²: 0.9233
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: All-Augm
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 1610
# Test samples: 403
# Feature dimensions: 9
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 10461.6535, Val Loss: 6114.2170
# Epoch [40/200], Train Loss: 9766.7691, Val Loss: 5897.2843
# Epoch [60/200], Train Loss: 9426.6130, Val Loss: 5680.8301
# Epoch [80/200], Train Loss: 9298.4475, Val Loss: 5626.0983
# Epoch [100/200], Train Loss: 10138.5301, Val Loss: 5626.8919
# Early stopping at epoch 106
#
# Final Test Metrics:
#   R² = 0.9262
#   RMSE = 75.22 K
#   MAE = 41.32 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/All-Augm_MLP_pca_8.png
#   FCNN/MLP - R²: 0.9262
#
# --------------------------------------------------
# Training with embedding: pca_64
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: All-Augm
# Using embedding: pca_64
# ============================================================
# Error running Linear models: Embedding column for type pca_64 not found
#
# ============================================================
# Training Random Forest: All-Augm
# Using embedding: pca_64
# ============================================================
# Error running Random Forest: Embedding column for type pca_64 not found
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: All-Augm
# Using embedding: pca_64
# ============================================================
# Error running FCNN/MLP: Embedding column for type pca_64 not found
#
# ============================================================
# DATASET: RE-Augm (type: re)
# ============================================================
# Loading embeddings file for 're': /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_RE_emb_w_embeddings_PCA.pkl
# Successfully loaded 1083 samples for 're'
# Available embedding columns for re: ['use_for_emb', 'compound_embedding', 'comp_emb_pca_8_components', 'comp_emb_pca_16_components', 'comp_emb_pca_32_components']
#
# --------------------------------------------------
# Training with embedding: raw_200D
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Augm
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 1083
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 866
# Test samples: 217
# Feature dimensions: 201
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.9018
# Test RMSE = 60.95 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Augm_lasso_None.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 10}
# Test R² = 0.9031
# Test RMSE = 60.54 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Augm_ridge_None.png
#   Linear - Best model: RIDGE, R²: 0.9031
#
# ============================================================
# Training Random Forest: RE-Augm
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 1083
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 866
# Test samples: 217
# Feature dimensions: 201
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.8993
#   RMSE = 61.74 K
#   MAE = 26.05 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Augm_RF_None.png
#   Random Forest - R²: 0.8993
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: RE-Augm
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 1083
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 866
# Test samples: 217
# Feature dimensions: 201
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 11921.6560, Val Loss: 15129.3093
# Epoch [40/200], Train Loss: 4299.2840, Val Loss: 4437.7687
# Epoch [60/200], Train Loss: 4517.5438, Val Loss: 4536.7414
# Epoch [80/200], Train Loss: 4067.1966, Val Loss: 3808.1375
# Early stopping at epoch 98
#
# Final Test Metrics:
#   R² = 0.9070
#   RMSE = 59.31 K
#   MAE = 31.00 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Augm_MLP_None.png
#   FCNN/MLP - R²: 0.9070
#
# --------------------------------------------------
# Training with embedding: pca_16
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Augm
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 866
# Test samples: 217
# Feature dimensions: 17
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.9019
# Test RMSE = 60.92 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Augm_lasso_pca_16.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.9018
# Test RMSE = 60.95 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Augm_ridge_pca_16.png
#   Linear - Best model: LASSO, R²: 0.9019
#
# ============================================================
# Training Random Forest: RE-Augm
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 866
# Test samples: 217
# Feature dimensions: 17
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 10, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.8940
#   RMSE = 63.33 K
#   MAE = 25.26 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Augm_RF_pca_16.png
#   Random Forest - R²: 0.8940
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: RE-Augm
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 866
# Test samples: 217
# Feature dimensions: 17
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 4628.8557, Val Loss: 4386.2402
# Epoch [40/200], Train Loss: 3660.0713, Val Loss: 4168.3190
# Epoch [60/200], Train Loss: 4183.8512, Val Loss: 3872.0067
# Epoch [80/200], Train Loss: 3517.0603, Val Loss: 3632.9685
# Early stopping at epoch 99
#
# Final Test Metrics:
#   R² = 0.9107
#   RMSE = 58.13 K
#   MAE = 26.95 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Augm_MLP_pca_16.png
#   FCNN/MLP - R²: 0.9107
#
# --------------------------------------------------
# Training with embedding: pca_32
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Augm
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 866
# Test samples: 217
# Feature dimensions: 33
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.9020
# Test RMSE = 60.91 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Augm_lasso_pca_32.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.9021
# Test RMSE = 60.85 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Augm_ridge_pca_32.png
#   Linear - Best model: RIDGE, R²: 0.9021
#
# ============================================================
# Training Random Forest: RE-Augm
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 866
# Test samples: 217
# Feature dimensions: 33
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 10, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.8944
#   RMSE = 63.22 K
#   MAE = 25.74 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Augm_RF_pca_32.png
#   Random Forest - R²: 0.8944
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: RE-Augm
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 866
# Test samples: 217
# Feature dimensions: 33
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 4362.7046, Val Loss: 4763.1319
# Epoch [40/200], Train Loss: 3409.6639, Val Loss: 3783.0737
# Epoch [60/200], Train Loss: 3444.2059, Val Loss: 3527.8871
# Epoch [80/200], Train Loss: 3571.8486, Val Loss: 3510.7024
# Epoch [100/200], Train Loss: 3316.8832, Val Loss: 3474.4828
# Early stopping at epoch 114
#
# Final Test Metrics:
#   R² = 0.9152
#   RMSE = 56.64 K
#   MAE = 27.23 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Augm_MLP_pca_32.png
#   FCNN/MLP - R²: 0.9152
#
# --------------------------------------------------
# Training with embedding: pca_8
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Augm
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 866
# Test samples: 217
# Feature dimensions: 9
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.9018
# Test RMSE = 60.97 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Augm_lasso_pca_8.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.9013
# Test RMSE = 61.11 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Augm_ridge_pca_8.png
#   Linear - Best model: LASSO, R²: 0.9018
#
# ============================================================
# Training Random Forest: RE-Augm
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 866
# Test samples: 217
# Feature dimensions: 9
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 10, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.8924
#   RMSE = 63.81 K
#   MAE = 25.33 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Augm_RF_pca_8.png
#   Random Forest - R²: 0.8924
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: RE-Augm
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 866
# Test samples: 217
# Feature dimensions: 9
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 5447.0924, Val Loss: 4426.6993
# Epoch [40/200], Train Loss: 5352.7814, Val Loss: 3899.8088
# Epoch [60/200], Train Loss: 4204.5303, Val Loss: 3766.6681
# Epoch [80/200], Train Loss: 3569.2350, Val Loss: 3559.5525
# Epoch [100/200], Train Loss: 3433.1104, Val Loss: 3540.5877
# Epoch [120/200], Train Loss: 4819.0957, Val Loss: 3461.8911
# Epoch [140/200], Train Loss: 3719.7658, Val Loss: 3512.2519
# Early stopping at epoch 144
#
# Final Test Metrics:
#   R² = 0.9128
#   RMSE = 57.44 K
#   MAE = 24.30 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Augm_MLP_pca_8.png
#   FCNN/MLP - R²: 0.9128
#
# --------------------------------------------------
# Training with embedding: pca_64
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Augm
# Using embedding: pca_64
# ============================================================
# Error running Linear models: Embedding column for type pca_64 not found
#
# ============================================================
# Training Random Forest: RE-Augm
# Using embedding: pca_64
# ============================================================
# Error running Random Forest: Embedding column for type pca_64 not found
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: RE-Augm
# Using embedding: pca_64
# ============================================================
# Error running FCNN/MLP: Embedding column for type pca_64 not found
#
# ============================================================
# DATASET: RE-Free-Augm (type: re-free)
# ============================================================
# Loading embeddings file for 're-free': /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/outputs/Augm_RE_Free_emb_w_embeddings_PCA.pkl
# Successfully loaded 930 samples for 're-free'
# Available embedding columns for re-free: ['use_for_emb', 'compound_embedding', 'comp_emb_pca_8_components', 'comp_emb_pca_16_components', 'comp_emb_pca_32_components']
#
# --------------------------------------------------
# Training with embedding: raw_200D
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Free-Augm
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 930
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 744
# Test samples: 186
# Feature dimensions: 201
#
# --- Training LASSO ---
# Best params: {'alpha': 10, 'max_iter': 20000}
# Test R² = 0.8770
# Test RMSE = 109.94 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_lasso_None.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 10}
# Test R² = 0.8646
# Test RMSE = 115.36 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_ridge_None.png
#   Linear - Best model: LASSO, R²: 0.8770
#
# ============================================================
# Training Random Forest: RE-Free-Augm
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 930
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 744
# Test samples: 186
# Feature dimensions: 201
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.8489
#   RMSE = 121.86 K
#   MAE = 64.80 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_RF_None.png
#   Random Forest - R²: 0.8489
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: RE-Free-Augm
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 930
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 744
# Test samples: 186
# Feature dimensions: 201
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 39229.8335, Val Loss: 39651.8584
# Epoch [40/200], Train Loss: 17561.8255, Val Loss: 16676.9590
# Epoch [60/200], Train Loss: 16021.4535, Val Loss: 17535.7541
# Epoch [80/200], Train Loss: 15899.2435, Val Loss: 15928.7624
# Epoch [100/200], Train Loss: 16600.2116, Val Loss: 16278.4183
# Early stopping at epoch 119
#
# Final Test Metrics:
#   R² = 0.8453
#   RMSE = 123.29 K
#   MAE = 84.64 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_MLP_None.png
#   FCNN/MLP - R²: 0.8453
#
# --------------------------------------------------
# Training with embedding: pca_16
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Free-Augm
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 744
# Test samples: 186
# Feature dimensions: 17
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.8740
# Test RMSE = 111.24 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_lasso_pca_16.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.8719
# Test RMSE = 112.21 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_ridge_pca_16.png
#   Linear - Best model: LASSO, R²: 0.8740
#
# ============================================================
# Training Random Forest: RE-Free-Augm
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 744
# Test samples: 186
# Feature dimensions: 17
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.8545
#   RMSE = 119.56 K
#   MAE = 62.74 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_RF_pca_16.png
#   Random Forest - R²: 0.8545
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: RE-Free-Augm
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 744
# Test samples: 186
# Feature dimensions: 17
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 20316.0635, Val Loss: 16967.0718
# Epoch [40/200], Train Loss: 18912.0589, Val Loss: 14735.5580
# Epoch [60/200], Train Loss: 17061.6665, Val Loss: 13945.9232
# Epoch [80/200], Train Loss: 16678.4233, Val Loss: 13353.9644
# Epoch [100/200], Train Loss: 15608.9128, Val Loss: 13369.6562
# Early stopping at epoch 116
#
# Final Test Metrics:
#   R² = 0.8753
#   RMSE = 110.67 K
#   MAE = 67.67 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_MLP_pca_16.png
#   FCNN/MLP - R²: 0.8753
#
# --------------------------------------------------
# Training with embedding: pca_32
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Free-Augm
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 744
# Test samples: 186
# Feature dimensions: 33
#
# --- Training LASSO ---
# Best params: {'alpha': 10, 'max_iter': 20000}
# Test R² = 0.8766
# Test RMSE = 110.09 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_lasso_pca_32.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.8677
# Test RMSE = 113.99 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_ridge_pca_32.png
#   Linear - Best model: LASSO, R²: 0.8766
#
# ============================================================
# Training Random Forest: RE-Free-Augm
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 744
# Test samples: 186
# Feature dimensions: 33
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.8517
#   RMSE = 120.72 K
#   MAE = 62.61 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_RF_pca_32.png
#   Random Forest - R²: 0.8517
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: RE-Free-Augm
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 744
# Test samples: 186
# Feature dimensions: 33
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 22825.6134, Val Loss: 21679.7894
# Epoch [40/200], Train Loss: 17500.9846, Val Loss: 17897.8439
# Epoch [60/200], Train Loss: 17059.0299, Val Loss: 18025.4717
# Epoch [80/200], Train Loss: 16216.0040, Val Loss: 17362.1079
# Epoch [100/200], Train Loss: 13844.4085, Val Loss: 17405.9965
# Early stopping at epoch 105
#
# Final Test Metrics:
#   R² = 0.8334
#   RMSE = 127.94 K
#   MAE = 85.66 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_MLP_pca_32.png
#   FCNN/MLP - R²: 0.8334
#
# --------------------------------------------------
# Training with embedding: pca_8
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Free-Augm
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 744
# Test samples: 186
# Feature dimensions: 9
#
# --- Training LASSO ---
# Best params: {'alpha': 0.1, 'max_iter': 20000}
# Test R² = 0.8745
# Test RMSE = 111.04 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_lasso_pca_8.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.8745
# Test RMSE = 111.06 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_ridge_pca_8.png
#   Linear - Best model: LASSO, R²: 0.8745
#
# ============================================================
# Training Random Forest: RE-Free-Augm
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 744
# Test samples: 186
# Feature dimensions: 9
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.8463
#   RMSE = 122.90 K
#   MAE = 66.26 K
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_RF_pca_8.png
#   Random Forest - R²: 0.8463
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: RE-Free-Augm
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 744
# Test samples: 186
# Feature dimensions: 9
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 21394.6440, Val Loss: 14802.1270
# Epoch [40/200], Train Loss: 17806.1016, Val Loss: 13208.0698
# Epoch [60/200], Train Loss: 17845.5806, Val Loss: 12860.7097
# Epoch [80/200], Train Loss: 17517.3201, Val Loss: 12565.1767
# Epoch [100/200], Train Loss: 18111.7353, Val Loss: 12598.5016
# Early stopping at epoch 115
#
# Final Test Metrics:
#   R² = 0.8826
#   RMSE = 107.41 K
#   MAE = 65.43 K
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.002e+06, tolerance: 1.000e+04
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.433e+06, tolerance: 1.009e+04
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.294e+06, tolerance: 1.002e+04
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.837e+05, tolerance: 1.027e+04
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.972e+05, tolerance: 9.964e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.574e+05, tolerance: 1.002e+04
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.678e+06, tolerance: 9.964e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.041e+05, tolerance: 1.002e+04
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.186e+06, tolerance: 1.000e+04
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.938e+04, tolerance: 1.027e+04
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.362e+06, tolerance: 1.009e+04
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.847e+06, tolerance: 1.027e+04
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.546e+04, tolerance: 1.000e+04
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.073e+05, tolerance: 9.964e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.685e+06, tolerance: 1.009e+04
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.795e+06, tolerance: 1.009e+04
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.647e+05, tolerance: 1.027e+04
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.448e+06, tolerance: 1.027e+04
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.380e+05, tolerance: 1.000e+04
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.417e+06, tolerance: 9.964e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.161e+06, tolerance: 1.002e+04
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.279e+06, tolerance: 1.000e+04
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.421e+04, tolerance: 2.429e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.718e+05, tolerance: 2.433e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.755e+05, tolerance: 2.433e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.095e+04, tolerance: 2.429e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.070e+04, tolerance: 2.433e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.785e+05, tolerance: 2.433e+03
#   model = cd_fast.enet_coordinate_descent(
# ...
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.911e+04, tolerance: 2.103e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.007e+04, tolerance: 2.103e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.578e+05, tolerance: 5.536e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.262e+05, tolerance: 5.536e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.576e+05, tolerance: 6.083e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.288e+05, tolerance: 5.987e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.260e+06, tolerance: 6.234e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.863e+05, tolerance: 6.234e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.528e+05, tolerance: 6.419e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.004e+05, tolerance: 6.083e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.030e+06, tolerance: 6.083e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.048e+05, tolerance: 5.987e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.130e+06, tolerance: 6.234e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.894e+05, tolerance: 5.987e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.396e+05, tolerance: 6.234e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.925e+05, tolerance: 6.419e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.021e+06, tolerance: 6.419e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.606e+04, tolerance: 6.083e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.037e+05, tolerance: 6.419e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.506e+03, tolerance: 5.987e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.542e+05, tolerance: 6.083e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.317e+05, tolerance: 5.536e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.703e+05, tolerance: 5.987e+03
#   model = cd_fast.enet_coordinate_descent(
# /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.131e+06, tolerance: 5.536e+03
#   model = cd_fast.enet_coordinate_descent(
# Saved figure to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_MLP_pca_8.png
#   FCNN/MLP - R²: 0.8826
#
# --------------------------------------------------
# Training with embedding: pca_64
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Free-Augm
# Using embedding: pca_64
# ============================================================
# Error running Linear models: Embedding column for type pca_64 not found
#
# ============================================================
# Training Random Forest: RE-Free-Augm
# Using embedding: pca_64
# ============================================================
# Error running Random Forest: Embedding column for type pca_64 not found
# Using device: cpu
#
# ============================================================
# Training FCNN/MLP: RE-Free-Augm
# Using embedding: pca_64
# ============================================================
# Error running FCNN/MLP: Embedding column for type pca_64 not found
#
# ================================================================================
# AUGMENTED DATA WITH EMBEDDINGS - MODEL COMPARISON
# ================================================================================
# Model_Family Model      Dataset Embedding       R2       RMSE       MAE
#          MLP  FCNN     All-Augm    pca_16 0.927836  74.382899 43.363060
# RandomForest    RF     All-Augm    pca_16 0.925676  75.487778 38.594105
#       Linear LASSO     All-Augm    pca_16 0.923003  76.833548 37.867887
#          MLP  FCNN     All-Augm    pca_32 0.926802  74.913871 43.251629
# RandomForest    RF     All-Augm    pca_32 0.926128  75.258232 38.154227
#       Linear LASSO     All-Augm    pca_32 0.923689  76.490287 37.762767
#          MLP  FCNN     All-Augm     pca_8 0.926208  75.217339 41.324295
# RandomForest    RF     All-Augm     pca_8 0.923299  76.685804 39.101885
#       Linear LASSO     All-Augm     pca_8 0.922869  76.900496 38.102377
# RandomForest    RF     All-Augm  raw_200D 0.925893  75.377689 38.820745
#       Linear RIDGE     All-Augm  raw_200D 0.923617  76.526536 40.496460
#          MLP  FCNN     All-Augm  raw_200D 0.921214  77.720991 46.801896
#          MLP  FCNN      RE-Augm    pca_16 0.910715  58.126958 26.945549
#       Linear LASSO      RE-Augm    pca_16 0.901919  60.922646 23.011288
# RandomForest    RF      RE-Augm    pca_16 0.894018  63.329220 25.256621
#          MLP  FCNN      RE-Augm    pca_32 0.915211  56.644508 27.228874
#       Linear RIDGE      RE-Augm    pca_32 0.902149  60.851212 23.116582
# RandomForest    RF      RE-Augm    pca_32 0.894396  63.215958 25.738477
#          MLP  FCNN      RE-Augm     pca_8 0.912802  57.443431 24.301963
#       Linear LASSO      RE-Augm     pca_8 0.901772  60.968537 22.984711
# RandomForest    RF      RE-Augm     pca_8 0.892402  63.810008 25.327796
#          MLP  FCNN      RE-Augm  raw_200D 0.907031  59.313973 30.999757
#       Linear RIDGE      RE-Augm  raw_200D 0.903137  60.543173 24.241767
# RandomForest    RF      RE-Augm  raw_200D 0.899261  61.742835 26.051562
#          MLP  FCNN RE-Free-Augm    pca_16 0.875333 110.673316 67.665588
#       Linear LASSO RE-Free-Augm    pca_16 0.874046 111.243033 60.067562
# RandomForest    RF RE-Free-Augm    pca_16 0.854519 119.555727 62.740314
#       Linear LASSO RE-Free-Augm    pca_32 0.876641 110.091045 59.708031
# RandomForest    RF RE-Free-Augm    pca_32 0.851673 120.719476 62.614985
#          MLP  FCNN RE-Free-Augm    pca_32 0.833389 127.943811 85.661345
#          MLP  FCNN RE-Free-Augm     pca_8 0.882570 107.413019 65.432811
#       Linear LASSO RE-Free-Augm     pca_8 0.874498 111.043376 59.883862
# RandomForest    RF RE-Free-Augm     pca_8 0.846269 122.898887 66.260151
#       Linear LASSO RE-Free-Augm  raw_200D 0.876971 109.943699 59.355834
# RandomForest    RF RE-Free-Augm  raw_200D 0.848867 121.855869 64.797749
#          MLP  FCNN RE-Free-Augm  raw_200D 0.845300 123.285801 84.635533
# ================================================================================
# Results saved to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/augmented_emb_comparison/augmented_emb_models_comparison.csv
#
# ================================================================================
# BEST MODEL BY DATASET (SORTED BY R2)
# ================================================================================
# Model_Family Model      Dataset Embedding       R2       RMSE       MAE
#          MLP  FCNN     All-Augm    pca_16 0.927836  74.382899 43.363060
#          MLP  FCNN      RE-Augm    pca_32 0.915211  56.644508 27.228874
#          MLP  FCNN RE-Free-Augm     pca_8 0.882570 107.413019 65.432811
# ================================================================================
# Best models by dataset saved to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/augmented_emb_comparison/augmented_emb_best_by_dataset.csv
#
# R² BY EMBEDDING AND MODEL FAMILY:
#      Dataset Embedding   Linear      MLP  RandomForest
#     All-Augm    pca_16 0.923003 0.927836      0.925676
#     All-Augm    pca_32 0.923689 0.926802      0.926128
#     All-Augm     pca_8 0.922869 0.926208      0.923299
#     All-Augm  raw_200D 0.923617 0.921214      0.925893
#      RE-Augm    pca_16 0.901919 0.910715      0.894018
#      RE-Augm    pca_32 0.902149 0.915211      0.894396
#      RE-Augm     pca_8 0.901772 0.912802      0.892402
#      RE-Augm  raw_200D 0.903137 0.907031      0.899261
# RE-Free-Augm    pca_16 0.874046 0.875333      0.854519
# RE-Free-Augm    pca_32 0.876641 0.833389      0.851673
# RE-Free-Augm     pca_8 0.874498 0.882570      0.846269
# RE-Free-Augm  raw_200D 0.876971 0.845300      0.848867
# Pivot table saved to: /home/christina-winkler/Projects/ML-models/experimental-simulation-tc/results/augmented_emb_comparison/augmented_emb_comparison_pivot.csv
