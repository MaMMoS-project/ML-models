# %% [markdown]
# # Error Correction Curie temperature

# %% [markdown]
# This notebook showcases how to train machine learning models for error correction from simulation results to experimental measurements.

# %%
import sys

sys.path.append("..")

# %% [markdown]
# ### 1. Data augmentation

# %%
from src.augment_data import augment_data

# %%
# %%capture captured_output
augment_data()

# %% [markdown]
# ### 2. Creation of embeddings

# %%
from src.create_embeddings import create_embeddings

# %%
# %%capture captured_output
create_embeddings()

# %% [markdown]
# ### 3. Compress embeddings with PCA

# %%
from src.compress_embedding_PCA import compress_embeddings_PCA

# %%
# %%capture captured_output
compress_embeddings_PCA()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Documents/ML-models/experimental-simulation-tc/demonstrator_notebook/../src/log_to_file.py:7, in log_output.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#       6 try:
# ----> 7     with open(file_path, "a") as f:
#       8         with redirect_stdout(f):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'logs/compress_embeddings_PCA.txt'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 compress_embeddings_PCA()
#
# File ~/Documents/ML-models/experimental-simulation-tc/demonstrator_notebook/../src/log_to_file.py:11, in log_output.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#       9             return func(*args, **kwargs)
#      10 except FileNotFoundError:
# ---> 11     return func(*args, **kwargs)
#
# File ~/Documents/ML-models/experimental-simulation-tc/demonstrator_notebook/../src/compress_embedding_PCA.py:293, in compress_embeddings_PCA()
#     291 # Compress embeddings with specific PCA components
#     292 print(f"  Adding PCA components: {component_sizes}")
# --> 293 df_compressed = compressor.compress_embeddings(df, component_sizes=component_sizes)
#     295 # Save result to a new file with _PCA.pkl suffix
#     296 new_filename = fname.replace('.pkl', '_PCA.pkl')
#
# File ~/Documents/ML-models/experimental-simulation-tc/demonstrator_notebook/../src/compress_embedding_PCA.py:146, in PCAEmbeddingCompressor.compress_embeddings(self, df, component_sizes)
#     144 # Use CompositionData to maintain consistency
#     145 task_dict = {'Tc_exp': 'regression'}
# --> 146 comp_data = CompositionData(
#     147     df=df,
#     148     task_dict=task_dict,
#     149     elem_embedding="matscholar200",
#     150     inputs="composition",
#     151     identifiers=("composition", "composition")
#     152 )
#     154 for item in comp_data:
#     155     try:
#
# File ~/Documents/ML-models/experimental-simulation-tc/demonstrator_notebook/../src/composition_data.py:63, in CompositionData.__init__(self, df, task_dict, elem_embedding, inputs, identifiers)
#      58 if elem_embedding in ["matscholar200", "cgcnn92", "megnet16", "onehot112"]:
#      59 #     elem_embedding = f"{PKG_DIR}/embeddings/element/{elem_embedding}.json"
#      60 #    elem_embedding = f"../embeddings/element/{elem_embedding}.json"
#      61     elem_embedding = f"data/embeddings/element/{elem_embedding}.json"
# ---> 63 with open(elem_embedding) as file:
#      64     self.elem_features = json.load(file)
#      66 self.elem_emb_len = len(next(iter(self.elem_features.values())))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/embeddings/element/matscholar200.json'

# %% [markdown]
# ### 4. Model Training

# %% [markdown]
# #### 4.1 Original Dataset
# Train ML models on existing materials where both experimental and simulated values have been recorded. Input is the simulated curie-temperature and target is the experimental curie-temperature.

# %%
from src.training_original import training_original

# %%
# %%capture captured_output
training_original();

# %% [markdown]
# #### 4.2 Orginal Dataset with embedding
# Train ML models including stoichiometric embedding as input variable alongside the simulated curie-temperature.

# %%
from src.training_original_emb import train_original_embedding

# %%
# %%capture captured_output
train_original_embedding()

# %% [markdown]
# #### 4.3 Augmented dataset
# Train ML models on augmented dataset, where gaps of missing experimental values have been filled with mock values. Input is the simulated curie-temperature and target is the experimental curie-temperature.

# %%
from src.training_augmented import training_augmented

# %%
# %%capture captured_output
training_augmented()

# %% [markdown]
# #### 4.4 Augmented dataset with embedding
# Train ML models on augmented dataset, where gaps of missing experimental values have been filled with mock values. Input is the simulated curie-temperature as well as the stoichiometric embedding and target is the experimental curie-temperature.

# %%
from src.training_augmented_emb import train_augmented_embedding

# %%
# %%capture captured_output
train_augmented_embedding()
