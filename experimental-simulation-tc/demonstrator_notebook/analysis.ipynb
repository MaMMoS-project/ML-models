# %% [markdown]
# # Error Correction Curie temperature

# %% [markdown]
# [TODO] add description

# %%
import sys
from pathlib import Path
import os

# Get project root (parent of notebooks/)
PROJECT_ROOT = Path.cwd().parent.resolve()

# Add project root to Python path so src/ is importable
sys.path.insert(0, str(PROJECT_ROOT))

# Change working directory to project root
os.chdir(PROJECT_ROOT)

print("Project root set to:", PROJECT_ROOT)
print("Current working directory:", Path.cwd())
# Out:
# Project root set to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc
# Current working directory: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc

# %%
from src.augment_data import augment_data

# %% [markdown]
# ### 1. Data augmentation

# %%
augment_data()
# Out:
# Input: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/data/EC_curie_temp.csv
# Output directory: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs
#
# ============================================================
# CURIE TEMPERATURE DATA AUGMENTATION
# ============================================================
# Random seed: 42
# Loading data from /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/data/EC_curie_temp.csv
# mammos_entity not available, using pandas directly
# Loaded 27754 entries using pandas
#
# ============================================================
# FILTERING PAIRED DATA
# ============================================================
# All paired data: 839 samples
# RE paired data: 547 samples
# RE-free paired data: 292 samples
#
# ============================================================
# STATISTICAL DISTRIBUTION TESTS: RE VS RE-FREE
# ============================================================
#
# Performing Kolmogorov-Smirnov test on RE vs RE-free Tc_delta distributions
# Null hypothesis: The two distributions are the same
# Alternative hypothesis: The two distributions are different
#
# Kolmogorov-Smirnov test results:
#   KS statistic: 0.1933
#   p-value: 0.00000105
#   Result: Reject the null hypothesis (p < 0.05)
#   The distributions of Tc_delta in RE and RE-free datasets are significantly different.
#   This suggests that developing separate ML models for each dataset is justified.
#
# Distribution statistics:
#   RE materials:      mean = 2.20 K, std = 47.29 K, n = 547
#   RE-free materials: mean = -18.69 K, std = 126.22 K, n = 292
#
# ============================================================
# AUGMENTING DATASETS
# ============================================================
#
# Materials with Tc_sim but no Tc_exp: 1516
#
# Labeling materials for augmentation
#
# Generating mock experimental values:
#
# 1. ALL MATERIALS
#
#   Generating 1518 mock values for All materials...
#   Completed after 3 iteration(s)
#   Mean: 346.90 K, Std: 308.91 K
#   Min: 0.00 K, Max: 2315.00 K
#
# 2. RE MATERIALS
#
#   Generating 663 mock values for RE materials...
#   Completed after 4 iteration(s)
#   Mean: 231.33 K, Std: 215.84 K
#   Min: 0.17 K, Max: 1361.00 K
#
# 3. RE-FREE MATERIALS
#
#   Generating 855 mock values for RE-free materials...
#   Completed after 4 iteration(s)
#   Mean: 432.35 K, Std: 350.46 K
#   Min: 0.00 K, Max: 2455.00 K
#
# ============================================================
# COMBINING REAL AND MOCK DATA
# ============================================================
#
# Updating Tc_exp with augmented values where missing:
#   Updated RE-free compounds
#   Updated RE compounds
# ✓ All original Tc_exp values preserved correctly
# Total samples with valid Tc_exp: 18996
#
# ============================================================
# CALCULATING TEMPERATURE DELTAS
# ============================================================
# Main delta calculated using augmented Tc_exp values
#
# ============================================================
# GENERATING DELTA DISTRIBUTION PLOTS
# ============================================================
# Using 1383 bins for histograms
#   Saved: deltas_combined.png
#   Saved: deltas_re_free_and_re.png
#
# ============================================================
# SAVING AUGMENTED DATASETS
# ============================================================
#   Saved filtered original All dataset: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_all.csv
#     Samples: 839
#   Saved filtered original RE dataset: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_RE.csv
#     Samples: 547
#   Saved filtered original RE-free dataset: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_RE_Free.csv
#     Samples: 292
#   Saved All dataset: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_all.csv
#     Samples: 2474
#   Saved RE dataset: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_RE.csv
#     Samples: 1261
#   Saved RE-free dataset: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_RE_Free.csv
#     Samples: 1213
#
# Creating embedding-ready datasets based on use_for_emb == True
#   Original filtered embedding-compatible samples (All): 764
#   Saved original filtered All embedding dataset: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_all_emb.csv
#     Samples: 764
#   Saved original filtered RE embedding dataset: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_RE_emb.csv
#     Samples: 507
#   Saved original filtered RE-free embedding dataset: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_RE_Free_emb.csv
#     Samples: 257
#   Augmented embedding-compatible samples (All): 2013
#   Saved augmented All embedding dataset: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_all_emb.csv
#     Samples: 2013
#   Saved augmented RE embedding dataset: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_RE_emb.csv
#     Samples: 1083
#   Saved augmented RE-free embedding dataset: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_RE_Free_emb.csv
#     Samples: 930
#
# ============================================================
# AUGMENTATION SUMMARY (FROM OUTPUT FILES)
# ============================================================
#
# Reading original dataset files...
#   All: 839 samples
#   RE: 547 samples
#   RE-free: 292 samples
#   All (emb): 764 samples
#   RE (emb): 507 samples
#   RE-free (emb): 257 samples
#
# Reading augmented dataset files...
#   All: 2474 samples
#   RE: 1261 samples
#   RE-free: 1213 samples
#   All (emb): 2013 samples
#   RE (emb): 1083 samples
#   RE-free (emb): 930 samples
#
# ============================================================
# STATISTICAL DISTRIBUTION TESTS: ORIGINAL VS AUGMENTED
# ============================================================
# Performing Kolmogorov-Smirnov tests to verify augmentation quality
# Null hypothesis: The original and augmented distributions are the same
# Alternative hypothesis: The distributions are different
#
# 1. RE DATASET COMPARISON
#   Original RE samples: 547
#   Augmented RE samples: 1261
#   KS statistic: 0.0158
#   p-value: 0.99995880
#   Result: Fail to reject null hypothesis (p >= 0.05)
#   The augmented RE delta distribution is not significantly different from the original.
#   This suggests the augmentation maintained the statistical properties of the RE dataset.
#   Original RE: mean = 2.20 K, std = 47.29 K
#   Augmented RE: mean = 2.86 K, std = 48.71 K
#
# 2. RE-FREE DATASET COMPARISON
#   Original RE-free samples: 292
#   Augmented RE-free samples: 1213
#   KS statistic: 0.0332
#   p-value: 0.94858011
#   Result: Fail to reject null hypothesis (p >= 0.05)
#   The augmented RE-free delta distribution is not significantly different from the original.
#   This suggests the augmentation maintained the statistical properties of the RE-free dataset.
#   Original RE-free: mean = -18.69 K, std = 126.22 K
#   Augmented RE-free: mean = -9.08 K, std = 112.92 K
#
# ============================================================
# DATASET SIZE SUMMARY
# ============================================================
#
# Dataset              Original        Augmented
# --------------------------------------------------
# All                  839             2474
# RE                   547             1261
# RE-free              292             1213
#
# Embedding Dataset    Original        Augmented
# --------------------------------------------------
# All (emb)            764             2013
# RE (emb)             507             1083
# RE-free (emb)        257             930
#
# ============================================================
# AUGMENTATION COMPLETE!
# ============================================================

# %% [markdown]
# ### 2. Creation of embeddings

# %%
from src.create_embeddings import create_embeddings

# %%
create_embeddings()
# Out:
# script_dir /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/src
# project_root /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc
# ============================================================
# COMPOUND EMBEDDING CREATION
# ============================================================
# Random seed: 42
# Element embeddings: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/data/embeddings/element/matscholar200.json
# Data directory: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs
# Output directory: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs
#
# Loading element embeddings from /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/data/embeddings/element/matscholar200.json
# ✓ Loaded 103 element embeddings (200D)
#
# ============================================================
# LOADING EMBEDDING-READY DATASETS
# ============================================================
# Loading All_orig dataset from Pairs_all_emb.csv...
# ✓ Loaded All_orig: 764 samples
# Loading RE_orig dataset from Pairs_RE_emb.csv...
# ✓ Loaded RE_orig: 507 samples
# Loading RE-free_orig dataset from Pairs_RE_Free_emb.csv...
# ✓ Loaded RE-free_orig: 257 samples
# Loading All_aug dataset from Augm_all_emb.csv...
# ✓ Loaded All_aug: 2013 samples
# Loading RE_aug dataset from Augm_RE_emb.csv...
# ✓ Loaded RE_aug: 1083 samples
# Loading RE-free_aug dataset from Augm_RE_Free_emb.csv...
# ✓ Loaded RE-free_aug: 930 samples
#
# ============================================================
# Processing All_orig
# ============================================================
# Total samples: 764
# ✓ CompositionData initialized
# Creating embeddings using element-abundance weighted sum...
#   Progress: 700/764
# ✓ Successfully created embeddings: 764/764
#
# ============================================================
# Creating t-SNE visualization for All_orig
# ============================================================
# Samples with valid embeddings: 764
# Embeddings shape: (764, 200)
# Unique majority elements: 43
# Running t-SNE (perplexity=30, random_state=42)...
# ✓ t-SNE complete
# ✓ Saved visualization: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots/tsne_all_orig_majority_element.png
# ✓ Saved Tc_delta visualization: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots/tsne_all_orig_tc_delta.png
# ✓ Saved pickle: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_all_emb_w_embeddings.pkl
#
# ============================================================
# Processing RE_orig
# ============================================================
# Total samples: 507
# ✓ CompositionData initialized
# Creating embeddings using element-abundance weighted sum...
#   Progress: 500/507
# ✓ Successfully created embeddings: 507/507
#
# ============================================================
# Creating t-SNE visualization for RE_orig
# ============================================================
# Samples with valid embeddings: 507
# Embeddings shape: (507, 200)
# Unique majority elements: 30
# Running t-SNE (perplexity=30, random_state=42)...
# ✓ t-SNE complete
# ✓ Saved visualization: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots/tsne_re_orig_majority_element.png
# ✓ Saved Tc_delta visualization: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots/tsne_re_orig_tc_delta.png
# ✓ Saved pickle: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_RE_emb_w_embeddings.pkl
#
# ============================================================
# Processing RE-free_orig
# ============================================================
# Total samples: 257
# ✓ CompositionData initialized
# Creating embeddings using element-abundance weighted sum...
#   Progress: 200/257
# ✓ Successfully created embeddings: 257/257
#
# ============================================================
# Creating t-SNE visualization for RE-free_orig
# ============================================================
# Samples with valid embeddings: 257
# Embeddings shape: (257, 200)
# Unique majority elements: 28
# Running t-SNE (perplexity=30, random_state=42)...
# ✓ t-SNE complete
# ✓ Saved visualization: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots/tsne_re-free_orig_majority_element.png
# ✓ Saved Tc_delta visualization: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots/tsne_re-free_orig_tc_delta.png
# ✓ Saved pickle: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_RE_Free_emb_w_embeddings.pkl
#
# ============================================================
# Processing All_aug
# ============================================================
# Total samples: 2013
# ✓ CompositionData initialized
# Creating embeddings using element-abundance weighted sum...
#   Progress: 2000/2013
# ✓ Successfully created embeddings: 2013/2013
#
# ============================================================
# Creating t-SNE visualization for All_aug
# ============================================================
# Samples with valid embeddings: 2013
# Embeddings shape: (2013, 200)
# Unique majority elements: 61
# Running t-SNE (perplexity=30, random_state=42)...
# ✓ t-SNE complete
# ✓ Saved visualization: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots/tsne_all_aug_majority_element.png
# ✓ Saved Tc_delta visualization: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots/tsne_all_aug_tc_delta.png
# ✓ Saved pickle: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_all_emb_w_embeddings.pkl
#
# ============================================================
# Processing RE_aug
# ============================================================
# Total samples: 1083
# ✓ CompositionData initialized
# Creating embeddings using element-abundance weighted sum...
#   Progress: 1000/1083
# ✓ Successfully created embeddings: 1083/1083
#
# ============================================================
# Creating t-SNE visualization for RE_aug
# ============================================================
# Samples with valid embeddings: 1083
# Embeddings shape: (1083, 200)
# Unique majority elements: 40
# Running t-SNE (perplexity=30, random_state=42)...
# ✓ t-SNE complete
# ✓ Saved visualization: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots/tsne_re_aug_majority_element.png
# ✓ Saved Tc_delta visualization: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots/tsne_re_aug_tc_delta.png
# ✓ Saved pickle: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_RE_emb_w_embeddings.pkl
#
# ============================================================
# Processing RE-free_aug
# ============================================================
# Total samples: 930
# ✓ CompositionData initialized
# Creating embeddings using element-abundance weighted sum...
#   Progress: 900/930
# ✓ Successfully created embeddings: 930/930
#
# ============================================================
# Creating t-SNE visualization for RE-free_aug
# ============================================================
# Samples with valid embeddings: 930
# Embeddings shape: (930, 200)
# Unique majority elements: 46
# Running t-SNE (perplexity=30, random_state=42)...
# ✓ t-SNE complete
# ✓ Saved visualization: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots/tsne_re-free_aug_majority_element.png
# ✓ Saved Tc_delta visualization: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots/tsne_re-free_aug_tc_delta.png
# ✓ Saved pickle: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_RE_Free_emb_w_embeddings.pkl
#
# ============================================================
# EMBEDDING CREATION SUMMARY
# ============================================================
#
# Dataset                             Total   With Emb    % Valid
# ------------------------------------------------------------
# All_orig                              764        764     100.0%
# RE_orig                               507        507     100.0%
# RE-free_orig                          257        257     100.0%
# All_aug                              2013       2013     100.0%
# RE_aug                               1083       1083     100.0%
# RE-free_aug                           930        930     100.0%
#
# ============================================================
# OUTPUTS
# ============================================================
# Embeddings (PKL):   /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs
# Visualizations:     /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/embeddings_tsne_plots
# ============================================================
#
# ✓ Embedding creation complete!

# %% [markdown]
# ### 3. Compress embeddings with PCA

# %%
from src.compress_embedding_PCA import compress_embeddings_PCA

# %%
compress_embeddings_PCA()
# Out:
# ============================================================
# PCA EMBEDDING COMPRESSION PIPELINE
# ============================================================
# Random seed: 42
# Input directory: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs
# Output directory: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs
#
#
# ============================================================
# PROCESSING DATASET: All_orig
# ============================================================
# Input file: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_all_emb_w_embeddings.pkl
#   Loaded 764 samples
#   Adding PCA components: [8, 16, 32]
#
# ============================================================
# COMPRESSING EMBEDDINGS WITH PCA
# ============================================================
# Original embeddings shape: (764, 200)
#
# Creating PCA compressions:
#
#   Fitting PCA with 8 components...
#   ✓ Explained variance: 0.7833 (78.33%)
#   ✓ Added column: comp_emb_pca_8_components
#
#   Fitting PCA with 16 components...
#   ✓ Explained variance: 0.8996 (89.96%)
#   ✓ Added column: comp_emb_pca_16_components
#
#   Fitting PCA with 32 components...
#   ✓ Explained variance: 0.9776 (97.76%)
#   ✓ Added column: comp_emb_pca_32_components
#
# ✓ Saved: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_all_emb_w_embeddings_PCA.pkl
#   Samples: 764
#   Columns: 12
#
#   Embedding columns:
#     - use_for_emb: ()
#     - compound_embedding: (200,)
#     - comp_emb_pca_8_components: (8,)
#     - comp_emb_pca_16_components: (16,)
#     - comp_emb_pca_32_components: (32,)
#
# ============================================================
# SUMMARY
# ============================================================
#
# Dataset Statistics:
#   Total samples: 764
#   Paired samples (Tc_sim & Tc_exp): 764
#   With embeddings: 764
#   Rare-earth containing: 507
#   Rare-earth free: 257
#
# Embedding Columns:
#   comp_emb_pca_16_components: 764 non-null
#   comp_emb_pca_32_components: 764 non-null
#   comp_emb_pca_8_components: 764 non-null
#   compound_embedding: 764 non-null
#   use_for_emb: 764 non-null
#
# ============================================================
#
# ============================================================
# PROCESSING DATASET: RE_orig
# ============================================================
# Input file: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_RE_emb_w_embeddings.pkl
#   Loaded 507 samples
#   Adding PCA components: [8, 16, 32]
#
# ============================================================
# COMPRESSING EMBEDDINGS WITH PCA
# ============================================================
# Original embeddings shape: (507, 200)
#
# Creating PCA compressions:
#
#   Fitting PCA with 8 components...
#   ✓ Explained variance: 0.8274 (82.74%)
#   ✓ Added column: comp_emb_pca_8_components
#
#   Fitting PCA with 16 components...
#   ✓ Explained variance: 0.9298 (92.98%)
#   ✓ Added column: comp_emb_pca_16_components
#
#   Fitting PCA with 32 components...
#   ✓ Explained variance: 0.9915 (99.15%)
#   ✓ Added column: comp_emb_pca_32_components
#
# ✓ Saved: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_RE_emb_w_embeddings_PCA.pkl
#   Samples: 507
#   Columns: 12
#
#   Embedding columns:
#     - use_for_emb: ()
#     - compound_embedding: (200,)
#     - comp_emb_pca_8_components: (8,)
#     - comp_emb_pca_16_components: (16,)
#     - comp_emb_pca_32_components: (32,)
#
# ============================================================
# SUMMARY
# ============================================================
#
# Dataset Statistics:
#   Total samples: 507
#   Paired samples (Tc_sim & Tc_exp): 507
#   With embeddings: 507
#   Rare-earth containing: 507
#   Rare-earth free: 0
#
# Embedding Columns:
#   comp_emb_pca_16_components: 507 non-null
#   comp_emb_pca_32_components: 507 non-null
#   comp_emb_pca_8_components: 507 non-null
#   compound_embedding: 507 non-null
#   use_for_emb: 507 non-null
#
# ============================================================
#
# ============================================================
# PROCESSING DATASET: RE-free_orig
# ============================================================
# Input file: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_RE_Free_emb_w_embeddings.pkl
#   Loaded 257 samples
#   Adding PCA components: [8, 16, 32]
#
# ============================================================
# COMPRESSING EMBEDDINGS WITH PCA
# ============================================================
# Original embeddings shape: (257, 200)
#
# Creating PCA compressions:
#
#   Fitting PCA with 8 components...
#   ✓ Explained variance: 0.7790 (77.90%)
#   ✓ Added column: comp_emb_pca_8_components
#
#   Fitting PCA with 16 components...
#   ✓ Explained variance: 0.9137 (91.37%)
#   ✓ Added column: comp_emb_pca_16_components
#
#   Fitting PCA with 32 components...
#   ✓ Explained variance: 0.9929 (99.29%)
#   ✓ Added column: comp_emb_pca_32_components
#
# ✓ Saved: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_RE_Free_emb_w_embeddings_PCA.pkl
#   Samples: 257
#   Columns: 12
#
#   Embedding columns:
#     - use_for_emb: ()
#     - compound_embedding: (200,)
#     - comp_emb_pca_8_components: (8,)
#     - comp_emb_pca_16_components: (16,)
#     - comp_emb_pca_32_components: (32,)
#
# ============================================================
# SUMMARY
# ============================================================
#
# Dataset Statistics:
#   Total samples: 257
#   Paired samples (Tc_sim & Tc_exp): 257
#   With embeddings: 257
#   Rare-earth containing: 0
#   Rare-earth free: 257
#
# Embedding Columns:
#   comp_emb_pca_16_components: 257 non-null
#   comp_emb_pca_32_components: 257 non-null
#   comp_emb_pca_8_components: 257 non-null
#   compound_embedding: 257 non-null
#   use_for_emb: 257 non-null
#
# ============================================================
#
# ============================================================
# PROCESSING DATASET: All_aug
# ============================================================
# Input file: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_all_emb_w_embeddings.pkl
#   Loaded 2013 samples
#   Adding PCA components: [8, 16, 32]
#
# ============================================================
# COMPRESSING EMBEDDINGS WITH PCA
# ============================================================
# Original embeddings shape: (2013, 200)
#
# Creating PCA compressions:
#
#   Fitting PCA with 8 components...
#   ✓ Explained variance: 0.7567 (75.67%)
#   ✓ Added column: comp_emb_pca_8_components
#
#   Fitting PCA with 16 components...
#   ✓ Explained variance: 0.8767 (87.67%)
#   ✓ Added column: comp_emb_pca_16_components
#
#   Fitting PCA with 32 components...
#   ✓ Explained variance: 0.9659 (96.59%)
#   ✓ Added column: comp_emb_pca_32_components
#
# ✓ Saved: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_all_emb_w_embeddings_PCA.pkl
#   Samples: 2013
#   Columns: 12
#
#   Embedding columns:
#     - use_for_emb: ()
#     - compound_embedding: (200,)
#     - comp_emb_pca_8_components: (8,)
#     - comp_emb_pca_16_components: (16,)
#     - comp_emb_pca_32_components: (32,)
#
# ============================================================
# SUMMARY
# ============================================================
#
# Dataset Statistics:
#   Total samples: 2013
#   Paired samples (Tc_sim & Tc_exp): 764
#   With embeddings: 2013
#   Rare-earth containing: 1083
#   Rare-earth free: 930
#
# Embedding Columns:
#   comp_emb_pca_16_components: 2013 non-null
#   comp_emb_pca_32_components: 2013 non-null
#   comp_emb_pca_8_components: 2013 non-null
#   compound_embedding: 2013 non-null
#   use_for_emb: 2013 non-null
#
# ============================================================
#
# ============================================================
# PROCESSING DATASET: RE_aug
# ============================================================
# Input file: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_RE_emb_w_embeddings.pkl
#   Loaded 1083 samples
#   Adding PCA components: [8, 16, 32]
#
# ============================================================
# COMPRESSING EMBEDDINGS WITH PCA
# ============================================================
# Original embeddings shape: (1083, 200)
#
# Creating PCA compressions:
#
#   Fitting PCA with 8 components...
#   ✓ Explained variance: 0.8209 (82.09%)
#   ✓ Added column: comp_emb_pca_8_components
#
#   Fitting PCA with 16 components...
#   ✓ Explained variance: 0.9214 (92.14%)
#   ✓ Added column: comp_emb_pca_16_components
#
#   Fitting PCA with 32 components...
#   ✓ Explained variance: 0.9862 (98.62%)
#   ✓ Added column: comp_emb_pca_32_components
#
# ✓ Saved: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_RE_emb_w_embeddings_PCA.pkl
#   Samples: 1083
#   Columns: 12
#
#   Embedding columns:
#     - use_for_emb: ()
#     - compound_embedding: (200,)
#     - comp_emb_pca_8_components: (8,)
#     - comp_emb_pca_16_components: (16,)
#     - comp_emb_pca_32_components: (32,)
#
# ============================================================
# SUMMARY
# ============================================================
#
# Dataset Statistics:
#   Total samples: 1083
#   Paired samples (Tc_sim & Tc_exp): 507
#   With embeddings: 1083
#   Rare-earth containing: 1083
#   Rare-earth free: 0
#
# Embedding Columns:
#   comp_emb_pca_16_components: 1083 non-null
#   comp_emb_pca_32_components: 1083 non-null
#   comp_emb_pca_8_components: 1083 non-null
#   compound_embedding: 1083 non-null
#   use_for_emb: 1083 non-null
#
# ============================================================
#
# ============================================================
# PROCESSING DATASET: RE-free_aug
# ============================================================
# Input file: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_RE_Free_emb_w_embeddings.pkl
#   Loaded 930 samples
#   Adding PCA components: [8, 16, 32]
#
# ============================================================
# COMPRESSING EMBEDDINGS WITH PCA
# ============================================================
# Original embeddings shape: (930, 200)
#
# Creating PCA compressions:
#
#   Fitting PCA with 8 components...
#   ✓ Explained variance: 0.7294 (72.94%)
#   ✓ Added column: comp_emb_pca_8_components
#
#   Fitting PCA with 16 components...
#   ✓ Explained variance: 0.8748 (87.48%)
#   ✓ Added column: comp_emb_pca_16_components
#
#   Fitting PCA with 32 components...
#   ✓ Explained variance: 0.9788 (97.88%)
#   ✓ Added column: comp_emb_pca_32_components
#
# ✓ Saved: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_RE_Free_emb_w_embeddings_PCA.pkl
#   Samples: 930
#   Columns: 12
#
#   Embedding columns:
#     - use_for_emb: ()
#     - compound_embedding: (200,)
#     - comp_emb_pca_8_components: (8,)
#     - comp_emb_pca_16_components: (16,)
#     - comp_emb_pca_32_components: (32,)
#
# ============================================================
# SUMMARY
# ============================================================
#
# Dataset Statistics:
#   Total samples: 930
#   Paired samples (Tc_sim & Tc_exp): 257
#   With embeddings: 930
#   Rare-earth containing: 0
#   Rare-earth free: 930
#
# Embedding Columns:
#   comp_emb_pca_16_components: 930 non-null
#   comp_emb_pca_32_components: 930 non-null
#   comp_emb_pca_8_components: 930 non-null
#   compound_embedding: 930 non-null
#   use_for_emb: 930 non-null
#
# ============================================================
#
# ✓ PCA compression complete for all available datasets!
#
# You can now run the training pipeline with:
#   python src/training_original_emb.py
#   python src/training_augmented_emb.py
#
# NOTE: The compressed embeddings are saved in new files with _PCA.pkl suffix.

# %% [markdown]
# ### 4. Model Training

# %% [markdown]
# #### 4.1 Original Dataset
# Train ML models on existing materials where both experimental and simulated values have been recorded.

# %%
from src.training_original import training_original

# %%
training_original()
# Out:
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/juliacall/__init__.py:61: UserWarning: torch was imported before juliacall. This may cause a segfault. To avoid this, import juliacall before importing torch. For updates, see https://github.com/pytorch/pytorch/issues/78829.
#   warnings.warn(
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython
# ================================================================================
# ORIGINAL DATA TRAINING (NO EMBEDDINGS)
# ================================================================================
#
# ------------------------------------------------------------
# Training on All-Pairs dataset type: all
# ------------------------------------------------------------
#
# ============================================================
# Training Symbolic Regression: All-Pairs
# ============================================================
# Loading original (pairs) data for all dataset from: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_all.csv
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 839
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 671
# Test samples: 168
#
# Fitting PySR model...
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.439e+03  0.000e+00  y = x₀
# 3           6.139e+03  2.364e-02  y = x₀ * 0.95099
# 5           5.986e+03  1.232e-02  y = (x₀ * 0.91041) + 18.939
# 9           5.977e+03  2.462e-04  y = (((x₀ * -3.7008e-05) + 0.94143) * x₀) + 15.25
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#
# Best equation: x0 * 0.95098996
#
# Test Metrics:
#   R² = 0.8408
#   RMSE = 96.76 K
#   MAE = 39.73 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Pairs_SR.png
#   Symbolic Regression - R²: 0.8408
#
# ============================================================
# Training Linear Models: All-Pairs
# Using only Tc_sim (no embedding)
# ============================================================
# Loading original (pairs) data for all dataset from: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_all.csv
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 839
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 671
# Test samples: 168
# Feature dimensions: 1
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.8464
# Test RMSE = 95.06 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Pairs_lasso_no_emb.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.8462
# Test RMSE = 95.10 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Pairs_ridge_no_emb.png
#
# --- Training LINEAR ---
# Best params: {}
# Test R² = 0.8462
# Test RMSE = 95.13 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Pairs_linear_no_emb.png
#   Linear - Best model: LASSO, R²: 0.8464
#
# ============================================================
# Training Random Forest: All-Pairs
# Using only Tc_sim (no embedding)
# ============================================================
# Loading original (pairs) data for all dataset from: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_all.csv
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 839
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 671
# Test samples: 168
# Feature dimensions: 1
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 100, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': None, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.8278
#   RMSE = 100.63 K
#   MAE = 44.02 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Pairs_RF_no_emb.png
#   Random Forest - R²: 0.8278
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: All-Pairs
# Using only Tc_sim (no embedding)
# ============================================================
# Loading original (pairs) data for all dataset from: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_all.csv
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 839
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 671
# Test samples: 168
# Feature dimensions: 1
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 9778.5805, Val Loss: 8211.3833
# Epoch [40/200], Train Loss: 10677.3335, Val Loss: 8047.4371
# Epoch [60/200], Train Loss: 9043.9371, Val Loss: 7924.4757
# Early stopping at epoch 64
#
# Final Test Metrics:
#   R² = 0.8481
#   RMSE = 94.51 K
#   MAE = 40.59 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Pairs_MLP_no_emb.png
#   FCNN/MLP - R²: 0.8481
#
# ------------------------------------------------------------
# Training on RE-Pairs dataset type: re
# ------------------------------------------------------------
#
# ============================================================
# Training Symbolic Regression: RE-Pairs
# ============================================================
# Loading original (pairs) data for re dataset from: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_RE.csv
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 547
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 437
# Test samples: 110
#
# Fitting PySR model...
#   - outputs/20260113_164301_pusfLO/hall_of_fame.csv
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.150e+03  0.000e+00  y = x₀
# 3           2.105e+03  1.053e-02  y = x₀ * 0.97406
# 5           2.031e+03  1.773e-02  y = (x₀ + 13.541) * 0.938
# 9           2.028e+03  4.279e-04  y = (((x₀ * 2.868e-05) + 0.91783) * x₀) + 14.632
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#
# Best equation: (x0 + 13.540815) * 0.9379961
#
# Test Metrics:
#   R² = 0.9130
#   RMSE = 52.23 K
#   MAE = 21.27 K
# [ Info: Results saved to:
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_SR.png
#   Symbolic Regression - R²: 0.9130
#
# ============================================================
# Training Linear Models: RE-Pairs
# Using only Tc_sim (no embedding)
# ============================================================
# Loading original (pairs) data for re dataset from: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_RE.csv
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 547
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 437
# Test samples: 110
# Feature dimensions: 1
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.9122
# Test RMSE = 52.46 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_lasso_no_emb.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.9127
# Test RMSE = 52.32 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_ridge_no_emb.png
#
# --- Training LINEAR ---
# Best params: {}
# Test R² = 0.9129
# Test RMSE = 52.23 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_linear_no_emb.png
#   Linear - Best model: LINEAR, R²: 0.9129
#
# ============================================================
# Training Random Forest: RE-Pairs
# Using only Tc_sim (no embedding)
# ============================================================
# Loading original (pairs) data for re dataset from: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_RE.csv
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 547
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 437
# Test samples: 110
# Feature dimensions: 1
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.9000
#   RMSE = 55.97 K
#   MAE = 24.41 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_RF_no_emb.png
#   Random Forest - R²: 0.9000
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: RE-Pairs
# Using only Tc_sim (no embedding)
# ============================================================
# Loading original (pairs) data for re dataset from: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_RE.csv
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 547
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 437
# Test samples: 110
# Feature dimensions: 1
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 4256.6038, Val Loss: 3047.6290
# Epoch [40/200], Train Loss: 4352.8927, Val Loss: 2669.6087
# Early stopping at epoch 59
#
# Final Test Metrics:
#   R² = 0.9144
#   RMSE = 51.81 K
#   MAE = 21.23 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_MLP_no_emb.png
#   FCNN/MLP - R²: 0.9144
#
# ------------------------------------------------------------
# Training on RE-Free-Pairs dataset type: re-free
# ------------------------------------------------------------
#
# ============================================================
# Training Symbolic Regression: RE-Free-Pairs
# ============================================================
# Loading original (pairs) data for re-free dataset from: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_RE_Free.csv
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 292
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 233
# Test samples: 59
#
# Fitting PySR model...
#   - outputs/20260113_164333_YtRXCW/hall_of_fame.csv
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.554e+04  0.000e+00  y = x₀
# 3           1.458e+04  3.146e-02  y = x₀ * 0.93613
# 5           1.408e+04  1.708e-02  y = (x₀ * 0.86204) + 42.412
# 9           1.407e+04  -0.000e+00  y = (((x₀ * 2.4203e-05) + 0.83764) * x₀) + 46.755
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#
# Best equation: x0 * 0.9361337
#
# Test Metrics:
#   R² = 0.7890
#   RMSE = 130.65 K
#   MAE = 71.14 K
# [ Info: Results saved to:
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_SR.png
#   Symbolic Regression - R²: 0.7890
#
# ============================================================
# Training Linear Models: RE-Free-Pairs
# Using only Tc_sim (no embedding)
# ============================================================
# Loading original (pairs) data for re-free dataset from: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_RE_Free.csv
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 292
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 233
# Test samples: 59
# Feature dimensions: 1
#
# --- Training LASSO ---
# Best params: {'alpha': 0.0001, 'max_iter': 20000}
# Test R² = 0.7887
# Test RMSE = 130.74 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_lasso_no_emb.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 0.1}
# Test R² = 0.7887
# Test RMSE = 130.74 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_ridge_no_emb.png
#
# --- Training LINEAR ---
# Best params: {}
# Test R² = 0.7887
# Test RMSE = 130.74 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_linear_no_emb.png
#   Linear - Best model: LINEAR, R²: 0.7887
#
# ============================================================
# Training Random Forest: RE-Free-Pairs
# Using only Tc_sim (no embedding)
# ============================================================
# Loading original (pairs) data for re-free dataset from: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_RE_Free.csv
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 292
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 233
# Test samples: 59
# Feature dimensions: 1
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 50, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': None, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.7699
#   RMSE = 136.46 K
#   MAE = 81.82 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_RF_no_emb.png
#   Random Forest - R²: 0.7699
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: RE-Free-Pairs
# Using only Tc_sim (no embedding)
# ============================================================
# Loading original (pairs) data for re-free dataset from: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_RE_Free.csv
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 292
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 233
# Test samples: 59
# Feature dimensions: 1
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 22850.0625, Val Loss: 25505.1826
# Epoch [40/200], Train Loss: 17872.8504, Val Loss: 18728.1030
# Epoch [60/200], Train Loss: 18207.1360, Val Loss: 18304.6975
# Epoch [80/200], Train Loss: 21457.4829, Val Loss: 18041.4026
# Early stopping at epoch 86
#
# Final Test Metrics:
#   R² = 0.7920
#   RMSE = 129.74 K
#   MAE = 76.26 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_MLP_no_emb.png
#   FCNN/MLP - R²: 0.7920
#
# ================================================================================
# ORIGINAL DATA (NO EMBEDDINGS) - MODEL COMPARISON
# ================================================================================
#       Model_Family  Model       Dataset       R2       RMSE       MAE
#                MLP   FCNN     All-Pairs 0.848144  94.508227 40.589001
#             Linear  LASSO     All-Pairs 0.846373  95.057771 41.092637
# SymbolicRegression   PySR     All-Pairs 0.840829  96.757542 39.731461
#       RandomForest     RF     All-Pairs 0.827818 100.634554 44.019236
#                MLP   FCNN RE-Free-Pairs 0.791961 129.738997 76.258630
# SymbolicRegression   PySR RE-Free-Pairs 0.789040 130.646532 71.138735
#             Linear LINEAR RE-Free-Pairs 0.788735 130.741098 72.643931
#       RandomForest     RF RE-Free-Pairs 0.769854 136.458333 81.817193
#                MLP   FCNN      RE-Pairs 0.914373  51.805337 21.233140
# SymbolicRegression   PySR      RE-Pairs 0.912953  52.233123 21.269102
#             Linear LINEAR      RE-Pairs 0.912950  52.234197 21.272112
#       RandomForest     RF      RE-Pairs 0.900039  55.973840 24.412276
# ================================================================================
# Results saved to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/original_comparison/original_models_comparison.csv
#
# ================================================================================
# BEST MODEL BY DATASET (SORTED BY R2)
# ================================================================================
# Model_Family Model       Dataset       R2       RMSE       MAE
#          MLP  FCNN      RE-Pairs 0.914373  51.805337 21.233140
#          MLP  FCNN     All-Pairs 0.848144  94.508227 40.589001
#          MLP  FCNN RE-Free-Pairs 0.791961 129.738997 76.258630
# ================================================================================
# Best models by dataset saved to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/original_comparison/original_best_by_dataset.csv
#
# R² BY DATASET AND MODEL FAMILY:
#       Dataset   Linear      MLP  RandomForest  SymbolicRegression
#     All-Pairs 0.846373 0.848144      0.827818            0.840829
# RE-Free-Pairs 0.788735 0.791961      0.769854            0.789040
#      RE-Pairs 0.912950 0.914373      0.900039            0.912953
# Pivot table saved to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/original_comparison/original_comparison_pivot.csv
#   - outputs/20260113_164344_M22D09/hall_of_fame.csv

# %% [markdown]
# #### 4.2 Orginal Dataset with embedding

# %%
from src.training_original_emb import train_original_embedding

# %%
train_original_embedding() # FIX THIS
# Out:
# ================================================================================
# ORIGINAL DATA TRAINING WITH EMBEDDINGS
# ================================================================================
# Found PCA-enriched embedding file for all: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_all_emb_w_embeddings_PCA.pkl
# Found PCA-enriched embedding file for re: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_RE_emb_w_embeddings_PCA.pkl
# Found PCA-enriched embedding file for re-free: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_RE_Free_emb_w_embeddings_PCA.pkl
# Loading embeddings file for 'all': /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_all_emb_w_embeddings_PCA.pkl
# Successfully loaded 764 samples for 'all'
# Filtered to pairs only: 764 -> 764 samples
# Available embedding columns for all: ['use_for_emb', 'compound_embedding', 'comp_emb_pca_8_components', 'comp_emb_pca_16_components', 'comp_emb_pca_32_components']
# Available embedding columns: ['use_for_emb', 'compound_embedding', 'comp_emb_pca_8_components', 'comp_emb_pca_16_components', 'comp_emb_pca_32_components']
#
# ============================================================
# DATASET: All-Pairs (type: all)
# ============================================================
#
# --------------------------------------------------
# Training with embedding: raw_200D
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: All-Pairs
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 764
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 611
# Test samples: 153
# Feature dimensions: 201
#
# --- Training LASSO ---
# Best params: {'alpha': 10, 'max_iter': 20000}
# Test R² = 0.7870
# Test RMSE = 111.77 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Pairs_lasso_None.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 10}
# Test R² = 0.7955
# Test RMSE = 109.52 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Pairs_ridge_None.png
#   Linear - Best model: RIDGE, R²: 0.7955
#
# ============================================================
# Training Random Forest: All-Pairs
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 764
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 611
# Test samples: 153
# Feature dimensions: 201
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.7880
#   RMSE = 111.51 K
#   MAE = 45.17 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Pairs_RF_None.png
#   Random Forest - R²: 0.7880
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: All-Pairs
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 764
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 611
# Test samples: 153
# Feature dimensions: 201
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 16702.0979, Val Loss: 17650.0677
# Epoch [40/200], Train Loss: 7152.2708, Val Loss: 12076.1661
# Epoch [60/200], Train Loss: 5579.9935, Val Loss: 11585.8589
# Early stopping at epoch 66
#
# Final Test Metrics:
#   R² = 0.8046
#   RMSE = 107.07 K
#   MAE = 58.29 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Pairs_MLP_None.png
#   FCNN/MLP - R²: 0.8046
#
# --------------------------------------------------
# Training with embedding: pca_16
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: All-Pairs
# Using embedding: pca_16
# ============================================================
# Training samples: 611
# Test samples: 153
# Feature dimensions: 17
#
# --- Training LASSO ---
# Best params: {'alpha': 10, 'max_iter': 20000}
# Test R² = 0.7861
# Test RMSE = 112.01 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Pairs_lasso_pca_16.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 10}
# Test R² = 0.7879
# Test RMSE = 111.53 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Pairs_ridge_pca_16.png
#   Linear - Best model: RIDGE, R²: 0.7879
#
# ============================================================
# Training Random Forest: All-Pairs
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 611
# Test samples: 153
# Feature dimensions: 17
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.7855
#   RMSE = 112.17 K
#   MAE = 43.50 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Pairs_RF_pca_16.png
#   Random Forest - R²: 0.7855
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: All-Pairs
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 611
# Test samples: 153
# Feature dimensions: 17
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 8827.2398, Val Loss: 12587.8342
# Epoch [40/200], Train Loss: 7169.9065, Val Loss: 12710.0338
# Early stopping at epoch 41
#
# Final Test Metrics:
#   R² = 0.7863
#   RMSE = 111.97 K
#   MAE = 63.77 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Pairs_MLP_pca_16.png
#   FCNN/MLP - R²: 0.7863
#
# --------------------------------------------------
# Training with embedding: pca_32
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: All-Pairs
# Using embedding: pca_32
# ============================================================
# Training samples: 611
# Test samples: 153
# Feature dimensions: 33
#
# --- Training LASSO ---
# Best params: {'alpha': 10, 'max_iter': 20000}
# Test R² = 0.7861
# Test RMSE = 112.01 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Pairs_lasso_pca_32.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 10}
# Test R² = 0.7908
# Test RMSE = 110.76 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Pairs_ridge_pca_32.png
#   Linear - Best model: RIDGE, R²: 0.7908
#
# ============================================================
# Training Random Forest: All-Pairs
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 611
# Test samples: 153
# Feature dimensions: 33
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': None, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.7834
#   RMSE = 112.72 K
#   MAE = 43.82 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Pairs_RF_pca_32.png
#   Random Forest - R²: 0.7834
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: All-Pairs
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 611
# Test samples: 153
# Feature dimensions: 33
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 6566.6746, Val Loss: 12498.6858
# Epoch [40/200], Train Loss: 5706.0950, Val Loss: 12966.0737
# Early stopping at epoch 41
#
# Final Test Metrics:
#   R² = 0.7855
#   RMSE = 112.16 K
#   MAE = 66.81 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Pairs_MLP_pca_32.png
#   FCNN/MLP - R²: 0.7855
#
# --------------------------------------------------
# Training with embedding: pca_8
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: All-Pairs
# Using embedding: pca_8
# ============================================================
# Training samples: 611
# Test samples: 153
# Feature dimensions: 9
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.7858
# Test RMSE = 112.10 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Pairs_lasso_pca_8.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 10}
# Test R² = 0.7901
# Test RMSE = 110.96 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Pairs_ridge_pca_8.png
#   Linear - Best model: RIDGE, R²: 0.7901
#
# ============================================================
# Training Random Forest: All-Pairs
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 611
# Test samples: 153
# Feature dimensions: 9
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.7654
#   RMSE = 117.30 K
#   MAE = 46.39 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Pairs_RF_pca_8.png
#   Random Forest - R²: 0.7654
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: All-Pairs
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 611
# Test samples: 153
# Feature dimensions: 9
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 8218.2033, Val Loss: 12971.9531
# Epoch [40/200], Train Loss: 6708.6267, Val Loss: 12475.7464
# Early stopping at epoch 59
#
# Final Test Metrics:
#   R² = 0.7843
#   RMSE = 112.49 K
#   MAE = 58.44 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Pairs_MLP_pca_8.png
#   FCNN/MLP - R²: 0.7843
#
# --------------------------------------------------
# Training with embedding: pca_64
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: All-Pairs
# Using embedding: pca_64
# ============================================================
# Error running Linear models: Embedding column for type pca_64 not found
#
# ============================================================
# Training Random Forest: All-Pairs
# Using embedding: pca_64
# ============================================================
# Error running Random Forest: Embedding column for type pca_64 not found
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: All-Pairs
# Using embedding: pca_64
# ============================================================
# Error running FCNN/MLP: Embedding column for type pca_64 not found
#
# ============================================================
# DATASET: RE-Pairs (type: re)
# ============================================================
# Loading embeddings file for 're': /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_RE_emb_w_embeddings_PCA.pkl
# Successfully loaded 507 samples for 're'
# Filtered to pairs only: 507 -> 507 samples
# Available embedding columns for re: ['use_for_emb', 'compound_embedding', 'comp_emb_pca_8_components', 'comp_emb_pca_16_components', 'comp_emb_pca_32_components']
#
# --------------------------------------------------
# Training with embedding: raw_200D
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Pairs
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 507
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 405
# Test samples: 102
# Feature dimensions: 201
#
# --- Training LASSO ---
# Best params: {'alpha': 10, 'max_iter': 20000}
# Test R² = 0.9140
# Test RMSE = 47.23 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_lasso_None.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 10}
# Test R² = 0.9071
# Test RMSE = 49.10 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_ridge_None.png
#   Linear - Best model: LASSO, R²: 0.9140
#
# ============================================================
# Training Random Forest: RE-Pairs
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 507
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 405
# Test samples: 102
# Feature dimensions: 201
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.9289
#   RMSE = 42.94 K
#   MAE = 21.76 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_RF_None.png
#   Random Forest - R²: 0.9289
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: RE-Pairs
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 507
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 405
# Test samples: 102
# Feature dimensions: 201
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 12458.3690, Val Loss: 7415.2037
# Epoch [40/200], Train Loss: 6801.8043, Val Loss: 4135.5251
# Epoch [60/200], Train Loss: 4173.8908, Val Loss: 2493.9104
# Epoch [80/200], Train Loss: 3278.6315, Val Loss: 2111.3960
# Epoch [100/200], Train Loss: 3061.3754, Val Loss: 1974.4643
# Epoch [120/200], Train Loss: 2532.5216, Val Loss: 1690.5474
# Epoch [140/200], Train Loss: 2258.4113, Val Loss: 1722.7794
# Early stopping at epoch 140
#
# Final Test Metrics:
#   R² = 0.9340
#   RMSE = 41.38 K
#   MAE = 30.66 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_MLP_None.png
#   FCNN/MLP - R²: 0.9340
#
# --------------------------------------------------
# Training with embedding: pca_16
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Pairs
# Using embedding: pca_16
# ============================================================
# Training samples: 405
# Test samples: 102
# Feature dimensions: 17
#
# --- Training LASSO ---
# Best params: {'alpha': 10, 'max_iter': 20000}
# Test R² = 0.9137
# Test RMSE = 47.31 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_lasso_pca_16.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.9252
# Test RMSE = 44.05 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_ridge_pca_16.png
#   Linear - Best model: RIDGE, R²: 0.9252
#
# ============================================================
# Training Random Forest: RE-Pairs
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 405
# Test samples: 102
# Feature dimensions: 17
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.9075
#   RMSE = 48.98 K
#   MAE = 24.71 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_RF_pca_16.png
#   Random Forest - R²: 0.9075
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: RE-Pairs
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 405
# Test samples: 102
# Feature dimensions: 17
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 4942.3749, Val Loss: 3762.7595
# Epoch [40/200], Train Loss: 3508.2428, Val Loss: 2500.2402
# Epoch [60/200], Train Loss: 2861.7952, Val Loss: 2134.4584
# Epoch [80/200], Train Loss: 3055.9309, Val Loss: 1955.3363
# Epoch [100/200], Train Loss: 3422.5237, Val Loss: 1732.2050
# Epoch [120/200], Train Loss: 3199.2032, Val Loss: 1692.9406
# Early stopping at epoch 129
#
# Final Test Metrics:
#   R² = 0.9397
#   RMSE = 39.56 K
#   MAE = 27.71 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_MLP_pca_16.png
#   FCNN/MLP - R²: 0.9397
#
# --------------------------------------------------
# Training with embedding: pca_32
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Pairs
# Using embedding: pca_32
# ============================================================
# Training samples: 405
# Test samples: 102
# Feature dimensions: 33
#
# --- Training LASSO ---
# Best params: {'alpha': 10, 'max_iter': 20000}
# Test R² = 0.9137
# Test RMSE = 47.31 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_lasso_pca_32.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.9202
# Test RMSE = 45.51 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_ridge_pca_32.png
#   Linear - Best model: RIDGE, R²: 0.9202
#
# ============================================================
# Training Random Forest: RE-Pairs
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 405
# Test samples: 102
# Feature dimensions: 33
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.9117
#   RMSE = 47.85 K
#   MAE = 24.52 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_RF_pca_32.png
#   Random Forest - R²: 0.9117
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: RE-Pairs
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 405
# Test samples: 102
# Feature dimensions: 33
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 6323.6905, Val Loss: 6768.6212
# Epoch [40/200], Train Loss: 3682.5556, Val Loss: 4620.3279
# Epoch [60/200], Train Loss: 2535.6733, Val Loss: 4277.5704
# Epoch [80/200], Train Loss: 2563.4342, Val Loss: 4460.5341
# Early stopping at epoch 83
#
# Final Test Metrics:
#   R² = 0.8213
#   RMSE = 68.08 K
#   MAE = 39.25 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_MLP_pca_32.png
#   FCNN/MLP - R²: 0.8213
#
# --------------------------------------------------
# Training with embedding: pca_8
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Pairs
# Using embedding: pca_8
# ============================================================
# Training samples: 405
# Test samples: 102
# Feature dimensions: 9
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.9220
# Test RMSE = 44.97 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_lasso_pca_8.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.9220
# Test RMSE = 44.98 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_ridge_pca_8.png
#   Linear - Best model: LASSO, R²: 0.9220
#
# ============================================================
# Training Random Forest: RE-Pairs
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 405
# Test samples: 102
# Feature dimensions: 9
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.9028
#   RMSE = 50.20 K
#   MAE = 24.95 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_RF_pca_8.png
#   Random Forest - R²: 0.9028
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: RE-Pairs
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 405
# Test samples: 102
# Feature dimensions: 9
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 5521.2506, Val Loss: 3014.0927
# Epoch [40/200], Train Loss: 3794.8648, Val Loss: 2241.5941
# Epoch [60/200], Train Loss: 3433.0444, Val Loss: 1895.0994
# Epoch [80/200], Train Loss: 4873.1049, Val Loss: 1818.6436
# Epoch [100/200], Train Loss: 4267.5376, Val Loss: 1798.2015
# Early stopping at epoch 106
#
# Final Test Metrics:
#   R² = 0.9333
#   RMSE = 41.61 K
#   MAE = 24.02 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Pairs_MLP_pca_8.png
#   FCNN/MLP - R²: 0.9333
#
# --------------------------------------------------
# Training with embedding: pca_64
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Pairs
# Using embedding: pca_64
# ============================================================
# Error running Linear models: Embedding column for type pca_64 not found
#
# ============================================================
# Training Random Forest: RE-Pairs
# Using embedding: pca_64
# ============================================================
# Error running Random Forest: Embedding column for type pca_64 not found
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: RE-Pairs
# Using embedding: pca_64
# ============================================================
# Error running FCNN/MLP: Embedding column for type pca_64 not found
#
# ============================================================
# DATASET: RE-Free-Pairs (type: re-free)
# ============================================================
# Loading embeddings file for 're-free': /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Pairs_RE_Free_emb_w_embeddings_PCA.pkl
# Successfully loaded 257 samples for 're-free'
# Filtered to pairs only: 257 -> 257 samples
# Available embedding columns for re-free: ['use_for_emb', 'compound_embedding', 'comp_emb_pca_8_components', 'comp_emb_pca_16_components', 'comp_emb_pca_32_components']
#
# --------------------------------------------------
# Training with embedding: raw_200D
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Free-Pairs
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 257
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 205
# Test samples: 52
# Feature dimensions: 201
#
# --- Training LASSO ---
# Best params: {'alpha': 10, 'max_iter': 20000}
# Test R² = 0.7809
# Test RMSE = 128.21 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_lasso_None.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 10}
# Test R² = 0.7520
# Test RMSE = 136.39 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_ridge_None.png
#   Linear - Best model: LASSO, R²: 0.7809
#
# ============================================================
# Training Random Forest: RE-Free-Pairs
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 257
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 205
# Test samples: 52
# Feature dimensions: 201
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 50, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': None, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.7787
#   RMSE = 128.85 K
#   MAE = 83.37 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_RF_None.png
#   Random Forest - R²: 0.7787
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: RE-Free-Pairs
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 257
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 205
# Test samples: 52
# Feature dimensions: 201
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 34426.0246, Val Loss: 40439.0859
# Epoch [40/200], Train Loss: 29583.7966, Val Loss: 29149.8672
# Epoch [60/200], Train Loss: 18977.8100, Val Loss: 21761.7061
# Epoch [80/200], Train Loss: 15669.1286, Val Loss: 18099.8301
# Epoch [100/200], Train Loss: 14107.7387, Val Loss: 16194.0210
# Epoch [120/200], Train Loss: 12645.5244, Val Loss: 14997.1987
# Early stopping at epoch 135
#
# Final Test Metrics:
#   R² = 0.7972
#   RMSE = 123.35 K
#   MAE = 92.45 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_MLP_None.png
#   FCNN/MLP - R²: 0.7972
#
# --------------------------------------------------
# Training with embedding: pca_16
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Free-Pairs
# Using embedding: pca_16
# ============================================================
# Training samples: 205
# Test samples: 52
# Feature dimensions: 17
#
# --- Training LASSO ---
# Best params: {'alpha': 10, 'max_iter': 20000}
# Test R² = 0.7668
# Test RMSE = 132.27 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_lasso_pca_16.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 10}
# Test R² = 0.7698
# Test RMSE = 131.40 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_ridge_pca_16.png
#   Linear - Best model: RIDGE, R²: 0.7698
#
# ============================================================
# Training Random Forest: RE-Free-Pairs
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 205
# Test samples: 52
# Feature dimensions: 17
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 10, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.7959
#   RMSE = 123.73 K
#   MAE = 76.24 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_RF_pca_16.png
#   Random Forest - R²: 0.7959
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: RE-Free-Pairs
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 205
# Test samples: 52
# Feature dimensions: 17
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 28337.8334, Val Loss: 30248.6953
# Epoch [40/200], Train Loss: 15386.3610, Val Loss: 15651.5664
# Epoch [60/200], Train Loss: 12360.7522, Val Loss: 14639.7009
# Epoch [80/200], Train Loss: 12775.9843, Val Loss: 15156.7190
# Early stopping at epoch 92
#
# Final Test Metrics:
#   R² = 0.7846
#   RMSE = 127.11 K
#   MAE = 92.18 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_MLP_pca_16.png
#   FCNN/MLP - R²: 0.7846
#
# --------------------------------------------------
# Training with embedding: pca_32
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Free-Pairs
# Using embedding: pca_32
# ============================================================
# Training samples: 205
# Test samples: 52
# Feature dimensions: 33
#
# --- Training LASSO ---
# Best params: {'alpha': 10, 'max_iter': 20000}
# Test R² = 0.7604
# Test RMSE = 134.08 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_lasso_pca_32.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 10}
# Test R² = 0.7275
# Test RMSE = 142.96 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_ridge_pca_32.png
#   Linear - Best model: LASSO, R²: 0.7604
#
# ============================================================
# Training Random Forest: RE-Free-Pairs
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 205
# Test samples: 52
# Feature dimensions: 33
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 50, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': None, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.7764
#   RMSE = 129.52 K
#   MAE = 80.68 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_RF_pca_32.png
#   Random Forest - R²: 0.7764
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: RE-Free-Pairs
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 205
# Test samples: 52
# Feature dimensions: 33
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 22323.7363, Val Loss: 45580.0234
# Epoch [40/200], Train Loss: 13001.3047, Val Loss: 31784.9346
# Epoch [60/200], Train Loss: 9832.8226, Val Loss: 30125.0039
# Epoch [80/200], Train Loss: 9488.1433, Val Loss: 29503.7061
# Epoch [100/200], Train Loss: 12592.2731, Val Loss: 29292.7197
# Early stopping at epoch 103
#
# Final Test Metrics:
#   R² = 0.6530
#   RMSE = 161.35 K
#   MAE = 106.29 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_MLP_pca_32.png
#   FCNN/MLP - R²: 0.6530
#
# --------------------------------------------------
# Training with embedding: pca_8
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Free-Pairs
# Using embedding: pca_8
# ============================================================
# Training samples: 205
# Test samples: 52
# Feature dimensions: 9
#
# --- Training LASSO ---
# Best params: {'alpha': 10, 'max_iter': 20000}
# Test R² = 0.7586
# Test RMSE = 134.57 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_lasso_pca_8.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 10}
# Test R² = 0.7640
# Test RMSE = 133.05 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_ridge_pca_8.png
#   Linear - Best model: RIDGE, R²: 0.7640
#
# ============================================================
# Training Random Forest: RE-Free-Pairs
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 205
# Test samples: 52
# Feature dimensions: 9
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20, 'bootstrap': False}
#
# Test Metrics:
#   R² = 0.7547
#   RMSE = 135.67 K
#   MAE = 82.40 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_RF_pca_8.png
#   Random Forest - R²: 0.7547
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: RE-Free-Pairs
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 205
# Test samples: 52
# Feature dimensions: 9
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 27656.6521, Val Loss: 25420.2695
# Epoch [40/200], Train Loss: 17817.5711, Val Loss: 14697.7522
# Epoch [60/200], Train Loss: 16229.4269, Val Loss: 14084.7094
# Early stopping at epoch 68
#
# Final Test Metrics:
#   R² = 0.7874
#   RMSE = 126.29 K
#   MAE = 91.51 K
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.956e+05, tolerance: 2.424e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.493e+05, tolerance: 2.436e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.935e+05, tolerance: 2.218e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.178e+05, tolerance: 2.436e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.299e+05, tolerance: 2.456e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.663e+05, tolerance: 2.331e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.889e+05, tolerance: 2.424e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.783e+05, tolerance: 2.456e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.585e+04, tolerance: 2.436e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.437e+05, tolerance: 2.218e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.009e+05, tolerance: 2.331e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.979e+05, tolerance: 2.424e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.279e+05, tolerance: 2.456e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.517e+05, tolerance: 2.331e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.534e+05, tolerance: 2.218e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.718e+05, tolerance: 2.424e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.358e+05, tolerance: 2.436e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.956e+05, tolerance: 2.218e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.447e+05, tolerance: 2.424e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.499e+03, tolerance: 2.218e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.011e+05, tolerance: 2.456e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.499e+03, tolerance: 2.456e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.943e+04, tolerance: 2.331e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.522e+05, tolerance: 2.331e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.050e+04, tolerance: 2.424e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.303e+04, tolerance: 2.331e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.781e+03, tolerance: 2.456e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.534e+04, tolerance: 1.083e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.283e+05, tolerance: 1.054e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.402e+04, tolerance: 1.021e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.042e+04, tolerance: 1.083e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.498e+05, tolerance: 1.021e+03
#   model = cd_fast.enet_coordinate_descent(
# ...
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.567e+05, tolerance: 1.013e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.075e+05, tolerance: 9.853e+02
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.812e+05, tolerance: 9.835e+02
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.219e+05, tolerance: 1.039e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.975e+05, tolerance: 9.835e+02
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.692e+05, tolerance: 9.853e+02
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.636e+05, tolerance: 9.853e+02
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.358e+05, tolerance: 9.774e+02
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.821e+04, tolerance: 9.774e+02
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.314e+05, tolerance: 1.013e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.444e+04, tolerance: 9.853e+02
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.852e+05, tolerance: 9.774e+02
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.656e+05, tolerance: 9.835e+02
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.229e+03, tolerance: 1.039e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.298e+04, tolerance: 1.039e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.902e+04, tolerance: 9.835e+02
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.323e+04, tolerance: 1.013e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.824e+03, tolerance: 1.039e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.810e+05, tolerance: 1.013e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.345e+05, tolerance: 9.835e+02
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.197e+04, tolerance: 9.853e+02
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.778e+04, tolerance: 1.013e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.291e+04, tolerance: 9.835e+02
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.258e+04, tolerance: 9.774e+02
#   model = cd_fast.enet_coordinate_descent(
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Pairs_MLP_pca_8.png
#   FCNN/MLP - R²: 0.7874
#
# --------------------------------------------------
# Training with embedding: pca_64
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Free-Pairs
# Using embedding: pca_64
# ============================================================
# Error running Linear models: Embedding column for type pca_64 not found
#
# ============================================================
# Training Random Forest: RE-Free-Pairs
# Using embedding: pca_64
# ============================================================
# Error running Random Forest: Embedding column for type pca_64 not found
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: RE-Free-Pairs
# Using embedding: pca_64
# ============================================================
# Error running FCNN/MLP: Embedding column for type pca_64 not found
#
# ================================================================================
# ORIGINAL DATA WITH EMBEDDINGS - MODEL COMPARISON
# ================================================================================
# Model_Family Model       Dataset Embedding       R2       RMSE        MAE
#       Linear RIDGE     All-Pairs    pca_16 0.787940 111.530067  50.475076
#          MLP  FCNN     All-Pairs    pca_16 0.786277 111.966513  63.766632
# RandomForest    RF     All-Pairs    pca_16 0.785509 112.167659  43.501445
#       Linear RIDGE     All-Pairs    pca_32 0.790850 110.762354  51.344423
#          MLP  FCNN     All-Pairs    pca_32 0.785532 112.161439  66.806916
# RandomForest    RF     All-Pairs    pca_32 0.783382 112.722348  43.823721
#       Linear RIDGE     All-Pairs     pca_8 0.790113 110.957335  50.086731
#          MLP  FCNN     All-Pairs     pca_8 0.784261 112.493380  58.441242
# RandomForest    RF     All-Pairs     pca_8 0.765422 117.302374  46.385551
#          MLP  FCNN     All-Pairs  raw_200D 0.804556 107.071446  58.286287
#       Linear RIDGE     All-Pairs  raw_200D 0.795517 109.519372  51.950872
# RandomForest    RF     All-Pairs  raw_200D 0.788016 111.510172  45.169594
# RandomForest    RF RE-Free-Pairs    pca_16 0.795912 123.734126  76.241858
#          MLP  FCNN RE-Free-Pairs    pca_16 0.784629 127.108387  92.177691
#       Linear RIDGE RE-Free-Pairs    pca_16 0.769846 131.398314  87.553427
# RandomForest    RF RE-Free-Pairs    pca_32 0.776384 129.518562  80.682285
#       Linear LASSO RE-Free-Pairs    pca_32 0.760370 134.076097  84.832266
#          MLP  FCNN RE-Free-Pairs    pca_32 0.652965 161.349170 106.287678
#          MLP  FCNN RE-Free-Pairs     pca_8 0.787377 126.294959  91.511449
#       Linear RIDGE RE-Free-Pairs     pca_8 0.764026 133.049159  85.860911
# RandomForest    RF RE-Free-Pairs     pca_8 0.754652 135.666303  82.403198
#          MLP  FCNN RE-Free-Pairs  raw_200D 0.797174 123.351015  92.451832
#       Linear LASSO RE-Free-Pairs  raw_200D 0.780883 128.209122  81.180760
# RandomForest    RF RE-Free-Pairs  raw_200D 0.778683 128.851043  83.365433
#          MLP  FCNN      RE-Pairs    pca_16 0.939689  39.556360  27.705213
#       Linear RIDGE      RE-Pairs    pca_16 0.925216  44.047660  21.464747
# RandomForest    RF      RE-Pairs    pca_16 0.907537  48.978107  24.709250
#       Linear RIDGE      RE-Pairs    pca_32 0.920177  45.507259  22.634540
# RandomForest    RF      RE-Pairs    pca_32 0.911732  47.853966  24.523009
#          MLP  FCNN      RE-Pairs    pca_32 0.821336  68.082515  39.253097
#          MLP  FCNN      RE-Pairs     pca_8 0.933271  41.607668  24.015602
#       Linear LASSO      RE-Pairs     pca_8 0.922037  44.973958  21.577725
# RandomForest    RF      RE-Pairs     pca_8 0.902847  50.204887  24.952838
#          MLP  FCNN      RE-Pairs  raw_200D 0.934002  41.379240  30.659555
# RandomForest    RF      RE-Pairs  raw_200D 0.928917  42.943651  21.758419
#       Linear LASSO      RE-Pairs  raw_200D 0.914033  47.226240  24.875347
# ================================================================================
# Results saved to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/original_emb_comparison/original_emb_models_comparison.csv
#
# ================================================================================
# BEST MODEL BY DATASET (SORTED BY R2)
# ================================================================================
# Model_Family Model       Dataset Embedding       R2       RMSE       MAE
#          MLP  FCNN      RE-Pairs    pca_16 0.939689  39.556360 27.705213
#          MLP  FCNN     All-Pairs  raw_200D 0.804556 107.071446 58.286287
#          MLP  FCNN RE-Free-Pairs  raw_200D 0.797174 123.351015 92.451832
# ================================================================================
# Best models by dataset saved to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/original_emb_comparison/original_emb_best_by_dataset.csv
#
# R² BY EMBEDDING AND MODEL FAMILY:
#       Dataset Embedding   Linear      MLP  RandomForest
#     All-Pairs    pca_16 0.787940 0.786277      0.785509
#     All-Pairs    pca_32 0.790850 0.785532      0.783382
#     All-Pairs     pca_8 0.790113 0.784261      0.765422
#     All-Pairs  raw_200D 0.795517 0.804556      0.788016
# RE-Free-Pairs    pca_16 0.769846 0.784629      0.795912
# RE-Free-Pairs    pca_32 0.760370 0.652965      0.776384
# RE-Free-Pairs     pca_8 0.764026 0.787377      0.754652
# RE-Free-Pairs  raw_200D 0.780883 0.797174      0.778683
#      RE-Pairs    pca_16 0.925216 0.939689      0.907537
#      RE-Pairs    pca_32 0.920177 0.821336      0.911732
#      RE-Pairs     pca_8 0.922037 0.933271      0.902847
#      RE-Pairs  raw_200D 0.914033 0.934002      0.928917
# Pivot table saved to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/original_emb_comparison/original_emb_comparison_pivot.csv

# %% [markdown]
# #### 4.3 Augmented dataset

# %%
from src.training_augmented import training_augmented

# %%
training_augmented()
# Out:
# ================================================================================
# AUGMENTED DATA TRAINING (NO EMBEDDINGS)
# ================================================================================
#
# ------------------------------------------------------------
# Training on All-Augm dataset type: all
# ------------------------------------------------------------
#
# ============================================================
# Training Symbolic Regression: All-Augm
# ============================================================
# Loading augmented data for all dataset from: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_all.csv
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 2474
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 1979
# Test samples: 495
#
# Fitting PySR model...
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           7.687e+03  0.000e+00  y = x₀
# 3           7.588e+03  6.240e-03  y = x₀ * 0.97721
# 5           7.537e+03  3.084e-03  y = (x₀ + 11.101) * 0.95906
# 9           7.457e+03  2.557e-03  y = ((x₀ * 5.9863e-05) + 0.89102) * (x₀ + 23.477)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#
# Best equation: x0 * 0.9772063
#
# Test Metrics:
#   R² = 0.9271
#   RMSE = 81.53 K
#   MAE = 33.78 K
# [ Info: Results saved to:
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Augm_SR.png
#   Symbolic Regression - R²: 0.9271
#
# ============================================================
# Training Linear Models: All-Augm
# Using only Tc_sim (no embedding)
# ============================================================
# Loading augmented data for all dataset from: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_all.csv
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 2474
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 1979
# Test samples: 495
# Feature dimensions: 1
#
# --- Training LASSO ---
# Best params: {'alpha': 0.0001, 'max_iter': 20000}
# Test R² = 0.9275
# Test RMSE = 81.25 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Augm_lasso_no_emb.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 0.0001}
# Test R² = 0.9275
# Test RMSE = 81.25 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Augm_ridge_no_emb.png
#
# --- Training LINEAR ---
# Best params: {}
# Test R² = 0.9275
# Test RMSE = 81.25 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Augm_linear_no_emb.png
#   Linear - Best model: LASSO, R²: 0.9275
#
# ============================================================
# Training Random Forest: All-Augm
# Using only Tc_sim (no embedding)
# ============================================================
# Loading augmented data for all dataset from: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_all.csv
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 2474
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 1979
# Test samples: 495
# Feature dimensions: 1
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 10, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.9174
#   RMSE = 86.78 K
#   MAE = 42.91 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Augm_RF_no_emb.png
#   Random Forest - R²: 0.9174
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: All-Augm
# Using only Tc_sim (no embedding)
# ============================================================
# Loading augmented data for all dataset from: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_all.csv
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 2474
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 1979
# Test samples: 495
# Feature dimensions: 1
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 11880.4615, Val Loss: 6507.6107
# Early stopping at epoch 39
#
# Final Test Metrics:
#   R² = 0.9275
#   RMSE = 81.27 K
#   MAE = 36.55 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Augm_MLP_no_emb.png
#   FCNN/MLP - R²: 0.9275
#
# ------------------------------------------------------------
# Training on RE-Augm dataset type: re
# ------------------------------------------------------------
#
# ============================================================
# Training Symbolic Regression: RE-Augm
# ============================================================
# Loading augmented data for re dataset from: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_RE.csv
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 1261
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 1008
# Test samples: 253
#
# Fitting PySR model...
#   - outputs/20260113_164709_g0UtUK/hall_of_fame.csv
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.687e+03  0.000e+00  y = x₀
# 3           2.674e+03  2.422e-03  y = x₀ + 3.6874
# 5           2.631e+03  7.832e-03  y = (x₀ * 0.96779) + 10.648
# 9           2.630e+03  6.125e-05  y = (x₀ + 9.5933) * ((x₀ * -1.4809e-05) + 0.97971)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#
# Best equation: (x0 * 0.96778923) + 10.648005
#
# Test Metrics:
#   R² = 0.9671
#   RMSE = 33.54 K
#   MAE = 15.89 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Augm_SR.png
#   Symbolic Regression - R²: 0.9671
#
# ============================================================
# Training Linear Models: RE-Augm
# Using only Tc_sim (no embedding)
# ============================================================
# Loading augmented data for re dataset from: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_RE.csv
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 1261
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 1008
# Test samples: 253
# Feature dimensions: 1
#
# --- Training LASSO ---
# Best params: {'alpha': 0.1, 'max_iter': 20000}
# Test R² = 0.9671
# Test RMSE = 33.53 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Augm_lasso_no_emb.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 0.1}
# Test R² = 0.9671
# Test RMSE = 33.54 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Augm_ridge_no_emb.png
#
# --- Training LINEAR ---
# Best params: {}
# Test R² = 0.9671
# Test RMSE = 33.54 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Augm_linear_no_emb.png
#   Linear - Best model: LASSO, R²: 0.9671
#
# ============================================================
# Training Random Forest: RE-Augm
# Using only Tc_sim (no embedding)
# ============================================================
# Loading augmented data for re dataset from: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_RE.csv
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 1261
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 1008
# Test samples: 253
# Feature dimensions: 1
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.9627
#   RMSE = 35.71 K
#   MAE = 18.64 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Augm_RF_no_emb.png
#   Random Forest - R²: 0.9627
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: RE-Augm
# Using only Tc_sim (no embedding)
# ============================================================
# Loading augmented data for re dataset from: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_RE.csv
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 1261
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 1008
# Test samples: 253
# Feature dimensions: 1
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 4339.2159, Val Loss: 1171.6782
# Epoch [40/200], Train Loss: 5239.7302, Val Loss: 1131.6596
# Early stopping at epoch 53
#
# Final Test Metrics:
#   R² = 0.9667
#   RMSE = 33.75 K
#   MAE = 15.57 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Augm_MLP_no_emb.png
#   FCNN/MLP - R²: 0.9667
#
# ------------------------------------------------------------
# Training on RE-Free-Augm dataset type: re-free
# ------------------------------------------------------------
#
# ============================================================
# Training Symbolic Regression: RE-Free-Augm
# ============================================================
# Loading augmented data for re-free dataset from: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_RE_Free.csv
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 1213
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 970
# Test samples: 243
#
# Fitting PySR model...
#   - outputs/20260113_164724_KMJnzc/hall_of_fame.csv
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.282e+04  0.000e+00  y = x₀
# 3           1.251e+04  1.148e-02  y = x₀ * 0.96815
# 5           1.247e+04  1.355e-03  y = (x₀ * 0.95119) + 11.472
# 9           1.237e+04  1.807e-03  y = (((x₀ * 5.5667e-05) + 0.8801) * x₀) + 26.161
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#
# Best equation: x0 * 0.96814835
#
# Test Metrics:
#   R² = 0.9008
#   RMSE = 113.77 K
#   MAE = 55.92 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_SR.png
#   Symbolic Regression - R²: 0.9008
#
# ============================================================
# Training Linear Models: RE-Free-Augm
# Using only Tc_sim (no embedding)
# ============================================================
# Loading augmented data for re-free dataset from: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_RE_Free.csv
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 1213
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 970
# Test samples: 243
# Feature dimensions: 1
#
# --- Training LASSO ---
# Best params: {'alpha': 0.1, 'max_iter': 20000}
# Test R² = 0.9005
# Test RMSE = 113.95 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_lasso_no_emb.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.9004
# Test RMSE = 113.98 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_ridge_no_emb.png
#
# --- Training LINEAR ---
# Best params: {}
# Test R² = 0.9005
# Test RMSE = 113.94 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_linear_no_emb.png
#   Linear - Best model: LINEAR, R²: 0.9005
#
# ============================================================
# Training Random Forest: RE-Free-Augm
# Using only Tc_sim (no embedding)
# ============================================================
# Loading augmented data for re-free dataset from: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_RE_Free.csv
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 1213
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 970
# Test samples: 243
# Feature dimensions: 1
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.8871
#   RMSE = 121.38 K
#   MAE = 69.04 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_RF_no_emb.png
#   Random Forest - R²: 0.8871
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: RE-Free-Augm
# Using only Tc_sim (no embedding)
# ============================================================
# Loading augmented data for re-free dataset from: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_RE_Free.csv
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 1213
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 970
# Test samples: 243
# Feature dimensions: 1
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 17783.3117, Val Loss: 12670.4084
# Early stopping at epoch 36
#
# Final Test Metrics:
#   R² = 0.9046
#   RMSE = 111.57 K
#   MAE = 58.65 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_MLP_no_emb.png
#   FCNN/MLP - R²: 0.9046
#
# ================================================================================
# AUGMENTED DATA (NO EMBEDDINGS) - MODEL COMPARISON
# ================================================================================
#       Model_Family  Model      Dataset       R2       RMSE       MAE
#             Linear  LASSO     All-Augm 0.927548  81.253476 34.522182
#                MLP   FCNN     All-Augm 0.927524  81.266835 36.554400
# SymbolicRegression   PySR     All-Augm 0.927060  81.526469 33.783785
#       RandomForest     RF     All-Augm 0.917357  86.779831 42.907296
#             Linear  LASSO      RE-Augm 0.967105  33.534100 15.922176
# SymbolicRegression   PySR      RE-Augm 0.967098  33.537570 15.890202
#                MLP   FCNN      RE-Augm 0.966675  33.752566 15.569774
#       RandomForest     RF      RE-Augm 0.962687  35.714930 18.643267
#                MLP   FCNN RE-Free-Augm 0.904592 111.565105 58.653276
# SymbolicRegression   PySR RE-Free-Augm 0.900792 113.765063 55.920432
#             Linear LINEAR RE-Free-Augm 0.900482 113.942461 55.721495
#       RandomForest     RF RE-Free-Augm 0.887075 121.375361 69.036193
# ================================================================================
# Results saved to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/augmented_comparison/augmented_models_comparison.csv
#
# ================================================================================
# BEST MODEL BY DATASET (SORTED BY R2)
# ================================================================================
# Model_Family Model      Dataset       R2       RMSE       MAE
#       Linear LASSO      RE-Augm 0.967105  33.534100 15.922176
#       Linear LASSO     All-Augm 0.927548  81.253476 34.522182
#          MLP  FCNN RE-Free-Augm 0.904592 111.565105 58.653276
# ================================================================================
# Best models by dataset saved to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/augmented_comparison/augmented_best_by_dataset.csv
#
# R² BY DATASET AND MODEL FAMILY:
#      Dataset   Linear      MLP  RandomForest  SymbolicRegression
#     All-Augm 0.927548 0.927524      0.917357            0.927060
#      RE-Augm 0.967105 0.966675      0.962687            0.967098
# RE-Free-Augm 0.900482 0.904592      0.887075            0.900792
# Pivot table saved to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/augmented_comparison/augmented_comparison_pivot.csv
#   - outputs/20260113_164737_vr0GtF/hall_of_fame.csv

# %% [markdown]
# #### 4.4 Augmented dataset with embedding

# %%
from src.training_augmented_emb import train_augmented_embedding

# %%
train_augmented_embedding()
# Out:
# ================================================================================
# AUGMENTED DATA TRAINING WITH EMBEDDINGS
# ================================================================================
# Found PCA-enriched embedding file for all: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_all_emb_w_embeddings_PCA.pkl
# Found PCA-enriched embedding file for re: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_RE_emb_w_embeddings_PCA.pkl
# Found PCA-enriched embedding file for re-free: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_RE_Free_emb_w_embeddings_PCA.pkl
# Loading embeddings file for 'all': /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_all_emb_w_embeddings_PCA.pkl
# Successfully loaded 2013 samples for 'all'
# Available embedding columns for all: ['use_for_emb', 'compound_embedding', 'comp_emb_pca_8_components', 'comp_emb_pca_16_components', 'comp_emb_pca_32_components']
# Available embedding columns: ['use_for_emb', 'compound_embedding', 'comp_emb_pca_8_components', 'comp_emb_pca_16_components', 'comp_emb_pca_32_components']
#
# ============================================================
# DATASET: All-Augm (type: all)
# ============================================================
#
# --------------------------------------------------
# Training with embedding: raw_200D
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: All-Augm
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 2013
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 1610
# Test samples: 403
# Feature dimensions: 201
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.9234
# Test RMSE = 76.64 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Augm_lasso_None.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 10}
# Test R² = 0.9236
# Test RMSE = 76.53 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Augm_ridge_None.png
#   Linear - Best model: RIDGE, R²: 0.9236
#
# ============================================================
# Training Random Forest: All-Augm
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 2013
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 1610
# Test samples: 403
# Feature dimensions: 201
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.9259
#   RMSE = 75.38 K
#   MAE = 38.82 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Augm_RF_None.png
#   Random Forest - R²: 0.9259
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: All-Augm
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: all
#   - Target column: Tc_exp
#   - Total rows: 2013
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 1610
# Test samples: 403
# Feature dimensions: 201
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 12068.8050, Val Loss: 7855.6033
# Epoch [40/200], Train Loss: 11347.8631, Val Loss: 6659.0117
# Epoch [60/200], Train Loss: 11347.7632, Val Loss: 6743.2286
# Epoch [80/200], Train Loss: 9277.1571, Val Loss: 6265.8431
# Early stopping at epoch 90
#
# Final Test Metrics:
#   R² = 0.9206
#   RMSE = 78.03 K
#   MAE = 47.66 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Augm_MLP_None.png
#   FCNN/MLP - R²: 0.9206
#
# --------------------------------------------------
# Training with embedding: pca_16
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: All-Augm
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 1610
# Test samples: 403
# Feature dimensions: 17
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.9230
# Test RMSE = 76.83 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Augm_lasso_pca_16.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.9222
# Test RMSE = 77.24 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Augm_ridge_pca_16.png
#   Linear - Best model: LASSO, R²: 0.9230
#
# ============================================================
# Training Random Forest: All-Augm
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 1610
# Test samples: 403
# Feature dimensions: 17
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': None, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.9256
#   RMSE = 75.53 K
#   MAE = 38.68 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Augm_RF_pca_16.png
#   Random Forest - R²: 0.9256
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: All-Augm
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 1610
# Test samples: 403
# Feature dimensions: 17
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 11894.2218, Val Loss: 6463.2745
# Epoch [40/200], Train Loss: 11828.8720, Val Loss: 5726.5466
# Epoch [60/200], Train Loss: 10328.4856, Val Loss: 5632.0736
# Epoch [80/200], Train Loss: 10151.4689, Val Loss: 5579.4134
# Early stopping at epoch 91
#
# Final Test Metrics:
#   R² = 0.9267
#   RMSE = 74.94 K
#   MAE = 42.03 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Augm_MLP_pca_16.png
#   FCNN/MLP - R²: 0.9267
#
# --------------------------------------------------
# Training with embedding: pca_32
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: All-Augm
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 1610
# Test samples: 403
# Feature dimensions: 33
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.9237
# Test RMSE = 76.49 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Augm_lasso_pca_32.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.9232
# Test RMSE = 76.73 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Augm_ridge_pca_32.png
#   Linear - Best model: LASSO, R²: 0.9237
#
# ============================================================
# Training Random Forest: All-Augm
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 1610
# Test samples: 403
# Feature dimensions: 33
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.9263
#   RMSE = 75.16 K
#   MAE = 38.10 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Augm_RF_pca_32.png
#   Random Forest - R²: 0.9263
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: All-Augm
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 1610
# Test samples: 403
# Feature dimensions: 33
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 13231.7030, Val Loss: 7192.9374
# Epoch [40/200], Train Loss: 10523.9174, Val Loss: 6178.7016
# Epoch [60/200], Train Loss: 10833.2733, Val Loss: 6086.5520
# Epoch [80/200], Train Loss: 11416.2514, Val Loss: 5644.1833
# Early stopping at epoch 85
#
# Final Test Metrics:
#   R² = 0.9261
#   RMSE = 75.26 K
#   MAE = 44.70 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Augm_MLP_pca_32.png
#   FCNN/MLP - R²: 0.9261
#
# --------------------------------------------------
# Training with embedding: pca_8
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: All-Augm
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 1610
# Test samples: 403
# Feature dimensions: 9
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.9229
# Test RMSE = 76.90 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Augm_lasso_pca_8.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 0.1}
# Test R² = 0.9221
# Test RMSE = 77.27 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Augm_ridge_pca_8.png
#   Linear - Best model: LASSO, R²: 0.9229
#
# ============================================================
# Training Random Forest: All-Augm
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 1610
# Test samples: 403
# Feature dimensions: 9
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.9233
#   RMSE = 76.69 K
#   MAE = 39.11 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Augm_RF_pca_8.png
#   Random Forest - R²: 0.9233
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: All-Augm
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 1610
# Test samples: 403
# Feature dimensions: 9
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 10846.1607, Val Loss: 6187.1949
# Epoch [40/200], Train Loss: 10514.4231, Val Loss: 5762.5546
# Epoch [60/200], Train Loss: 10108.9002, Val Loss: 5812.6539
# Early stopping at epoch 66
#
# Final Test Metrics:
#   R² = 0.9264
#   RMSE = 75.14 K
#   MAE = 42.11 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/All-Augm_MLP_pca_8.png
#   FCNN/MLP - R²: 0.9264
#
# --------------------------------------------------
# Training with embedding: pca_64
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: All-Augm
# Using embedding: pca_64
# ============================================================
# Error running Linear models: Embedding column for type pca_64 not found
#
# ============================================================
# Training Random Forest: All-Augm
# Using embedding: pca_64
# ============================================================
# Error running Random Forest: Embedding column for type pca_64 not found
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: All-Augm
# Using embedding: pca_64
# ============================================================
# Error running FCNN/MLP: Embedding column for type pca_64 not found
#
# ============================================================
# DATASET: RE-Augm (type: re)
# ============================================================
# Loading embeddings file for 're': /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_RE_emb_w_embeddings_PCA.pkl
# Successfully loaded 1083 samples for 're'
# Available embedding columns for re: ['use_for_emb', 'compound_embedding', 'comp_emb_pca_8_components', 'comp_emb_pca_16_components', 'comp_emb_pca_32_components']
#
# --------------------------------------------------
# Training with embedding: raw_200D
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Augm
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 1083
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 866
# Test samples: 217
# Feature dimensions: 201
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.9018
# Test RMSE = 60.95 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Augm_lasso_None.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 10}
# Test R² = 0.9031
# Test RMSE = 60.54 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Augm_ridge_None.png
#   Linear - Best model: RIDGE, R²: 0.9031
#
# ============================================================
# Training Random Forest: RE-Augm
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 1083
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 866
# Test samples: 217
# Feature dimensions: 201
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.8993
#   RMSE = 61.74 K
#   MAE = 26.05 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Augm_RF_None.png
#   Random Forest - R²: 0.8993
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: RE-Augm
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: re
#   - Target column: Tc_exp
#   - Total rows: 1083
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 866
# Test samples: 217
# Feature dimensions: 201
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 12018.6784, Val Loss: 15285.0027
# Epoch [40/200], Train Loss: 4707.2343, Val Loss: 4565.9106
# Epoch [60/200], Train Loss: 4348.2017, Val Loss: 3887.9178
# Epoch [80/200], Train Loss: 4116.4912, Val Loss: 3840.1419
# Epoch [100/200], Train Loss: 4077.2138, Val Loss: 3832.2804
# Early stopping at epoch 106
#
# Final Test Metrics:
#   R² = 0.9067
#   RMSE = 59.43 K
#   MAE = 29.78 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Augm_MLP_None.png
#   FCNN/MLP - R²: 0.9067
#
# --------------------------------------------------
# Training with embedding: pca_16
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Augm
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 866
# Test samples: 217
# Feature dimensions: 17
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.9019
# Test RMSE = 60.92 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Augm_lasso_pca_16.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.9018
# Test RMSE = 60.95 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Augm_ridge_pca_16.png
#   Linear - Best model: LASSO, R²: 0.9019
#
# ============================================================
# Training Random Forest: RE-Augm
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 866
# Test samples: 217
# Feature dimensions: 17
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 10, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.8940
#   RMSE = 63.34 K
#   MAE = 25.27 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Augm_RF_pca_16.png
#   Random Forest - R²: 0.8940
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: RE-Augm
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 866
# Test samples: 217
# Feature dimensions: 17
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 4218.6965, Val Loss: 4538.7339
# Epoch [40/200], Train Loss: 6817.4092, Val Loss: 4160.0621
# Epoch [60/200], Train Loss: 3917.7801, Val Loss: 3596.6777
# Epoch [80/200], Train Loss: 3692.5624, Val Loss: 3666.4052
# Early stopping at epoch 97
#
# Final Test Metrics:
#   R² = 0.9091
#   RMSE = 58.66 K
#   MAE = 26.81 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Augm_MLP_pca_16.png
#   FCNN/MLP - R²: 0.9091
#
# --------------------------------------------------
# Training with embedding: pca_32
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Augm
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 866
# Test samples: 217
# Feature dimensions: 33
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.9020
# Test RMSE = 60.91 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Augm_lasso_pca_32.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.9021
# Test RMSE = 60.85 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Augm_ridge_pca_32.png
#   Linear - Best model: RIDGE, R²: 0.9021
#
# ============================================================
# Training Random Forest: RE-Augm
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 866
# Test samples: 217
# Feature dimensions: 33
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 10, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.8942
#   RMSE = 63.27 K
#   MAE = 25.83 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Augm_RF_pca_32.png
#   Random Forest - R²: 0.8942
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: RE-Augm
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 866
# Test samples: 217
# Feature dimensions: 33
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 4017.2020, Val Loss: 4841.0694
# Epoch [40/200], Train Loss: 3731.1993, Val Loss: 3940.4893
# Epoch [60/200], Train Loss: 3534.3676, Val Loss: 3632.6858
# Epoch [80/200], Train Loss: 3583.1139, Val Loss: 3391.7539
# Epoch [100/200], Train Loss: 3467.9938, Val Loss: 3364.6945
# Epoch [120/200], Train Loss: 3305.1064, Val Loss: 3339.4130
# Early stopping at epoch 121
#
# Final Test Metrics:
#   R² = 0.9185
#   RMSE = 55.55 K
#   MAE = 27.25 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Augm_MLP_pca_32.png
#   FCNN/MLP - R²: 0.9185
#
# --------------------------------------------------
# Training with embedding: pca_8
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Augm
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 866
# Test samples: 217
# Feature dimensions: 9
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.9018
# Test RMSE = 60.97 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Augm_lasso_pca_8.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.9013
# Test RMSE = 61.11 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Augm_ridge_pca_8.png
#   Linear - Best model: LASSO, R²: 0.9018
#
# ============================================================
# Training Random Forest: RE-Augm
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 866
# Test samples: 217
# Feature dimensions: 9
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 10, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.8924
#   RMSE = 63.81 K
#   MAE = 25.31 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Augm_RF_pca_8.png
#   Random Forest - R²: 0.8924
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: RE-Augm
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 866
# Test samples: 217
# Feature dimensions: 9
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 3918.0062, Val Loss: 4733.1057
# Epoch [40/200], Train Loss: 4092.9984, Val Loss: 3951.9066
# Epoch [60/200], Train Loss: 3318.3979, Val Loss: 4210.7059
# Epoch [80/200], Train Loss: 3088.4955, Val Loss: 3671.9860
# Epoch [100/200], Train Loss: 3423.1103, Val Loss: 3628.1876
# Early stopping at epoch 114
#
# Final Test Metrics:
#   R² = 0.9103
#   RMSE = 58.27 K
#   MAE = 25.13 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Augm_MLP_pca_8.png
#   FCNN/MLP - R²: 0.9103
#
# --------------------------------------------------
# Training with embedding: pca_64
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Augm
# Using embedding: pca_64
# ============================================================
# Error running Linear models: Embedding column for type pca_64 not found
#
# ============================================================
# Training Random Forest: RE-Augm
# Using embedding: pca_64
# ============================================================
# Error running Random Forest: Embedding column for type pca_64 not found
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: RE-Augm
# Using embedding: pca_64
# ============================================================
# Error running FCNN/MLP: Embedding column for type pca_64 not found
#
# ============================================================
# DATASET: RE-Free-Augm (type: re-free)
# ============================================================
# Loading embeddings file for 're-free': /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/outputs/Augm_RE_Free_emb_w_embeddings_PCA.pkl
# Successfully loaded 930 samples for 're-free'
# Available embedding columns for re-free: ['use_for_emb', 'compound_embedding', 'comp_emb_pca_8_components', 'comp_emb_pca_16_components', 'comp_emb_pca_32_components']
#
# --------------------------------------------------
# Training with embedding: raw_200D
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Free-Augm
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 930
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 744
# Test samples: 186
# Feature dimensions: 201
#
# --- Training LASSO ---
# Best params: {'alpha': 10, 'max_iter': 20000}
# Test R² = 0.8770
# Test RMSE = 109.94 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_lasso_None.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 10}
# Test R² = 0.8646
# Test RMSE = 115.36 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_ridge_None.png
#   Linear - Best model: LASSO, R²: 0.8770
#
# ============================================================
# Training Random Forest: RE-Free-Augm
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 930
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 744
# Test samples: 186
# Feature dimensions: 201
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.8489
#   RMSE = 121.86 K
#   MAE = 64.80 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_RF_None.png
#   Random Forest - R²: 0.8489
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: RE-Free-Augm
# Using embedding: None
# ============================================================
#
# Dataset diagnostics:
#   - Dataset type: re-free
#   - Target column: Tc_exp
#   - Total rows: 930
#   - Rows with NaN in Tc_sim: 0
#   - Rows with NaN in Tc_exp: 0
# Training samples: 744
# Test samples: 186
# Feature dimensions: 201
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 43132.0785, Val Loss: 45877.5329
# Epoch [40/200], Train Loss: 20990.0779, Val Loss: 20095.7848
# Epoch [60/200], Train Loss: 18476.2229, Val Loss: 17205.6979
# Epoch [80/200], Train Loss: 17747.7954, Val Loss: 17684.4465
# Early stopping at epoch 95
#
# Final Test Metrics:
#   R² = 0.8476
#   RMSE = 122.36 K
#   MAE = 85.48 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_MLP_None.png
#   FCNN/MLP - R²: 0.8476
#
# --------------------------------------------------
# Training with embedding: pca_16
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Free-Augm
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 744
# Test samples: 186
# Feature dimensions: 17
#
# --- Training LASSO ---
# Best params: {'alpha': 1, 'max_iter': 20000}
# Test R² = 0.8740
# Test RMSE = 111.24 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_lasso_pca_16.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.8719
# Test RMSE = 112.21 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_ridge_pca_16.png
#   Linear - Best model: LASSO, R²: 0.8740
#
# ============================================================
# Training Random Forest: RE-Free-Augm
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 744
# Test samples: 186
# Feature dimensions: 17
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.8545
#   RMSE = 119.56 K
#   MAE = 62.74 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_RF_pca_16.png
#   Random Forest - R²: 0.8545
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: RE-Free-Augm
# Using embedding: pca_16
# ============================================================
# Using column comp_emb_pca_16_components for embedding type pca_16
# Training samples: 744
# Test samples: 186
# Feature dimensions: 17
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 21347.2946, Val Loss: 16849.0168
# Epoch [40/200], Train Loss: 19259.9574, Val Loss: 14563.4425
# Epoch [60/200], Train Loss: 18726.7180, Val Loss: 14717.5586
# Epoch [80/200], Train Loss: 17721.8403, Val Loss: 14720.7494
# Epoch [100/200], Train Loss: 17075.8139, Val Loss: 14483.3550
# Epoch [120/200], Train Loss: 19325.1613, Val Loss: 14388.0345
# Early stopping at epoch 132
#
# Final Test Metrics:
#   R² = 0.8656
#   RMSE = 114.93 K
#   MAE = 72.89 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_MLP_pca_16.png
#   FCNN/MLP - R²: 0.8656
#
# --------------------------------------------------
# Training with embedding: pca_32
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Free-Augm
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 744
# Test samples: 186
# Feature dimensions: 33
#
# --- Training LASSO ---
# Best params: {'alpha': 10, 'max_iter': 20000}
# Test R² = 0.8766
# Test RMSE = 110.09 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_lasso_pca_32.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.8677
# Test RMSE = 113.99 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_ridge_pca_32.png
#   Linear - Best model: LASSO, R²: 0.8766
#
# ============================================================
# Training Random Forest: RE-Free-Augm
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 744
# Test samples: 186
# Feature dimensions: 33
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.8517
#   RMSE = 120.72 K
#   MAE = 62.62 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_RF_pca_32.png
#   Random Forest - R²: 0.8517
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: RE-Free-Augm
# Using embedding: pca_32
# ============================================================
# Using column comp_emb_pca_32_components for embedding type pca_32
# Training samples: 744
# Test samples: 186
# Feature dimensions: 33
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 23517.2774, Val Loss: 20556.8333
# Epoch [40/200], Train Loss: 18516.5614, Val Loss: 18352.2010
# Epoch [60/200], Train Loss: 16283.0563, Val Loss: 17896.0623
# Epoch [80/200], Train Loss: 18011.2313, Val Loss: 16673.5275
# Epoch [100/200], Train Loss: 15857.6690, Val Loss: 16873.6072
# Epoch [120/200], Train Loss: 17528.9417, Val Loss: 15815.5564
# Early stopping at epoch 125
#
# Final Test Metrics:
#   R² = 0.8477
#   RMSE = 122.31 K
#   MAE = 80.34 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_MLP_pca_32.png
#   FCNN/MLP - R²: 0.8477
#
# --------------------------------------------------
# Training with embedding: pca_8
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Free-Augm
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 744
# Test samples: 186
# Feature dimensions: 9
#
# --- Training LASSO ---
# Best params: {'alpha': 0.1, 'max_iter': 20000}
# Test R² = 0.8745
# Test RMSE = 111.04 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_lasso_pca_8.png
#
# --- Training RIDGE ---
# Best params: {'alpha': 1}
# Test R² = 0.8745
# Test RMSE = 111.06 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_ridge_pca_8.png
#   Linear - Best model: LASSO, R²: 0.8745
#
# ============================================================
# Training Random Forest: RE-Free-Augm
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 744
# Test samples: 186
# Feature dimensions: 9
#
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 20, 'bootstrap': True}
#
# Test Metrics:
#   R² = 0.8463
#   RMSE = 122.90 K
#   MAE = 66.26 K
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_RF_pca_8.png
#   Random Forest - R²: 0.8463
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: RE-Free-Augm
# Using embedding: pca_8
# ============================================================
# Using column comp_emb_pca_8_components for embedding type pca_8
# Training samples: 744
# Test samples: 186
# Feature dimensions: 9
# Hidden dimensions: [128, 64, 32]
#
# Training...
# Epoch [20/200], Train Loss: 20216.5962, Val Loss: 15043.4118
# Epoch [40/200], Train Loss: 18330.5231, Val Loss: 13231.5243
# Epoch [60/200], Train Loss: 18401.6493, Val Loss: 12550.7909
# Epoch [80/200], Train Loss: 17081.3929, Val Loss: 12823.0489
# Early stopping at epoch 95
#
# Final Test Metrics:
#   R² = 0.8837
#   RMSE = 106.87 K
#   MAE = 65.10 K
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.002e+06, tolerance: 1.000e+04
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.186e+06, tolerance: 1.000e+04
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.073e+05, tolerance: 9.964e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.433e+06, tolerance: 1.009e+04
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.847e+06, tolerance: 1.027e+04
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.837e+05, tolerance: 1.027e+04
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.041e+05, tolerance: 1.002e+04
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.294e+06, tolerance: 1.002e+04
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.417e+06, tolerance: 9.964e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.647e+05, tolerance: 1.027e+04
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.678e+06, tolerance: 9.964e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.972e+05, tolerance: 9.964e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.279e+06, tolerance: 1.000e+04
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.795e+06, tolerance: 1.009e+04
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.448e+06, tolerance: 1.027e+04
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.161e+06, tolerance: 1.002e+04
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.938e+04, tolerance: 1.027e+04
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.546e+04, tolerance: 1.000e+04
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.685e+06, tolerance: 1.009e+04
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.380e+05, tolerance: 1.000e+04
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.362e+06, tolerance: 1.009e+04
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.574e+05, tolerance: 1.002e+04
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.421e+04, tolerance: 2.429e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.649e+05, tolerance: 2.103e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.854e+05, tolerance: 2.256e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.360e+05, tolerance: 2.103e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.861e+05, tolerance: 2.420e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.197e+05, tolerance: 2.420e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.718e+05, tolerance: 2.433e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.755e+05, tolerance: 2.433e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.132e+05, tolerance: 2.429e+03
#   model = cd_fast.enet_coordinate_descent(
# ...
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.850e+04, tolerance: 2.256e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.288e+05, tolerance: 2.103e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.007e+04, tolerance: 2.103e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.262e+05, tolerance: 5.536e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.396e+05, tolerance: 6.234e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.925e+05, tolerance: 6.419e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.894e+05, tolerance: 5.987e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.542e+05, tolerance: 6.083e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.578e+05, tolerance: 5.536e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.021e+06, tolerance: 6.419e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.576e+05, tolerance: 6.083e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.288e+05, tolerance: 5.987e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.260e+06, tolerance: 6.234e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.317e+05, tolerance: 5.536e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.048e+05, tolerance: 5.987e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.004e+05, tolerance: 6.083e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.130e+06, tolerance: 6.234e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.131e+06, tolerance: 5.536e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.528e+05, tolerance: 6.419e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.030e+06, tolerance: 6.083e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.703e+05, tolerance: 5.987e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.606e+04, tolerance: 6.083e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.506e+03, tolerance: 5.987e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.037e+05, tolerance: 6.419e+03
#   model = cd_fast.enet_coordinate_descent(
# /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/exp-sim-tc/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.863e+05, tolerance: 6.234e+03
#   model = cd_fast.enet_coordinate_descent(
# Saved figure to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/figures/RE-Free-Augm_MLP_pca_8.png
#   FCNN/MLP - R²: 0.8837
#
# --------------------------------------------------
# Training with embedding: pca_64
# --------------------------------------------------
#
# ============================================================
# Training Linear Models: RE-Free-Augm
# Using embedding: pca_64
# ============================================================
# Error running Linear models: Embedding column for type pca_64 not found
#
# ============================================================
# Training Random Forest: RE-Free-Augm
# Using embedding: pca_64
# ============================================================
# Error running Random Forest: Embedding column for type pca_64 not found
# Using device: cuda
#
# ============================================================
# Training FCNN/MLP: RE-Free-Augm
# Using embedding: pca_64
# ============================================================
# Error running FCNN/MLP: Embedding column for type pca_64 not found
#
# ================================================================================
# AUGMENTED DATA WITH EMBEDDINGS - MODEL COMPARISON
# ================================================================================
# Model_Family Model      Dataset Embedding       R2       RMSE       MAE
#          MLP  FCNN     All-Augm    pca_16 0.926748  74.941696 42.034217
# RandomForest    RF     All-Augm    pca_16 0.925592  75.530422 38.680004
#       Linear LASSO     All-Augm    pca_16 0.923003  76.833547 37.867888
# RandomForest    RF     All-Augm    pca_32 0.926322  75.159462 38.098966
#          MLP  FCNN     All-Augm    pca_32 0.926118  75.263094 44.702736
#       Linear LASSO     All-Augm    pca_32 0.923689  76.490282 37.762763
#          MLP  FCNN     All-Augm     pca_8 0.926354  75.142771 42.113606
# RandomForest    RF     All-Augm     pca_8 0.923291  76.689599 39.112355
#       Linear LASSO     All-Augm     pca_8 0.922869  76.900497 38.102377
# RandomForest    RF     All-Augm  raw_200D 0.925893  75.377689 38.820745
#       Linear RIDGE     All-Augm  raw_200D 0.923617  76.526536 40.496460
#          MLP  FCNN     All-Augm  raw_200D 0.920577  78.034630 47.656873
#          MLP  FCNN      RE-Augm    pca_16 0.909068  58.660409 26.807201
#       Linear LASSO      RE-Augm    pca_16 0.901919  60.922646 23.011288
# RandomForest    RF      RE-Augm    pca_16 0.893973  63.342490 25.274453
#          MLP  FCNN      RE-Augm    pca_32 0.918468  55.545706 27.245521
#       Linear RIDGE      RE-Augm    pca_32 0.902149  60.851212 23.116582
# RandomForest    RF      RE-Augm    pca_32 0.894222  63.268248 25.827529
#          MLP  FCNN      RE-Augm     pca_8 0.910262  58.273950 25.132249
#       Linear LASSO      RE-Augm     pca_8 0.901772  60.968539 22.984709
# RandomForest    RF      RE-Augm     pca_8 0.892403  63.809851 25.314506
#          MLP  FCNN      RE-Augm  raw_200D 0.906660  59.432043 29.778462
#       Linear RIDGE      RE-Augm  raw_200D 0.903137  60.543173 24.241767
# RandomForest    RF      RE-Augm  raw_200D 0.899261  61.742835 26.051562
#       Linear LASSO RE-Free-Augm    pca_16 0.874046 111.243031 60.067561
#          MLP  FCNN RE-Free-Augm    pca_16 0.865559 114.930050 72.891792
# RandomForest    RF RE-Free-Augm    pca_16 0.854519 119.555806 62.741415
#       Linear LASSO RE-Free-Augm    pca_32 0.876641 110.091045 59.708031
# RandomForest    RF RE-Free-Augm    pca_32 0.851670 120.720892 62.615939
#          MLP  FCNN RE-Free-Augm    pca_32 0.847728 122.314118 80.335495
#          MLP  FCNN RE-Free-Augm     pca_8 0.883747 106.873364 65.098913
#       Linear LASSO RE-Free-Augm     pca_8 0.874498 111.043374 59.883864
# RandomForest    RF RE-Free-Augm     pca_8 0.846267 122.899555 66.260776
#       Linear LASSO RE-Free-Augm  raw_200D 0.876971 109.943699 59.355834
# RandomForest    RF RE-Free-Augm  raw_200D 0.848867 121.855869 64.797749
#          MLP  FCNN RE-Free-Augm  raw_200D 0.847617 122.358867 85.479211
# ================================================================================
# Results saved to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/augmented_emb_comparison/augmented_emb_models_comparison.csv
#
# ================================================================================
# BEST MODEL BY DATASET (SORTED BY R2)
# ================================================================================
# Model_Family Model      Dataset Embedding       R2       RMSE       MAE
#          MLP  FCNN     All-Augm    pca_16 0.926748  74.941696 42.034217
#          MLP  FCNN      RE-Augm    pca_32 0.918468  55.545706 27.245521
#          MLP  FCNN RE-Free-Augm     pca_8 0.883747 106.873364 65.098913
# ================================================================================
# Best models by dataset saved to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/augmented_emb_comparison/augmented_emb_best_by_dataset.csv
#
# R² BY EMBEDDING AND MODEL FAMILY:
#      Dataset Embedding   Linear      MLP  RandomForest
#     All-Augm    pca_16 0.923003 0.926748      0.925592
#     All-Augm    pca_32 0.923689 0.926118      0.926322
#     All-Augm     pca_8 0.922869 0.926354      0.923291
#     All-Augm  raw_200D 0.923617 0.920577      0.925893
#      RE-Augm    pca_16 0.901919 0.909068      0.893973
#      RE-Augm    pca_32 0.902149 0.918468      0.894222
#      RE-Augm     pca_8 0.901772 0.910262      0.892403
#      RE-Augm  raw_200D 0.903137 0.906660      0.899261
# RE-Free-Augm    pca_16 0.874046 0.865559      0.854519
# RE-Free-Augm    pca_32 0.876641 0.847728      0.851670
# RE-Free-Augm     pca_8 0.874498 0.883747      0.846267
# RE-Free-Augm  raw_200D 0.876971 0.847617      0.848867
# Pivot table saved to: /raven/ptmp/cwinkler/ML-models/experimental-simulation-tc/results/augmented_emb_comparison/augmented_emb_comparison_pivot.csv
